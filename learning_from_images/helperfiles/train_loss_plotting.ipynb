# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
output_yolo_classifier = """Epoch 1/300, Train Loss: 1.1091982523600261, Val Loss: 1.1021813948949177
Epoch 2/300, Train Loss: 1.0780143464605014, Val Loss: 1.0954264601071675
Epoch 3/300, Train Loss: 1.0699573730429013, Val Loss: 1.08590567111969
Epoch 4/300, Train Loss: 1.037667341530323, Val Loss: 1.0957881410916646
Epoch 5/300, Train Loss: 1.0372535288333893, Val Loss: 1.0938873589038849
Epoch 6/300, Train Loss: 1.0026701415578525, Val Loss: 1.1163830657800038
Epoch 7/300, Train Loss: 1.0032261063655217, Val Loss: 1.1240219275156658
Epoch 8/300, Train Loss: 0.9431488861640295, Val Loss: 1.1519787013530731
Epoch 9/300, Train Loss: 0.9470668534437815, Val Loss: 1.1573596199353535
Epoch 10/300, Train Loss: 0.9508445163567861, Val Loss: 1.1522014141082764
Epoch 11/300, Train Loss: 0.8849179918567339, Val Loss: 1.1746953626473744
Epoch 12/300, Train Loss: 0.8964316472411156, Val Loss: 1.1942291458447774
Epoch 13/300, Train Loss: 0.8657328709959984, Val Loss: 1.1883347928524017
Epoch 14/300, Train Loss: 0.8468053589264551, Val Loss: 1.1786315441131592
Epoch 15/300, Train Loss: 0.8864972740411758, Val Loss: 1.2209628423055012
Epoch 16/300, Train Loss: 0.7894013226032257, Val Loss: 1.1928689380486805
Epoch 17/300, Train Loss: 0.7649058674772581, Val Loss: 1.24397940436999
Epoch 18/300, Train Loss: 0.7850714015463988, Val Loss: 1.1966145932674408
Epoch 19/300, Train Loss: 0.7596641754110655, Val Loss: 1.1889840265115101
Epoch 20/300, Train Loss: 0.7827411368489265, Val Loss: 1.223503549893697
Epoch 21/300, Train Loss: 0.740581930304567, Val Loss: 1.1563419103622437
Epoch 22/300, Train Loss: 0.7394697939356168, Val Loss: 1.1344914833704631
Epoch 23/300, Train Loss: 0.6481424222389857, Val Loss: 1.1338092188040416
Epoch 24/300, Train Loss: 0.656074375535051, Val Loss: 1.1557658811410267
Epoch 25/300, Train Loss: 0.6786970856289068, Val Loss: 1.1613270044326782
Epoch 26/300, Train Loss: 0.6487497587998708, Val Loss: 1.1537398546934128
Epoch 27/300, Train Loss: 0.6605400477225581, Val Loss: 1.162799894809723
Epoch 28/300, Train Loss: 0.6449060216546059, Val Loss: 1.1493006547292073
Epoch 29/300, Train Loss: 0.6129581468800703, Val Loss: 1.1296210686365764
Epoch 30/300, Train Loss: 0.5322440201416612, Val Loss: 1.1882148732741673
Epoch 31/300, Train Loss: 0.475701997987926, Val Loss: 1.2090901533762615
Epoch 32/300, Train Loss: 0.5266178001960119, Val Loss: 1.1690620183944702
Epoch 33/300, Train Loss: 0.5140794919182857, Val Loss: 1.1646217952171962
Epoch 34/300, Train Loss: 0.5880071918169657, Val Loss: 1.1629916379849117
Epoch 35/300, Train Loss: 0.5955224943657716, Val Loss: 1.1852114746967952
Epoch 36/300, Train Loss: 0.487900177637736, Val Loss: 1.1698771168788273
Epoch 37/300, Train Loss: 0.507918005498747, Val Loss: 1.227187027533849
Epoch 38/300, Train Loss: 0.4301497203608354, Val Loss: 1.1819808234771092
Epoch 39/300, Train Loss: 0.5341988420113921, Val Loss: 1.197593316435814
Epoch 40/300, Train Loss: 0.36075986611346406, Val Loss: 1.1554307142893474
Epoch 41/300, Train Loss: 0.47502003346259397, Val Loss: 1.1580175111691158
Epoch 42/300, Train Loss: 0.4440077521527807, Val Loss: 1.1764671554168065
Epoch 43/300, Train Loss: 0.39814308440933627, Val Loss: 1.1997214208046596
Epoch 44/300, Train Loss: 0.4507424334685008, Val Loss: 1.233901744087537
Epoch 45/300, Train Loss: 0.35604372760280967, Val Loss: 1.2877812286218007
Epoch 46/300, Train Loss: 0.4307286062588294, Val Loss: 1.225814312696457
Epoch 47/300, Train Loss: 0.3658433778521915, Val Loss: 1.2883594036102295
Epoch 48/300, Train Loss: 0.3766560759395361, Val Loss: 1.2372460812330246
Epoch 49/300, Train Loss: 0.38692769734188914, Val Loss: 1.2206206023693085
Epoch 50/300, Train Loss: 0.3246476457764705, Val Loss: 1.2756576538085938
Epoch 51/300, Train Loss: 0.34944333229213953, Val Loss: 1.2987288584311802
Epoch 52/300, Train Loss: 0.43145851550313336, Val Loss: 1.1090479840834935
Epoch 53/300, Train Loss: 0.3090443240168194, Val Loss: 1.2637746470669906
Epoch 54/300, Train Loss: 0.30588867313538987, Val Loss: 1.2186421702305477
Epoch 55/300, Train Loss: 0.3942707947765787, Val Loss: 1.2252498343586922
Epoch 56/300, Train Loss: 0.33560818061232567, Val Loss: 1.2159413397312164
Epoch 57/300, Train Loss: 0.2885705023848762, Val Loss: 1.265473149716854
Epoch 58/300, Train Loss: 0.2941460389799128, Val Loss: 1.3178543547789257
Epoch 59/300, Train Loss: 0.31203722356197733, Val Loss: 1.2854174623886745
Epoch 60/300, Train Loss: 0.3347405440484484, Val Loss: 1.2820542653401692
Epoch 61/300, Train Loss: 0.23084643172721067, Val Loss: 1.2666286081075668
Epoch 62/300, Train Loss: 0.2685241576594611, Val Loss: 1.3094857533772786
Epoch 63/300, Train Loss: 0.24917587513724962, Val Loss: 1.3031770984331768
Epoch 64/300, Train Loss: 0.38522510859183967, Val Loss: 1.3322800596555073
Epoch 65/300, Train Loss: 0.26983235353448737, Val Loss: 1.375974364578724
Epoch 66/300, Train Loss: 0.3152081928759192, Val Loss: 1.4859592194358509
Epoch 67/300, Train Loss: 0.23037552429984012, Val Loss: 1.3835287963350613
Epoch 68/300, Train Loss: 0.2907544227782637, Val Loss: 1.5276437538365524
Epoch 69/300, Train Loss: 0.24467991571873426, Val Loss: 1.4564265062411625
Epoch 70/300, Train Loss: 0.24658615867762515, Val Loss: 1.4613144447406132
Epoch 71/300, Train Loss: 0.2423059962068995, Val Loss: 1.4502608974774678
Epoch 72/300, Train Loss: 0.2602421655319631, Val Loss: 1.5028646836678188
Epoch 73/300, Train Loss: 0.27680338771703344, Val Loss: 1.4199455305933952
Epoch 74/300, Train Loss: 0.24558423049650932, Val Loss: 1.4559345493714015
Epoch 75/300, Train Loss: 0.20284950589605918, Val Loss: 1.4133170396089554
Epoch 76/300, Train Loss: 0.28257880908980343, Val Loss: 1.420451598862807
Epoch 77/300, Train Loss: 0.2059912687788407, Val Loss: 1.4792585323254268
Epoch 78/300, Train Loss: 0.23823080898728222, Val Loss: 1.5594708745678265
Epoch 79/300, Train Loss: 0.2119563694577664, Val Loss: 1.5491338695089023
Epoch 80/300, Train Loss: 0.2889958424105619, Val Loss: 1.5228943129380543
Epoch 81/300, Train Loss: 0.20791273723201206, Val Loss: 1.4719794715444248
Epoch 82/300, Train Loss: 0.2537148195163657, Val Loss: 1.5071075310309727
Epoch 83/300, Train Loss: 0.275893344078213, Val Loss: 1.5613983521858852
Epoch 84/300, Train Loss: 0.2613516183725248, Val Loss: 1.596046877404054
Epoch 85/300, Train Loss: 0.21035246385145, Val Loss: 1.604480932156245
Epoch 86/300, Train Loss: 0.18126468370125318, Val Loss: 1.5736765166123707
Epoch 87/300, Train Loss: 0.18089481334512433, Val Loss: 1.5649342375497024
Epoch 88/300, Train Loss: 0.21123753560823388, Val Loss: 1.4306925609707832
Epoch 89/300, Train Loss: 0.1483057204944392, Val Loss: 1.6517748801658552
Epoch 90/300, Train Loss: 0.20950427072239108, Val Loss: 1.556582895418008
Epoch 91/300, Train Loss: 0.1583413683498899, Val Loss: 1.509041115641594
Epoch 92/300, Train Loss: 0.26774115233759704, Val Loss: 1.5520374936362107
Epoch 93/300, Train Loss: 0.2103526460317274, Val Loss: 1.4380838746825855
Epoch 94/300, Train Loss: 0.1703813269850798, Val Loss: 1.5276589716474216
Epoch 95/300, Train Loss: 0.25501285419644165, Val Loss: 1.597363072137038
Epoch 96/300, Train Loss: 0.1658157688798383, Val Loss: 1.6729855152467887
Epoch 97/300, Train Loss: 0.1347148277758, Val Loss: 1.6254550541440647
Epoch 98/300, Train Loss: 0.15291856755114472, Val Loss: 1.6055423468351364
Epoch 99/300, Train Loss: 0.18658411495077112, Val Loss: 1.7003584299236536
Epoch 100/300, Train Loss: 0.22361117427741797, Val Loss: 1.6553699113428593
Epoch 101/300, Train Loss: 0.3050712902719776, Val Loss: 1.662598190208276
Epoch 102/300, Train Loss: 0.17184523949496602, Val Loss: 1.6198322276274364
Epoch 103/300, Train Loss: 0.15935005767581364, Val Loss: 1.6729962130387623
Epoch 104/300, Train Loss: 0.13981997903465526, Val Loss: 1.7185621336102486
Epoch 105/300, Train Loss: 0.18503270378884432, Val Loss: 1.6535476570328076
Epoch 106/300, Train Loss: 0.24167157895863056, Val Loss: 1.6496670134365559
Epoch 107/300, Train Loss: 0.15194475956862638, Val Loss: 1.686345258106788
Epoch 108/300, Train Loss: 0.12327435755287297, Val Loss: 1.7165421719352405
Epoch 109/300, Train Loss: 0.09317312331404537, Val Loss: 1.7858089283108711
Epoch 110/300, Train Loss: 0.13997752805395672, Val Loss: 1.7333620215455692
Epoch 111/300, Train Loss: 0.19134436410483127, Val Loss: 1.8036705578366916
Epoch 112/300, Train Loss: 0.15640875033083526, Val Loss: 1.72249831755956
Epoch 113/300, Train Loss: 0.14326859350937107, Val Loss: 1.6330915838479996
Epoch 114/300, Train Loss: 0.23591343458974734, Val Loss: 1.8809481995801132
Epoch 115/300, Train Loss: 0.1799073819614326, Val Loss: 1.6436518107851346
Epoch 116/300, Train Loss: 0.2039703186698413, Val Loss: 1.8345094888160627
Epoch 117/300, Train Loss: 0.1458451557943287, Val Loss: 1.5281039699912071
Epoch 118/300, Train Loss: 0.13253634035936557, Val Loss: 1.5854761178294818
Epoch 119/300, Train Loss: 0.07878964254147529, Val Loss: 1.7356543714801471
Epoch 120/300, Train Loss: 0.13604957349283117, Val Loss: 1.636079341173172
Epoch 121/300, Train Loss: 0.1625176903010773, Val Loss: 1.6269784743587177
Epoch 122/300, Train Loss: 0.09615688670116167, Val Loss: 1.6773474911848705
Epoch 123/300, Train Loss: 0.12509918326395564, Val Loss: 1.7210911462704341
Epoch 124/300, Train Loss: 0.11358794316038257, Val Loss: 1.6825554482638836
Epoch 125/300, Train Loss: 0.055430632033676375, Val Loss: 1.7847686186432838
Epoch 126/300, Train Loss: 0.18532788697242117, Val Loss: 1.8380898510416348
Epoch 127/300, Train Loss: 0.10308970855476218, Val Loss: 1.9566369745880365
Epoch 128/300, Train Loss: 0.11130090171657987, Val Loss: 1.9541222732514143
Epoch 129/300, Train Loss: 0.18974863601276107, Val Loss: 1.91375295445323
Epoch 130/300, Train Loss: 0.1281358843940931, Val Loss: 1.7100068690876167
Epoch 131/300, Train Loss: 0.11315471392542047, Val Loss: 1.896092305580775
Epoch 132/300, Train Loss: 0.11709054068584616, Val Loss: 2.0134060342485705
Epoch 133/300, Train Loss: 0.05815371075671768, Val Loss: 1.8348184215525787
Epoch 134/300, Train Loss: 0.07422628544736654, Val Loss: 1.9253518792490165
Epoch 135/300, Train Loss: 0.08558274752431316, Val Loss: 1.9865539204329252
Epoch 136/300, Train Loss: 0.12299042902304791, Val Loss: 1.8787859504421551
Epoch 137/300, Train Loss: 0.13064757857015744, Val Loss: 1.8125210360934336
Epoch 138/300, Train Loss: 0.15351027468811176, Val Loss: 1.7768409519145887
Epoch 139/300, Train Loss: 0.08391400598581338, Val Loss: 1.9389480880151193
Epoch 140/300, Train Loss: 0.123129595759868, Val Loss: 1.8587088398635387
Epoch 141/300, Train Loss: 0.1100577925487111, Val Loss: 1.8498624588052432
Epoch 142/300, Train Loss: 0.06799840495417205, Val Loss: 1.8700716594854991
Epoch 143/300, Train Loss: 0.13185019859277722, Val Loss: 1.9248478909333546
Epoch 144/300, Train Loss: 0.0655575280058353, Val Loss: 1.9343105964362621
Epoch 145/300, Train Loss: 0.0974258659601522, Val Loss: 1.9786711670458317
Epoch 146/300, Train Loss: 0.08593367649882566, Val Loss: 1.9517462303241093
Epoch 147/300, Train Loss: 0.11757484358289123, Val Loss: 2.0777755131324134
Epoch 148/300, Train Loss: 0.0619742290849293, Val Loss: 2.0533696760733924
Epoch 149/300, Train Loss: 0.06354264826707852, Val Loss: 2.0091908425092697
Epoch 150/300, Train Loss: 0.10764378806925379, Val Loss: 2.0110333263874054
Epoch 151/300, Train Loss: 0.08268210742001732, Val Loss: 1.8912029042840004
Epoch 152/300, Train Loss: 0.05618679885568175, Val Loss: 2.002090367178122
Epoch 153/300, Train Loss: 0.1009229420160409, Val Loss: 2.208554861446222
Epoch 154/300, Train Loss: 0.11586486452142708, Val Loss: 2.048590611666441
Epoch 155/300, Train Loss: 0.08334464754443616, Val Loss: 2.030542813241482
Epoch 156/300, Train Loss: 0.06572922536724946, Val Loss: 1.9979815172652404
Epoch 157/300, Train Loss: 0.05114869768613062, Val Loss: 1.974743664264679
Epoch 158/300, Train Loss: 0.10015002588140003, Val Loss: 2.073018979281187
Epoch 159/300, Train Loss: 0.05021864848337524, Val Loss: 2.0076621559758983
Epoch 160/300, Train Loss: 0.08233599485053371, Val Loss: 2.0002952416737876
Epoch 161/300, Train Loss: 0.05263018201731029, Val Loss: 1.994844580690066
Epoch 162/300, Train Loss: 0.06300703934175544, Val Loss: 2.1418447786321244
Epoch 163/300, Train Loss: 0.05582266126051157, Val Loss: 2.0952919411162534
Epoch 164/300, Train Loss: 0.07878076365765689, Val Loss: 1.967544826368491
Epoch 165/300, Train Loss: 0.16111724633568278, Val Loss: 2.182082712650299
Epoch 166/300, Train Loss: 0.08778473776571143, Val Loss: 2.154915936291218
Epoch 167/300, Train Loss: 0.1074457965860347, Val Loss: 2.236860396961371
Epoch 168/300, Train Loss: 0.09085432315381088, Val Loss: 2.183755338191986
Epoch 169/300, Train Loss: 0.07232232843064897, Val Loss: 2.232504367828369
Epoch 170/300, Train Loss: 0.05023985592924873, Val Loss: 2.183475747704506
Epoch 171/300, Train Loss: 0.03822683490094884, Val Loss: 2.1973598822951317
Epoch 172/300, Train Loss: 0.06720487334390175, Val Loss: 2.176258364071449
Epoch 173/300, Train Loss: 0.06895804042990979, Val Loss: 2.1266675485918918
Epoch 174/300, Train Loss: 0.06016243053939737, Val Loss: 2.121891220410665
Epoch 175/300, Train Loss: 0.06845526040463785, Val Loss: 2.2093363466362157
Epoch 176/300, Train Loss: 0.03438804929176816, Val Loss: 2.1786667431394258
Epoch 177/300, Train Loss: 0.0523563958061762, Val Loss: 2.1849656576911607
Epoch 178/300, Train Loss: 0.04508813978767042, Val Loss: 2.216487673421701
Epoch 179/300, Train Loss: 0.09864548924754975, Val Loss: 2.281383221348127
Epoch 180/300, Train Loss: 0.06327318017671739, Val Loss: 2.2299106096227965
Epoch 181/300, Train Loss: 0.09088931602066926, Val Loss: 2.133675886938969
Epoch 182/300, Train Loss: 0.09519497097062413, Val Loss: 2.592233012740811
Epoch 183/300, Train Loss: 0.06937718624370366, Val Loss: 2.3970166283349195
Epoch 184/300, Train Loss: 0.08373294647359823, Val Loss: 2.416547443717718
Epoch 185/300, Train Loss: 0.05591374017603812, Val Loss: 2.5089373849332333
Epoch 186/300, Train Loss: 0.04052277605690809, Val Loss: 2.511675418665012
Epoch 187/300, Train Loss: 0.06143532038307361, Val Loss: 2.3334033836921058
Epoch 188/300, Train Loss: 0.059380801600733925, Val Loss: 2.449519529938698
Epoch 189/300, Train Loss: 0.1378401200182632, Val Loss: 2.4220338935653367
Epoch 190/300, Train Loss: 0.05856503490728452, Val Loss: 2.4005793929100037
Epoch 191/300, Train Loss: 0.04124821850882654, Val Loss: 2.487082896133264
Epoch 192/300, Train Loss: 0.048828571717119, Val Loss: 2.327832897504171
Epoch 193/300, Train Loss: 0.11278407709930131, Val Loss: 2.4316255723436675
Epoch 194/300, Train Loss: 0.05742677406184763, Val Loss: 2.6156413182616234
Epoch 195/300, Train Loss: 0.10360751233747578, Val Loss: 2.426577042788267
Epoch 196/300, Train Loss: 0.06012700739544622, Val Loss: 2.267288714647293
Epoch 197/300, Train Loss: 0.061902437739263405, Val Loss: 2.3951177895069122
Epoch 198/300, Train Loss: 0.07339617755951622, Val Loss: 2.418790010114511
Epoch 199/300, Train Loss: 0.0910939641338094, Val Loss: 2.3690254042545953
Epoch 200/300, Train Loss: 0.05190584162968056, Val Loss: 2.3330268003046513
Epoch 201/300, Train Loss: 0.025090054029230185, Val Loss: 2.2911320899923644
Epoch 202/300, Train Loss: 0.030109092245766078, Val Loss: 2.318976944933335
Epoch 203/300, Train Loss: 0.032884649397601606, Val Loss: 2.377554730201761
Epoch 204/300, Train Loss: 0.061160672728798694, Val Loss: 2.4022000432014465
Epoch 205/300, Train Loss: 0.05151247106732626, Val Loss: 2.640664681792259
Epoch 206/300, Train Loss: 0.05392460749953898, Val Loss: 2.580593983332316
Epoch 207/300, Train Loss: 0.016794455501440098, Val Loss: 2.4915380850434303
Epoch 208/300, Train Loss: 0.045900748435087735, Val Loss: 2.6481122573216758
Epoch 209/300, Train Loss: 0.02725495870223919, Val Loss: 2.581901511798302
Epoch 210/300, Train Loss: 0.03429606014954819, Val Loss: 2.492640994489193
Epoch 211/300, Train Loss: 0.045549067420627885, Val Loss: 2.465397762755553
Epoch 212/300, Train Loss: 0.027289604758455727, Val Loss: 2.454226770748695
Epoch 213/300, Train Loss: 0.04408476454182164, Val Loss: 2.5453776717185974
Epoch 214/300, Train Loss: 0.02392657934736538, Val Loss: 2.535659903039535
Epoch 215/300, Train Loss: 0.03230251942432005, Val Loss: 2.6556422896683216
Epoch 216/300, Train Loss: 0.050951615366405655, Val Loss: 2.3685005574176707
Epoch 217/300, Train Loss: 0.02953401665824155, Val Loss: 2.4000696539878845
Epoch 218/300, Train Loss: 0.032230784718497794, Val Loss: 2.5001162867993116
Epoch 219/300, Train Loss: 0.04288649138137165, Val Loss: 2.6670485362410545
Epoch 220/300, Train Loss: 0.06132441222204458, Val Loss: 2.7130155358463526
Epoch 221/300, Train Loss: 0.021124775261635403, Val Loss: 2.822595088121792
Epoch 222/300, Train Loss: 0.047203671357541076, Val Loss: 2.5439980486407876
Epoch 223/300, Train Loss: 0.09215110135666767, Val Loss: 2.749756706878543
Epoch 224/300, Train Loss: 0.11589203135554271, Val Loss: 2.810029330352942
Epoch 225/300, Train Loss: 0.040130818407457504, Val Loss: 2.9054192770272493
Epoch 226/300, Train Loss: 0.08424219460963893, Val Loss: 2.955036412924528
Epoch 227/300, Train Loss: 0.016874697007248567, Val Loss: 2.9221266681949296
Epoch 228/300, Train Loss: 0.0416965937142777, Val Loss: 2.812976191441218
Epoch 229/300, Train Loss: 0.040176753396887456, Val Loss: 2.7922750090559325
Epoch 230/300, Train Loss: 0.024174645378631492, Val Loss: 2.725184142589569
Epoch 231/300, Train Loss: 0.012066676994588002, Val Loss: 2.709334187209606
Epoch 232/300, Train Loss: 0.03217632661282247, Val Loss: 2.7004678721229234
Epoch 233/300, Train Loss: 0.07698229968794597, Val Loss: 2.7430457000931106
Epoch 234/300, Train Loss: 0.052910565806693434, Val Loss: 2.6932103720804057
Epoch 235/300, Train Loss: 0.05585860342034721, Val Loss: 2.591034933924675
Epoch 236/300, Train Loss: 0.026062414976877335, Val Loss: 2.6375035755336285
Epoch 237/300, Train Loss: 0.034805042161375845, Val Loss: 2.6338569882015386
Epoch 238/300, Train Loss: 0.03451692895722166, Val Loss: 2.645192132641872
Epoch 239/300, Train Loss: 0.03258408224125257, Val Loss: 2.701849410931269
Epoch 240/300, Train Loss: 0.023768837975012502, Val Loss: 2.6241001399854817
Epoch 241/300, Train Loss: 0.021576756387579128, Val Loss: 2.7025665674979487
Epoch 242/300, Train Loss: 0.04054509565345654, Val Loss: 2.615994371473789
Epoch 243/300, Train Loss: 0.03181549644417222, Val Loss: 2.5500128796945014
Epoch 244/300, Train Loss: 0.025701965755691464, Val Loss: 2.6427559815347195
Epoch 245/300, Train Loss: 0.08936132511144024, Val Loss: 2.691700699428717
Epoch 246/300, Train Loss: 0.035944188033378545, Val Loss: 2.741522608945767
Epoch 247/300, Train Loss: 0.024140531943776484, Val Loss: 2.7761590480804443
Epoch 248/300, Train Loss: 0.011746783696869064, Val Loss: 2.689269127945105
Epoch 249/300, Train Loss: 0.032455106386047795, Val Loss: 2.657578277091185
Epoch 250/300, Train Loss: 0.04190911634255675, Val Loss: 2.721305779491862
Epoch 251/300, Train Loss: 0.09880565687490162, Val Loss: 2.501660461227099
Epoch 252/300, Train Loss: 0.03781566256490502, Val Loss: 2.5032824811836085
Epoch 253/300, Train Loss: 0.010535809391664467, Val Loss: 2.5450399996091924
Epoch 254/300, Train Loss: 0.026880583897157823, Val Loss: 2.568918302965661
Epoch 255/300, Train Loss: 0.033623950457088846, Val Loss: 2.623757526278496
Epoch 256/300, Train Loss: 0.037028656804750426, Val Loss: 2.6367735005915165
Epoch 257/300, Train Loss: 0.06133289490518715, Val Loss: 2.7421875381842256
Epoch 258/300, Train Loss: 0.013085070966553758, Val Loss: 2.7748813995470605
Epoch 259/300, Train Loss: 0.02692754956861639, Val Loss: 2.6983878072351217
Epoch 260/300, Train Loss: 0.0390943589507818, Val Loss: 2.761587722847859
Epoch 261/300, Train Loss: 0.03280687104188473, Val Loss: 2.715482709618906
Epoch 262/300, Train Loss: 0.05649276999785494, Val Loss: 2.766136975338062
Epoch 263/300, Train Loss: 0.030824390582893102, Val Loss: 2.8713858909904957
Epoch 264/300, Train Loss: 0.029431293484454574, Val Loss: 2.84385026867191
Epoch 265/300, Train Loss: 0.02542124144383706, Val Loss: 2.9221491183464727
Epoch 266/300, Train Loss: 0.012080314527944816, Val Loss: 2.9333797747579715
Epoch 267/300, Train Loss: 0.021472789601521214, Val Loss: 2.844983534576992
Epoch 268/300, Train Loss: 0.027407840072783074, Val Loss: 2.8515725918114185
Epoch 269/300, Train Loss: 0.05409654190047301, Val Loss: 2.9481368605047464
Epoch 270/300, Train Loss: 0.034992286058402065, Val Loss: 3.131234411150217
Epoch 271/300, Train Loss: 0.03114839362967814, Val Loss: 3.0299247205257416
Epoch 272/300, Train Loss: 0.029853064979420196, Val Loss: 3.084054989274591
Epoch 273/300, Train Loss: 0.01439650289785277, Val Loss: 2.904157074789206
Epoch 274/300, Train Loss: 0.05030826052135732, Val Loss: 2.7379279732704163
Epoch 275/300, Train Loss: 0.03520955913578897, Val Loss: 3.1558486595749855
Epoch 276/300, Train Loss: 0.06509511290679863, Val Loss: 3.0799148666361966
Epoch 277/300, Train Loss: 0.06674974525829687, Val Loss: 3.2113703126087785
Epoch 278/300, Train Loss: 0.04547461833726629, Val Loss: 3.3043647271891436
Epoch 279/300, Train Loss: 0.01870999861830569, Val Loss: 3.2644262034446
Epoch 280/300, Train Loss: 0.0855962326968438, Val Loss: 3.053241773198048
Epoch 281/300, Train Loss: 0.015242351725495004, Val Loss: 3.010256052017212
Epoch 282/300, Train Loss: 0.03642914046304213, Val Loss: 3.0344962210704884
Epoch 283/300, Train Loss: 0.07301455959691339, Val Loss: 3.06005766770492
Epoch 284/300, Train Loss: 0.018664083246221708, Val Loss: 3.1418698939184346
Epoch 285/300, Train Loss: 0.03484273244563004, Val Loss: 3.200751980766654
Epoch 286/300, Train Loss: 0.027188972639294207, Val Loss: 3.1063510651389756
Epoch 287/300, Train Loss: 0.017906290833574683, Val Loss: 3.0409843772649765
Epoch 288/300, Train Loss: 0.06474195827831863, Val Loss: 3.1340569282571473
Epoch 289/300, Train Loss: 0.009980229471163208, Val Loss: 3.214186329394579
Epoch 290/300, Train Loss: 0.029413175195486474, Val Loss: 3.286211763198177
Epoch 291/300, Train Loss: 0.01012359207118152, Val Loss: 3.2017814069986343
Epoch 292/300, Train Loss: 0.01693163465641116, Val Loss: 3.2816722554465136
Epoch 293/300, Train Loss: 0.0258829602030346, Val Loss: 3.3129332195967436
Epoch 294/300, Train Loss: 0.014443605068815183, Val Loss: 3.1855839428802333
Epoch 295/300, Train Loss: 0.060000165565118856, Val Loss: 3.253547011564175
Epoch 296/300, Train Loss: 0.02719104379169342, Val Loss: 3.255569026184579
Epoch 297/300, Train Loss: 0.01629502349953782, Val Loss: 3.249841598367008
Epoch 298/300, Train Loss: 0.07541373120970245, Val Loss: 2.997887664784988
Epoch 299/300, Train Loss: 0.03034951962717969, Val Loss: 3.0056619544823966
Epoch 300/300, Train Loss: 0.03348153605782045, Val Loss: 2.8961916056772075"""
    
output_yolo_classifier = output_yolo_classifier.split("\n")
train_loss = [float(x.split(":")[1].split(",")[0]) for x in output_yolo_classifier]
val_loss = [float(x.split(":")[2]) for x in output_yolo_classifier]

plt.figure(figsize=(10,5))

plt.title("YOLO as Keypoint Detector + Classifier Train/Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.plot(train_loss, label="Train Loss")
plt.plot(val_loss, label="Val Loss")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 306
#     303 train_loss = [float(x.split(":")[1].split(",")[0]) for x in output_yolo_classifier]
#     304 val_loss = [float(x.split(":")[2]) for x in output_yolo_classifier]
# --> 306 plt.figure(figsize=(10,5))
#     308 plt.title("YOLO as Keypoint Detector + Classifier Train Loss")
#     309 plt.xlabel("Epoch")
#
# NameError: name 'plt' is not defined

# %%
output_yolo_scorer = """Epoch 1/200, Train Loss: 9.94090716044108, Val Loss: 7.285461902618408
Epoch 2/200, Train Loss: 5.165814956029256, Val Loss: 2.8560447692871094
Epoch 3/200, Train Loss: 5.056501309076945, Val Loss: 2.93658447265625
Epoch 4/200, Train Loss: 4.389483729998271, Val Loss: 4.412543773651123
Epoch 5/200, Train Loss: 4.397926052411397, Val Loss: 3.7507526874542236
Epoch 6/200, Train Loss: 4.160508553187053, Val Loss: 2.940628170967102
Epoch 7/200, Train Loss: 4.444228649139404, Val Loss: 3.0711225271224976
Epoch 8/200, Train Loss: 4.25360894203186, Val Loss: 3.8176181316375732
Epoch 9/200, Train Loss: 4.197326421737671, Val Loss: 3.132803201675415
Epoch 10/200, Train Loss: 4.1536392370859785, Val Loss: 3.028965473175049
Epoch 11/200, Train Loss: 4.153962095578511, Val Loss: 3.1693012714385986
Epoch 12/200, Train Loss: 4.109477639198303, Val Loss: 3.4885964393615723
Epoch 13/200, Train Loss: 4.06604524453481, Val Loss: 3.112795114517212
Epoch 14/200, Train Loss: 4.032925168673198, Val Loss: 3.082727789878845
Epoch 15/200, Train Loss: 4.029442350069682, Val Loss: 2.996743321418762
Epoch 16/200, Train Loss: 4.095206220944722, Val Loss: 3.2580907344818115
Epoch 17/200, Train Loss: 4.152835687001546, Val Loss: 3.575348734855652
Epoch 18/200, Train Loss: 4.151475389798482, Val Loss: 3.087362766265869
Epoch 19/200, Train Loss: 4.060190717379252, Val Loss: 3.2206512689590454
Epoch 20/200, Train Loss: 4.006862759590149, Val Loss: 3.3028303384780884
Epoch 21/200, Train Loss: 4.008845965067546, Val Loss: 3.2597835063934326
Epoch 22/200, Train Loss: 3.9808014233907065, Val Loss: 3.122888445854187
Epoch 23/200, Train Loss: 4.083855628967285, Val Loss: 2.920050621032715
Epoch 24/200, Train Loss: 4.170560280481975, Val Loss: 3.4419091939926147
Epoch 25/200, Train Loss: 4.008891065915425, Val Loss: 3.1428476572036743
Epoch 26/200, Train Loss: 3.977160930633545, Val Loss: 2.9120259284973145
Epoch 27/200, Train Loss: 4.031715949376424, Val Loss: 3.370343804359436
Epoch 28/200, Train Loss: 4.246863603591919, Val Loss: 3.0949807167053223
Epoch 29/200, Train Loss: 4.0840771198272705, Val Loss: 3.398118019104004
Epoch 30/200, Train Loss: 4.064545154571533, Val Loss: 3.0731769800186157
Epoch 31/200, Train Loss: 4.014250675837199, Val Loss: 3.275188446044922
Epoch 32/200, Train Loss: 4.073831677436829, Val Loss: 3.1661221981048584
Epoch 33/200, Train Loss: 4.084106882413228, Val Loss: 2.906603693962097
Epoch 34/200, Train Loss: 3.9855524698893228, Val Loss: 3.119584083557129
Epoch 35/200, Train Loss: 4.038880983988444, Val Loss: 3.0100988149642944
Epoch 36/200, Train Loss: 3.9963703552881875, Val Loss: 3.2039551734924316
Epoch 37/200, Train Loss: 4.020304640134175, Val Loss: 3.0509192943573
Epoch 38/200, Train Loss: 3.9880597988764444, Val Loss: 3.3908159732818604
Epoch 39/200, Train Loss: 4.10040005048116, Val Loss: 3.2316707372665405
Epoch 40/200, Train Loss: 4.057876706123352, Val Loss: 3.0591254234313965
Epoch 41/200, Train Loss: 4.071197112401326, Val Loss: 3.1259340047836304
Epoch 42/200, Train Loss: 4.0855278968811035, Val Loss: 3.279343843460083
Epoch 43/200, Train Loss: 3.9994585116704306, Val Loss: 3.083698272705078
Epoch 44/200, Train Loss: 4.067968289057414, Val Loss: 3.2195215225219727
Epoch 45/200, Train Loss: 3.964817523956299, Val Loss: 2.9867695569992065
Epoch 46/200, Train Loss: 3.978444457054138, Val Loss: 3.2440699338912964
Epoch 47/200, Train Loss: 4.029647787412007, Val Loss: 3.142145037651062
Epoch 48/200, Train Loss: 4.029979268709819, Val Loss: 3.3938841819763184
Epoch 49/200, Train Loss: 4.031410336494446, Val Loss: 3.2628071308135986
Epoch 50/200, Train Loss: 3.987224022547404, Val Loss: 3.149731993675232
Epoch 51/200, Train Loss: 4.038204312324524, Val Loss: 3.087390422821045
Epoch 52/200, Train Loss: 3.988138119379679, Val Loss: 3.377804398536682
Epoch 53/200, Train Loss: 4.007826288541158, Val Loss: 3.133183002471924
Epoch 54/200, Train Loss: 4.045995235443115, Val Loss: 3.017635226249695
Epoch 55/200, Train Loss: 4.045149087905884, Val Loss: 2.982164740562439
Epoch 56/200, Train Loss: 4.140931646029155, Val Loss: 3.245706796646118
Epoch 57/200, Train Loss: 3.967063824335734, Val Loss: 3.3752607107162476
Epoch 58/200, Train Loss: 4.04484756787618, Val Loss: 3.0361005067825317
Epoch 59/200, Train Loss: 4.004429936408997, Val Loss: 3.186065435409546
Epoch 60/200, Train Loss: 4.024644573529561, Val Loss: 3.2152912616729736
Epoch 61/200, Train Loss: 3.9720210234324136, Val Loss: 3.089469075202942
Epoch 62/200, Train Loss: 3.9665350914001465, Val Loss: 3.01817524433136
Epoch 63/200, Train Loss: 3.983779867490133, Val Loss: 3.0533095598220825
Epoch 64/200, Train Loss: 3.893630067507426, Val Loss: 3.1905009746551514
Epoch 65/200, Train Loss: 3.991280118624369, Val Loss: 3.0446592569351196
Epoch 66/200, Train Loss: 3.9885129928588867, Val Loss: 3.195535898208618
Epoch 67/200, Train Loss: 3.9893441597620645, Val Loss: 3.3260579109191895
Epoch 68/200, Train Loss: 3.937659581502279, Val Loss: 3.0721954107284546
Epoch 69/200, Train Loss: 4.201789100964864, Val Loss: 2.8948038816452026
Epoch 70/200, Train Loss: 4.197255730628967, Val Loss: 3.8867448568344116
Epoch 71/200, Train Loss: 4.239170749982198, Val Loss: 3.034621834754944
Epoch 72/200, Train Loss: 4.056868275006612, Val Loss: 2.895982027053833
Epoch 73/200, Train Loss: 4.1186535358428955, Val Loss: 3.5403642654418945
Epoch 74/200, Train Loss: 4.039822061856587, Val Loss: 3.0392236709594727
Epoch 75/200, Train Loss: 4.0404413143793745, Val Loss: 2.9907186031341553
Epoch 76/200, Train Loss: 4.039351105690002, Val Loss: 3.1872698068618774
Epoch 77/200, Train Loss: 4.001898328463237, Val Loss: 3.3053609132766724
Epoch 78/200, Train Loss: 3.9642425775527954, Val Loss: 3.125392198562622
Epoch 79/200, Train Loss: 3.9880356391270957, Val Loss: 3.1826692819595337
Epoch 80/200, Train Loss: 4.19375216960907, Val Loss: 2.8581652641296387
Epoch 81/200, Train Loss: 3.9340282678604126, Val Loss: 3.30981981754303
Epoch 82/200, Train Loss: 4.036618709564209, Val Loss: 3.2995694875717163
Epoch 83/200, Train Loss: 4.031542420387268, Val Loss: 2.912002921104431
Epoch 84/200, Train Loss: 3.9894240299860635, Val Loss: 3.129038691520691
Epoch 85/200, Train Loss: 4.066548148790996, Val Loss: 3.4168843030929565
Epoch 86/200, Train Loss: 3.999019980430603, Val Loss: 3.019574761390686
Epoch 87/200, Train Loss: 4.145672043164571, Val Loss: 3.29585063457489
Epoch 88/200, Train Loss: 4.0973325570424395, Val Loss: 2.9184482097625732
Epoch 89/200, Train Loss: 4.019850452740987, Val Loss: 3.2509905099868774
Epoch 90/200, Train Loss: 4.128957112630208, Val Loss: 3.0770055055618286
Epoch 91/200, Train Loss: 4.013973673184712, Val Loss: 3.3573148250579834
Epoch 92/200, Train Loss: 3.97989559173584, Val Loss: 3.2416696548461914
Epoch 93/200, Train Loss: 3.976278821627299, Val Loss: 3.2338532209396362
Epoch 94/200, Train Loss: 4.062809467315674, Val Loss: 3.2284785509109497
Epoch 95/200, Train Loss: 4.01751693089803, Val Loss: 2.873937726020813
Epoch 96/200, Train Loss: 3.987208286921183, Val Loss: 3.1613528728485107
Epoch 97/200, Train Loss: 3.9549105962117515, Val Loss: 3.1684261560440063
Epoch 98/200, Train Loss: 3.968215545018514, Val Loss: 2.956809401512146
Epoch 99/200, Train Loss: 3.945677916208903, Val Loss: 3.1348754167556763
Epoch 100/200, Train Loss: 4.035255948702495, Val Loss: 3.31558895111084
Epoch 101/200, Train Loss: 3.9912013610204062, Val Loss: 3.08327579498291
Epoch 102/200, Train Loss: 3.9954893986384072, Val Loss: 2.965124726295471
Epoch 103/200, Train Loss: 4.0177876551946, Val Loss: 3.323803424835205
Epoch 104/200, Train Loss: 4.0059967041015625, Val Loss: 3.214537501335144
Epoch 105/200, Train Loss: 4.033567388852437, Val Loss: 2.878106117248535
Epoch 106/200, Train Loss: 4.037314613660176, Val Loss: 3.3049509525299072
Epoch 107/200, Train Loss: 4.010432442029317, Val Loss: 3.1336230039596558
Epoch 108/200, Train Loss: 3.9128266175587973, Val Loss: 3.0198543071746826
Epoch 109/200, Train Loss: 3.9513354698816934, Val Loss: 3.016785502433777
Epoch 110/200, Train Loss: 3.9784040451049805, Val Loss: 3.1664735078811646
Epoch 111/200, Train Loss: 4.007726510365804, Val Loss: 3.333341360092163
Epoch 112/200, Train Loss: 3.9652390480041504, Val Loss: 3.141024589538574
Epoch 113/200, Train Loss: 3.988883296648661, Val Loss: 3.015965700149536
Epoch 114/200, Train Loss: 3.971613804499308, Val Loss: 3.157652735710144
Epoch 115/200, Train Loss: 4.003772536913554, Val Loss: 3.0579334497451782
Epoch 116/200, Train Loss: 3.9770673910776773, Val Loss: 3.276607871055603
Epoch 117/200, Train Loss: 3.9968677361806235, Val Loss: 3.010316491127014
Epoch 118/200, Train Loss: 3.9869529406229653, Val Loss: 3.154711127281189
Epoch 119/200, Train Loss: 3.92712672551473, Val Loss: 3.0663174390792847
Epoch 120/200, Train Loss: 3.9724371830622354, Val Loss: 3.0037710666656494
Epoch 121/200, Train Loss: 3.992011467615763, Val Loss: 3.238453507423401
Epoch 122/200, Train Loss: 3.943894624710083, Val Loss: 3.060420513153076
Epoch 123/200, Train Loss: 4.088792641957601, Val Loss: 2.939384341239929
Epoch 124/200, Train Loss: 3.981953740119934, Val Loss: 3.534689784049988
Epoch 125/200, Train Loss: 4.007912675539653, Val Loss: 3.363353967666626
Epoch 126/200, Train Loss: 3.9353328545888266, Val Loss: 2.9520514011383057
Epoch 127/200, Train Loss: 4.059278130531311, Val Loss: 3.1486414670944214
Epoch 128/200, Train Loss: 3.924245039621989, Val Loss: 3.3432291746139526
Epoch 129/200, Train Loss: 4.016842206319173, Val Loss: 3.2678654193878174
Epoch 130/200, Train Loss: 3.934413274129232, Val Loss: 3.0221447944641113
Epoch 131/200, Train Loss: 3.9809347788492837, Val Loss: 3.117789149284363
Epoch 132/200, Train Loss: 4.008951226870219, Val Loss: 3.131064534187317
Epoch 133/200, Train Loss: 4.069729208946228, Val Loss: 3.5211691856384277
Epoch 134/200, Train Loss: 3.9758148193359375, Val Loss: 3.0685946941375732
Epoch 135/200, Train Loss: 3.8717353343963623, Val Loss: 2.951112747192383
Epoch 136/200, Train Loss: 4.023246963818868, Val Loss: 3.255180597305298
Epoch 137/200, Train Loss: 4.076350927352905, Val Loss: 3.6341798305511475
Epoch 138/200, Train Loss: 4.054892937342326, Val Loss: 2.964266300201416
Epoch 139/200, Train Loss: 4.131766676902771, Val Loss: 2.98975932598114
Epoch 140/200, Train Loss: 4.0394041538238525, Val Loss: 3.8191263675689697
Epoch 141/200, Train Loss: 4.149021665255229, Val Loss: 3.37523353099823
Epoch 142/200, Train Loss: 4.036752065022786, Val Loss: 2.9102389812469482
Epoch 143/200, Train Loss: 4.052000880241394, Val Loss: 3.3369052410125732
Epoch 144/200, Train Loss: 3.9708118438720703, Val Loss: 3.3675694465637207
Epoch 145/200, Train Loss: 3.96345849831899, Val Loss: 2.9825775623321533
Epoch 146/200, Train Loss: 3.9508206049601235, Val Loss: 3.1024587154388428
Epoch 147/200, Train Loss: 3.953557014465332, Val Loss: 3.184501886367798
Epoch 148/200, Train Loss: 3.895148197809855, Val Loss: 3.156611442565918
Epoch 149/200, Train Loss: 4.051581819852193, Val Loss: 2.9428943395614624
Epoch 150/200, Train Loss: 3.9785807132720947, Val Loss: 3.065812826156616
Epoch 151/200, Train Loss: 3.9317731459935508, Val Loss: 3.379688024520874
Epoch 152/200, Train Loss: 3.980888565381368, Val Loss: 3.213498592376709
Epoch 153/200, Train Loss: 3.8984516859054565, Val Loss: 2.926776170730591
Epoch 154/200, Train Loss: 3.991339604059855, Val Loss: 3.1134132146835327
Epoch 155/200, Train Loss: 3.874183098475138, Val Loss: 3.1996090412139893
Epoch 156/200, Train Loss: 3.9108811616897583, Val Loss: 3.0699520111083984
Epoch 157/200, Train Loss: 3.8916012048721313, Val Loss: 3.2716437578201294
Epoch 158/200, Train Loss: 3.892640749613444, Val Loss: 3.2309101819992065
Epoch 159/200, Train Loss: 3.9051060676574707, Val Loss: 3.105372190475464
Epoch 160/200, Train Loss: 3.877245783805847, Val Loss: 3.1612263917922974
Epoch 161/200, Train Loss: 3.917770783106486, Val Loss: 3.049609065055847
Epoch 162/200, Train Loss: 3.967283924420675, Val Loss: 3.050677537918091
Epoch 163/200, Train Loss: 3.963385979334513, Val Loss: 3.1202175617218018
Epoch 164/200, Train Loss: 3.8703755140304565, Val Loss: 3.095482587814331
Epoch 165/200, Train Loss: 3.930053949356079, Val Loss: 3.0912280082702637
Epoch 166/200, Train Loss: 3.958006262779236, Val Loss: 3.1629313230514526
Epoch 167/200, Train Loss: 3.924065907796224, Val Loss: 3.2557923793792725
Epoch 168/200, Train Loss: 3.9913049141565957, Val Loss: 3.1693599224090576
Epoch 169/200, Train Loss: 4.008586327234904, Val Loss: 3.106537342071533
Epoch 170/200, Train Loss: 3.9338483810424805, Val Loss: 3.3792248964309692
Epoch 171/200, Train Loss: 3.9399768908818564, Val Loss: 3.245487689971924
Epoch 172/200, Train Loss: 3.8450914223988852, Val Loss: 3.0350639820098877
Epoch 173/200, Train Loss: 3.9182668129603067, Val Loss: 3.0731329917907715
Epoch 174/200, Train Loss: 4.060050010681152, Val Loss: 3.3417389392852783
Epoch 175/200, Train Loss: 3.8936906258265176, Val Loss: 3.0682926177978516
Epoch 176/200, Train Loss: 3.935524662335714, Val Loss: 2.957606315612793
Epoch 177/200, Train Loss: 3.9184027910232544, Val Loss: 3.2277032136917114
Epoch 178/200, Train Loss: 3.9546287059783936, Val Loss: 3.269200921058655
Epoch 179/200, Train Loss: 3.933972954750061, Val Loss: 3.0312007665634155
Epoch 180/200, Train Loss: 4.006412863731384, Val Loss: 3.0177870988845825
Epoch 181/200, Train Loss: 4.019315679868062, Val Loss: 3.4324917793273926
Epoch 182/200, Train Loss: 3.976349115371704, Val Loss: 3.095134735107422
Epoch 183/200, Train Loss: 3.9399338960647583, Val Loss: 3.028645873069763
Epoch 184/200, Train Loss: 3.909554362297058, Val Loss: 3.1394864320755005
Epoch 185/200, Train Loss: 3.944204847017924, Val Loss: 3.1375609636306763
Epoch 186/200, Train Loss: 3.965526024500529, Val Loss: 3.3116791248321533
Epoch 187/200, Train Loss: 3.95487387975057, Val Loss: 3.1674998998641968
Epoch 188/200, Train Loss: 3.956892490386963, Val Loss: 3.0889739990234375
Epoch 189/200, Train Loss: 3.9042919476826987, Val Loss: 3.2237894535064697
Epoch 190/200, Train Loss: 4.02083404858907, Val Loss: 3.2304171323776245
Epoch 191/200, Train Loss: 4.033280372619629, Val Loss: 2.9411063194274902
Epoch 192/200, Train Loss: 3.926680008570353, Val Loss: 3.147544026374817
Epoch 193/200, Train Loss: 3.9043476581573486, Val Loss: 3.3242844343185425
Epoch 194/200, Train Loss: 3.9608377615610757, Val Loss: 3.1547974348068237
Epoch 195/200, Train Loss: 3.9232988754908242, Val Loss: 2.994195580482483
Epoch 196/200, Train Loss: 3.9626293977101645, Val Loss: 3.1578935384750366
Epoch 197/200, Train Loss: 3.9378694693247476, Val Loss: 3.038115978240967
Epoch 198/200, Train Loss: 3.9251389503479004, Val Loss: 3.138271927833557
Epoch 199/200, Train Loss: 3.9512898524602256, Val Loss: 3.037093758583069
Epoch 200/200, Train Loss: 4.072030981381734, Val Loss: 3.327143430709839"""

output_yolo_scorer = output_yolo_scorer.split("\n")
train_loss = [float(x.split(":")[1].split(",")[0]) for x in output_yolo_scorer]
val_loss = [float(x.split(":")[2]) for x in output_yolo_scorer]

plt.figure(figsize=(10,5))

plt.title("YOLO as Keypoint Detector + Classifier Train/Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.plot(train_loss, label="Train Loss")
plt.plot(val_loss, label="Val Loss")

# %%
output_mmpose_classifier = """Epoch 1/100, Train Loss: 1.1267422338326771, Val Loss: 1.0280291438102722
Epoch 2/100, Train Loss: 1.0550921360651653, Val Loss: 1.0069505870342255
Epoch 3/100, Train Loss: 1.003382295370102, Val Loss: 0.9931492209434509
Epoch 4/100, Train Loss: 0.8632854918638865, Val Loss: 0.9577630162239075
Epoch 5/100, Train Loss: 0.884718120098114, Val Loss: 0.8074680864810944
Epoch 6/100, Train Loss: 0.8697219789028168, Val Loss: 0.9245278239250183
Epoch 7/100, Train Loss: 0.7821349998315176, Val Loss: 0.8422507643699646
Epoch 8/100, Train Loss: 0.7124631106853485, Val Loss: 0.8748502433300018
Epoch 9/100, Train Loss: 0.8135138948758444, Val Loss: 1.053790807723999
Epoch 10/100, Train Loss: 0.6776525874932607, Val Loss: 0.7038167715072632
Epoch 11/100, Train Loss: 0.6799253622690836, Val Loss: 0.8787814378738403
Epoch 12/100, Train Loss: 0.7048626939455668, Val Loss: 0.8341909646987915
Epoch 13/100, Train Loss: 0.6438632756471634, Val Loss: 0.802300900220871
Epoch 14/100, Train Loss: 0.5642996082703272, Val Loss: 0.9225807785987854
Epoch 15/100, Train Loss: 0.6054751773675283, Val Loss: 0.8208970725536346
Epoch 16/100, Train Loss: 0.5452381198604902, Val Loss: 0.7592215538024902
Epoch 17/100, Train Loss: 0.409074326356252, Val Loss: 0.9812422692775726
Epoch 18/100, Train Loss: 0.4935459792613983, Val Loss: 0.9551598429679871
Epoch 19/100, Train Loss: 0.4187127153078715, Val Loss: 0.8778308928012848
Epoch 20/100, Train Loss: 0.6119174907604853, Val Loss: 1.1064251363277435
Epoch 21/100, Train Loss: 0.48733891546726227, Val Loss: 0.868183970451355
Epoch 22/100, Train Loss: 0.5055306280652682, Val Loss: 0.9219909310340881
Epoch 23/100, Train Loss: 0.35974116375048953, Val Loss: 0.9348609447479248
Epoch 24/100, Train Loss: 0.344504751265049, Val Loss: 1.0338411927223206
Epoch 25/100, Train Loss: 0.42116203407446545, Val Loss: 0.9651825129985809
Epoch 26/100, Train Loss: 0.28327517956495285, Val Loss: 0.8832072615623474
Epoch 27/100, Train Loss: 0.3512303829193115, Val Loss: 1.0288946628570557
Epoch 28/100, Train Loss: 0.35741691042979556, Val Loss: 1.048606276512146
Epoch 29/100, Train Loss: 0.3632975121339162, Val Loss: 0.9307582080364227
Epoch 30/100, Train Loss: 0.3535975143313408, Val Loss: 1.0134399235248566
Epoch 31/100, Train Loss: 0.28151985133687657, Val Loss: 0.8277443945407867
Epoch 32/100, Train Loss: 0.29278364529212314, Val Loss: 1.1100775003433228
Epoch 33/100, Train Loss: 0.3170619135101636, Val Loss: 1.0894570350646973
Epoch 34/100, Train Loss: 0.3748695030808449, Val Loss: 0.9930172860622406
Epoch 35/100, Train Loss: 0.3636272996664047, Val Loss: 0.7145630419254303
Epoch 36/100, Train Loss: 0.2661781000594298, Val Loss: 1.0065361559391022
Epoch 37/100, Train Loss: 0.28162793070077896, Val Loss: 0.9424402415752411
Epoch 38/100, Train Loss: 0.22286795328060785, Val Loss: 0.9133186936378479
Epoch 39/100, Train Loss: 0.23196673393249512, Val Loss: 1.0776126384735107
Epoch 40/100, Train Loss: 0.22315195947885513, Val Loss: 0.9845162034034729
Epoch 41/100, Train Loss: 0.261973699554801, Val Loss: 1.332885503768921
Epoch 42/100, Train Loss: 0.27038674677411717, Val Loss: 1.1882006525993347
Epoch 43/100, Train Loss: 0.22372434536616007, Val Loss: 0.8265521824359894
Epoch 44/100, Train Loss: 0.379880723853906, Val Loss: 1.290542185306549
Epoch 45/100, Train Loss: 0.3080941488345464, Val Loss: 1.0694665908813477
Epoch 46/100, Train Loss: 0.2669300337632497, Val Loss: 1.0006482303142548
Epoch 47/100, Train Loss: 0.18227959300080934, Val Loss: 0.7941790223121643
Epoch 48/100, Train Loss: 0.25577669963240623, Val Loss: 0.8787646293640137
Epoch 49/100, Train Loss: 0.3319934618969758, Val Loss: 0.98610720038414
Epoch 50/100, Train Loss: 0.18980880081653595, Val Loss: 1.0931302309036255
Epoch 51/100, Train Loss: 0.28575745473305386, Val Loss: 1.1026718616485596
Epoch 52/100, Train Loss: 0.1981511072566112, Val Loss: 1.0083824694156647
Epoch 53/100, Train Loss: 0.22659868995348612, Val Loss: 1.359753131866455
Epoch 54/100, Train Loss: 0.2585701656838258, Val Loss: 1.1445620357990265
Epoch 55/100, Train Loss: 0.2001828762392203, Val Loss: 0.8240577876567841
Epoch 56/100, Train Loss: 0.18076762681206068, Val Loss: 1.1152477264404297
Epoch 57/100, Train Loss: 0.13010137155652046, Val Loss: 1.1566681265830994
Epoch 58/100, Train Loss: 0.10573507069299619, Val Loss: 1.2170641720294952
Epoch 59/100, Train Loss: 0.231263168156147, Val Loss: 1.2876340746879578
Epoch 60/100, Train Loss: 0.13917439306775728, Val Loss: 1.2391306161880493
Epoch 61/100, Train Loss: 0.1299263279264172, Val Loss: 1.2973305583000183
Epoch 62/100, Train Loss: 0.09433390976240237, Val Loss: 1.5490317344665527
Epoch 63/100, Train Loss: 0.23780466305712858, Val Loss: 1.4170754551887512
Epoch 64/100, Train Loss: 0.0767675129075845, Val Loss: 1.3023077547550201
Epoch 65/100, Train Loss: 0.2151295089473327, Val Loss: 1.3551064431667328
Epoch 66/100, Train Loss: 0.20895545184612274, Val Loss: 1.3750739991664886
Epoch 67/100, Train Loss: 0.199542123824358, Val Loss: 1.7377219796180725
Epoch 68/100, Train Loss: 0.1566654754181703, Val Loss: 1.3580412864685059
Epoch 69/100, Train Loss: 0.18005685384074846, Val Loss: 1.128378003835678
Epoch 70/100, Train Loss: 0.32495954741413396, Val Loss: 1.346963346004486
Epoch 71/100, Train Loss: 0.21931239559004703, Val Loss: 1.5098788738250732
Epoch 72/100, Train Loss: 0.20561613887548447, Val Loss: 1.5206891894340515
Epoch 73/100, Train Loss: 0.2410085635880629, Val Loss: 1.2055014967918396
Epoch 74/100, Train Loss: 0.20446259900927544, Val Loss: 1.2794469594955444
Epoch 75/100, Train Loss: 0.10078312332431476, Val Loss: 1.711912751197815
Epoch 76/100, Train Loss: 0.26358136162161827, Val Loss: 1.2460279762744904
Epoch 77/100, Train Loss: 0.23031126086910567, Val Loss: 1.1496897041797638
Epoch 78/100, Train Loss: 0.23894613608717918, Val Loss: 1.2781697511672974
Epoch 79/100, Train Loss: 0.21735594980418682, Val Loss: 1.297055184841156
Epoch 80/100, Train Loss: 0.1444625984877348, Val Loss: 1.04668527841568
Epoch 81/100, Train Loss: 0.2160740258793036, Val Loss: 1.1121517419815063
Epoch 82/100, Train Loss: 0.10375044991572697, Val Loss: 1.1250893473625183
Epoch 83/100, Train Loss: 0.0994338368376096, Val Loss: 1.3576996624469757
Epoch 84/100, Train Loss: 0.09290711193655928, Val Loss: 1.443607747554779
Epoch 85/100, Train Loss: 0.06023747660219669, Val Loss: 1.6237086653709412
Epoch 86/100, Train Loss: 0.10726175690069795, Val Loss: 2.0741143226623535
Epoch 87/100, Train Loss: 0.1144189047627151, Val Loss: 1.6740447878837585
Epoch 88/100, Train Loss: 0.21558993216603994, Val Loss: 1.1926841139793396
Epoch 89/100, Train Loss: 0.14551274788876375, Val Loss: 1.192821443080902
Epoch 90/100, Train Loss: 0.14907791838049889, Val Loss: 1.3858160376548767
Epoch 91/100, Train Loss: 0.09494557635237773, Val Loss: 1.7355741262435913
Epoch 92/100, Train Loss: 0.24168120262523493, Val Loss: 1.9731906652450562
Epoch 93/100, Train Loss: 0.19468325780083737, Val Loss: 1.7127041816711426
Epoch 94/100, Train Loss: 0.13717830802003542, Val Loss: 1.0656795501708984
Epoch 95/100, Train Loss: 0.167938352872928, Val Loss: 1.100980132818222
Epoch 96/100, Train Loss: 0.09331033953155081, Val Loss: 1.0047382414340973
Epoch 97/100, Train Loss: 0.06446218793280423, Val Loss: 1.0996713042259216
Epoch 98/100, Train Loss: 0.06632685180132587, Val Loss: 1.3807435035705566
Epoch 99/100, Train Loss: 0.05927681767692169, Val Loss: 1.814099669456482
Epoch 100/100, Train Loss: 0.049614562497784696, Val Loss: 1.68706613779068"""
        
output_mmpose_classifier = output_mmpose_classifier.split("\n")
train_loss = [float(x.split(":")[1].split(",")[0]) for x in output_mmpose_classifier]
val_loss = [float(x.split(":")[2]) for x in output_mmpose_classifier]

plt.figure(figsize=(10,5))

plt.title("MMPose as Keypoint Detector + Classifier Train/Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.plot(train_loss, label="Train Loss")
plt.plot(val_loss, label="Val Loss")

# %%
output_mmpose_scorer = """Epoch 1/200, Train Loss: 9.526455769936243, Val Loss: 8.479103803634644
Epoch 2/200, Train Loss: 5.709237972895305, Val Loss: 4.494751811027527
Epoch 3/200, Train Loss: 4.359436949094136, Val Loss: 3.563767671585083
Epoch 4/200, Train Loss: 4.001015196243922, Val Loss: 3.593095858891805
Epoch 5/200, Train Loss: 3.855829894542694, Val Loss: 3.3760560353597007
Epoch 6/200, Train Loss: 3.896317104498545, Val Loss: 3.415220061937968
Epoch 7/200, Train Loss: 3.8380458106597266, Val Loss: 3.676763375600179
Epoch 8/200, Train Loss: 3.979088512559732, Val Loss: 3.5743931929270425
Epoch 9/200, Train Loss: 3.9752684210737548, Val Loss: 3.7093417644500732
Epoch 10/200, Train Loss: 3.8422933171192803, Val Loss: 3.628670573234558
Epoch 11/200, Train Loss: 3.8536414305369058, Val Loss: 3.36616043249766
Epoch 12/200, Train Loss: 3.933162569999695, Val Loss: 3.353443463643392
Epoch 13/200, Train Loss: 3.644179751475652, Val Loss: 3.540842056274414
Epoch 14/200, Train Loss: 3.7993996689716973, Val Loss: 3.608885327974955
Epoch 15/200, Train Loss: 3.817895792424679, Val Loss: 3.403109908103943
Epoch 16/200, Train Loss: 3.8437329878409705, Val Loss: 3.4568497935930886
Epoch 17/200, Train Loss: 3.7232637852430344, Val Loss: 3.4378711581230164
Epoch 18/200, Train Loss: 3.741459416846434, Val Loss: 3.624294877052307
Epoch 19/200, Train Loss: 3.830826885998249, Val Loss: 3.515903353691101
Epoch 20/200, Train Loss: 3.8952825888991356, Val Loss: 3.58139701684316
Epoch 21/200, Train Loss: 3.7928551385800042, Val Loss: 3.5178361535072327
Epoch 22/200, Train Loss: 3.789778284728527, Val Loss: 3.5338414112726846
Epoch 23/200, Train Loss: 3.746736695369085, Val Loss: 3.5914305051167807
Epoch 24/200, Train Loss: 3.76557993888855, Val Loss: 3.2783153851826987
Epoch 25/200, Train Loss: 3.7307520285248756, Val Loss: 3.565005620320638
Epoch 26/200, Train Loss: 3.810151512424151, Val Loss: 3.6181477705637612
Epoch 27/200, Train Loss: 3.672890158991019, Val Loss: 3.5143613616625466
Epoch 28/200, Train Loss: 3.8923073609670005, Val Loss: 3.2815319895744324
Epoch 29/200, Train Loss: 3.876912703116735, Val Loss: 3.4977832237879434
Epoch 30/200, Train Loss: 3.79906531671683, Val Loss: 3.467487096786499
Epoch 31/200, Train Loss: 3.631383031606674, Val Loss: 3.6103914181391397
Epoch 32/200, Train Loss: 3.623401885231336, Val Loss: 3.577288031578064
Epoch 33/200, Train Loss: 3.7962736934423447, Val Loss: 3.4255136251449585
Epoch 34/200, Train Loss: 3.7325715869665146, Val Loss: 3.49854838848114
Epoch 35/200, Train Loss: 3.877065509557724, Val Loss: 3.5090553760528564
Epoch 36/200, Train Loss: 3.768074121326208, Val Loss: 3.281917989253998
Epoch 37/200, Train Loss: 3.759714553753535, Val Loss: 3.342568318049113
Epoch 38/200, Train Loss: 3.8103298246860504, Val Loss: 3.6136040687561035
Epoch 39/200, Train Loss: 3.8652208149433136, Val Loss: 3.6262672344843545
Epoch 40/200, Train Loss: 3.6878885428110757, Val Loss: 3.525180697441101
Epoch 41/200, Train Loss: 3.7983380059401193, Val Loss: 3.4037139415740967
Epoch 42/200, Train Loss: 3.842918778459231, Val Loss: 3.3906115094820657
Epoch 43/200, Train Loss: 3.683973247806231, Val Loss: 3.6419065793355307
Epoch 44/200, Train Loss: 3.7945491621891656, Val Loss: 3.4757887522379556
Epoch 45/200, Train Loss: 3.6206282724936805, Val Loss: 3.4605943163235984
Epoch 46/200, Train Loss: 3.8100445618232093, Val Loss: 3.5056277910868325
Epoch 47/200, Train Loss: 3.881423660864433, Val Loss: 3.650908629099528
Epoch 48/200, Train Loss: 3.6662714083989463, Val Loss: 3.373066524664561
Epoch 49/200, Train Loss: 3.903291908403238, Val Loss: 3.431789139906565
Epoch 50/200, Train Loss: 3.4757370203733444, Val Loss: 3.3315548102060952
Epoch 51/200, Train Loss: 3.9404318798333406, Val Loss: 3.4260714650154114
Epoch 52/200, Train Loss: 3.570900619029999, Val Loss: 3.383375962575277
Epoch 53/200, Train Loss: 3.7793022195498147, Val Loss: 3.4163553516070047
Epoch 54/200, Train Loss: 3.767020493745804, Val Loss: 3.6333277026812234
Epoch 55/200, Train Loss: 3.835660715897878, Val Loss: 3.6622461875279746
Epoch 56/200, Train Loss: 3.7841826577981315, Val Loss: 3.446158309777578
Epoch 57/200, Train Loss: 3.8058521449565887, Val Loss: 3.8421347935994468
Epoch 58/200, Train Loss: 3.8759870268404484, Val Loss: 3.5516456762949624
Epoch 59/200, Train Loss: 3.8178001468380294, Val Loss: 3.4791521231333413
Epoch 60/200, Train Loss: 3.8053151667118073, Val Loss: 3.4212712049484253
Epoch 61/200, Train Loss: 3.8165816167990365, Val Loss: 3.637085239092509
Epoch 62/200, Train Loss: 3.7731676499048867, Val Loss: 3.442032774289449
Epoch 63/200, Train Loss: 3.8541058177749314, Val Loss: 3.4827797015508017
Epoch 64/200, Train Loss: 3.6717114994923272, Val Loss: 3.6433674494425454
Epoch 65/200, Train Loss: 3.8105310375491777, Val Loss: 3.4280335903167725
Epoch 66/200, Train Loss: 3.7783751537402472, Val Loss: 3.726315975189209
Epoch 67/200, Train Loss: 3.766560638944308, Val Loss: 3.375252664089203
Epoch 68/200, Train Loss: 3.8170407712459564, Val Loss: 3.570738593737284
Epoch 69/200, Train Loss: 3.767412399252256, Val Loss: 3.58163313070933
Epoch 70/200, Train Loss: 3.737075457970301, Val Loss: 3.723606824874878
Epoch 71/200, Train Loss: 3.7625914762417474, Val Loss: 3.513469656308492
Epoch 72/200, Train Loss: 3.8013225495815277, Val Loss: 3.6035395860671997
Epoch 73/200, Train Loss: 3.803609942396482, Val Loss: 3.477320830027262
Epoch 74/200, Train Loss: 3.836201091607412, Val Loss: 3.5137268702189126
Epoch 75/200, Train Loss: 3.7709800402323403, Val Loss: 3.6906768878300986
Epoch 76/200, Train Loss: 3.8326192473371825, Val Loss: 3.6521267096201577
Epoch 77/200, Train Loss: 3.779434901972612, Val Loss: 3.4867042899131775
Epoch 78/200, Train Loss: 3.63688396414121, Val Loss: 3.951967636744181
Epoch 79/200, Train Loss: 3.785531833767891, Val Loss: 3.8817888100941977
Epoch 80/200, Train Loss: 3.7382889290650687, Val Loss: 3.6937353213628135
Epoch 81/200, Train Loss: 3.83244260152181, Val Loss: 3.650022824605306
Epoch 82/200, Train Loss: 3.7613302866617837, Val Loss: 3.676322062810262
Epoch 83/200, Train Loss: 3.498381162683169, Val Loss: 3.3480690121650696
Epoch 84/200, Train Loss: 3.9871156414349875, Val Loss: 3.6549862225850425
Epoch 85/200, Train Loss: 3.8189579198757806, Val Loss: 3.39005446434021
Epoch 86/200, Train Loss: 3.7754062116146088, Val Loss: 3.62224813302358
Epoch 87/200, Train Loss: 3.8836457580327988, Val Loss: 3.5681955814361572
Epoch 88/200, Train Loss: 3.7655844539403915, Val Loss: 3.6227833032608032
Epoch 89/200, Train Loss: 3.779407983024915, Val Loss: 3.537614663441976
Epoch 90/200, Train Loss: 3.7259097347656884, Val Loss: 3.619595170021057
Epoch 91/200, Train Loss: 3.8312368045250573, Val Loss: 3.4275975624720254
Epoch 92/200, Train Loss: 3.9077973067760468, Val Loss: 3.6765292485555015
Epoch 93/200, Train Loss: 3.530402402083079, Val Loss: 3.3373236457506814
Epoch 94/200, Train Loss: 3.8948439011971154, Val Loss: 3.4434642791748047
Epoch 95/200, Train Loss: 3.7241075610121093, Val Loss: 3.665325125058492
Epoch 96/200, Train Loss: 3.684810663263003, Val Loss: 3.3932003577550254
Epoch 97/200, Train Loss: 3.798817541450262, Val Loss: 3.494664112726847
Epoch 98/200, Train Loss: 3.681819796562195, Val Loss: 3.466200510660807
Epoch 99/200, Train Loss: 3.6681912392377853, Val Loss: 3.3438173135121665
Epoch 100/200, Train Loss: 3.909578268726667, Val Loss: 3.5298085610071817
Epoch 101/200, Train Loss: 3.8030041605234146, Val Loss: 3.392798642317454
Epoch 102/200, Train Loss: 3.737562914689382, Val Loss: 3.3877790570259094
Epoch 103/200, Train Loss: 3.6285075321793556, Val Loss: 3.6269611914952598
Epoch 104/200, Train Loss: 3.872637172540029, Val Loss: 3.586181879043579
Epoch 105/200, Train Loss: 3.769485349456469, Val Loss: 3.676517963409424
Epoch 106/200, Train Loss: 3.76117305457592, Val Loss: 3.4751281340916953
Epoch 107/200, Train Loss: 3.3519541025161743, Val Loss: 3.8598819573720298
Epoch 108/200, Train Loss: 3.8835862080256143, Val Loss: 3.659370183944702
Epoch 109/200, Train Loss: 3.8759653170903525, Val Loss: 3.6436979373296103
Epoch 110/200, Train Loss: 3.6861077547073364, Val Loss: 3.6253279050191245
Epoch 111/200, Train Loss: 3.616642194489638, Val Loss: 3.4950616359710693
Epoch 112/200, Train Loss: 3.647685925165812, Val Loss: 3.5822612841924033
Epoch 113/200, Train Loss: 3.5872438897689185, Val Loss: 3.45658802986145
Epoch 114/200, Train Loss: 3.655174252887567, Val Loss: 3.5975091457366943
Epoch 115/200, Train Loss: 3.641131510337194, Val Loss: 3.4557934602101645
Epoch 116/200, Train Loss: 3.7977404867609343, Val Loss: 3.6726628144582114
Epoch 117/200, Train Loss: 3.7044735650221505, Val Loss: 3.4866209824879966
Epoch 118/200, Train Loss: 3.990741550922394, Val Loss: 3.6162601312001548
Epoch 119/200, Train Loss: 3.6709858924150467, Val Loss: 3.3955893516540527
Epoch 120/200, Train Loss: 3.9632695466279984, Val Loss: 3.5102532307306924
Epoch 121/200, Train Loss: 3.7097739204764366, Val Loss: 3.421404759089152
Epoch 122/200, Train Loss: 3.767354587713877, Val Loss: 3.6642593145370483
Epoch 123/200, Train Loss: 3.539889022707939, Val Loss: 3.4323115150133767
Epoch 124/200, Train Loss: 3.9262073983748755, Val Loss: 3.6619334618250527
Epoch 125/200, Train Loss: 3.7390367637077966, Val Loss: 3.52738094329834
Epoch 126/200, Train Loss: 3.783857290943464, Val Loss: 3.8195595343907676
Epoch 127/200, Train Loss: 3.86679815252622, Val Loss: 3.461786409219106
Epoch 128/200, Train Loss: 3.8341882725556693, Val Loss: 3.639875610669454
Epoch 129/200, Train Loss: 3.7127204140027366, Val Loss: 3.6106403271357217
Epoch 130/200, Train Loss: 3.8180727089444795, Val Loss: 3.362686892350515
Epoch 131/200, Train Loss: 3.8613330349326134, Val Loss: 3.6496626933415732
Epoch 132/200, Train Loss: 3.7169356644153595, Val Loss: 3.6798702478408813
Epoch 133/200, Train Loss: 3.6507083723942437, Val Loss: 3.5957442919413247
Epoch 134/200, Train Loss: 3.8408179307977357, Val Loss: 3.5958020289738974
Epoch 135/200, Train Loss: 3.6575600480039916, Val Loss: 3.393028418223063
Epoch 136/200, Train Loss: 3.7635758196314177, Val Loss: 3.517268737157186
Epoch 137/200, Train Loss: 3.6652437721689544, Val Loss: 3.6035976012547812
Epoch 138/200, Train Loss: 3.7703196307023368, Val Loss: 3.551069696744283
Epoch 139/200, Train Loss: 3.6178229997555413, Val Loss: 3.501423160235087
Epoch 140/200, Train Loss: 3.808594264090061, Val Loss: 3.8883864879608154
Epoch 141/200, Train Loss: 3.7826706916093826, Val Loss: 3.682006319363912
Epoch 142/200, Train Loss: 3.9370675086975098, Val Loss: 3.597036123275757
Epoch 143/200, Train Loss: 3.768595273296038, Val Loss: 3.5876063108444214
Epoch 144/200, Train Loss: 3.7111846233407655, Val Loss: 3.54632568359375
Epoch 145/200, Train Loss: 3.6477225174506507, Val Loss: 3.5597616036732993
Epoch 146/200, Train Loss: 3.8457909896969795, Val Loss: 3.543527841567993
Epoch 147/200, Train Loss: 3.546968991557757, Val Loss: 3.480231523513794
Epoch 148/200, Train Loss: 3.8353160520394645, Val Loss: 3.549997011820475
Epoch 149/200, Train Loss: 3.8054646154244742, Val Loss: 3.41678394873937
Epoch 150/200, Train Loss: 3.899898961186409, Val Loss: 3.6071934700012207
Epoch 151/200, Train Loss: 3.6902040392160416, Val Loss: 3.3370808164278665
Epoch 152/200, Train Loss: 3.7904518246650696, Val Loss: 3.3501939177513123
Epoch 153/200, Train Loss: 3.962916354338328, Val Loss: 3.358393589655558
Epoch 154/200, Train Loss: 3.8374159385760627, Val Loss: 3.7901442448298135
Epoch 155/200, Train Loss: 3.8304198955496154, Val Loss: 3.5734362999598184
Epoch 156/200, Train Loss: 3.7630142929653325, Val Loss: 3.6619940201441445
Epoch 157/200, Train Loss: 3.846374417344729, Val Loss: 3.761211633682251
Epoch 158/200, Train Loss: 3.5877209529280663, Val Loss: 3.555301388104757
Epoch 159/200, Train Loss: 3.6134684905409813, Val Loss: 3.5703640381495156
Epoch 160/200, Train Loss: 3.664698302745819, Val Loss: 3.7086771726608276
Epoch 161/200, Train Loss: 3.7568013817071915, Val Loss: 3.6009156306584678
Epoch 162/200, Train Loss: 3.6209679072101912, Val Loss: 3.672251025835673
Epoch 163/200, Train Loss: 3.789357533057531, Val Loss: 3.5911802848180137
Epoch 164/200, Train Loss: 3.745441433042288, Val Loss: 3.661561886469523
Epoch 165/200, Train Loss: 3.7583047449588776, Val Loss: 3.5886823733647666
Epoch 166/200, Train Loss: 3.659745549162229, Val Loss: 3.373650312423706
Epoch 167/200, Train Loss: 3.5333233127991357, Val Loss: 3.544177075227102
Epoch 168/200, Train Loss: 3.6852668821811676, Val Loss: 3.6876460711161294
Epoch 169/200, Train Loss: 3.7845411400000253, Val Loss: 3.748913606007894
Epoch 170/200, Train Loss: 3.6400876194238663, Val Loss: 3.7360601822535195
Epoch 171/200, Train Loss: 3.7546136726935706, Val Loss: 3.4721670349438987
Epoch 172/200, Train Loss: 3.783465546866258, Val Loss: 3.5809863408406577
Epoch 173/200, Train Loss: 3.6333778674403825, Val Loss: 3.573975841204325
Epoch 174/200, Train Loss: 3.761202226082484, Val Loss: 3.3467296957969666
Epoch 175/200, Train Loss: 3.8494329899549484, Val Loss: 3.656643549601237
Epoch 176/200, Train Loss: 3.7130846132834754, Val Loss: 3.4364763498306274
Epoch 177/200, Train Loss: 3.618389477332433, Val Loss: 3.365394095579783
Epoch 178/200, Train Loss: 3.7914461667339006, Val Loss: 3.5664836168289185
Epoch 179/200, Train Loss: 3.524475760757923, Val Loss: 3.4926045139630637
Epoch 180/200, Train Loss: 3.6625752051671348, Val Loss: 3.3971226811408997
Epoch 181/200, Train Loss: 3.915093516310056, Val Loss: 3.422331770261129
Epoch 182/200, Train Loss: 3.915540874004364, Val Loss: 3.5180291732152305
Epoch 183/200, Train Loss: 3.781624456246694, Val Loss: 3.46392830212911
Epoch 184/200, Train Loss: 3.5518041203419366, Val Loss: 3.424525022506714
Epoch 185/200, Train Loss: 3.6780914266904197, Val Loss: 3.5156482060750327
Epoch 186/200, Train Loss: 3.47985677421093, Val Loss: 3.665384292602539
Epoch 187/200, Train Loss: 3.696799467007319, Val Loss: 3.409221669038137
Epoch 188/200, Train Loss: 3.785395214955012, Val Loss: 3.549840211868286
Epoch 189/200, Train Loss: 3.6196532944838204, Val Loss: 3.687190810839335
Epoch 190/200, Train Loss: 3.947923685113589, Val Loss: 3.3494086265563965
Epoch 191/200, Train Loss: 3.950966959198316, Val Loss: 3.7685025930404663
Epoch 192/200, Train Loss: 3.718856612841288, Val Loss: 3.344802419344584
Epoch 193/200, Train Loss: 3.7291846374670663, Val Loss: 3.5634345610936484
Epoch 194/200, Train Loss: 3.885875682036082, Val Loss: 3.3841234842936196
Epoch 195/200, Train Loss: 3.6367293099562326, Val Loss: 3.4667793909708657
Epoch 196/200, Train Loss: 3.7052407562732697, Val Loss: 3.475553790728251
Epoch 197/200, Train Loss: 3.798887215554714, Val Loss: 3.536096453666687
Epoch 198/200, Train Loss: 3.685870165626208, Val Loss: 3.554103374481201
Epoch 199/200, Train Loss: 3.8323230544726052, Val Loss: 3.6132231950759888
Epoch 200/200, Train Loss: 3.6710237115621567, Val Loss: 3.674491365750631"""
        
output_mmpose_scorer = output_mmpose_scorer.split("\n")
train_loss = [float(x.split(":")[1].split(",")[0]) for x in output_mmpose_scorer]
val_loss = [float(x.split(":")[2]) for x in output_mmpose_scorer]

plt.figure(figsize=(10,5))

plt.title("MMPose as Keypoint Detector + Scorer Train/Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.plot(train_loss, label="Train Loss")
plt.plot(val_loss, label="Val Loss")

# %%
output_yolo_kp_angle_classifier = """Epoch 1/300, Train Loss: 2.7415448889320126, Val Loss: 1.5030702909697657
Epoch 2/300, Train Loss: 2.3512340996421317, Val Loss: 1.869833820539972
Epoch 3/300, Train Loss: 2.394148216779362, Val Loss: 3.170441850685798
Epoch 4/300, Train Loss: 2.110684498091953, Val Loss: 1.458433894035609
Epoch 5/300, Train Loss: 1.8620224735516546, Val Loss: 1.2545388253486676
Epoch 6/300, Train Loss: 1.6563157844235417, Val Loss: 1.2657645905147428
Epoch 7/300, Train Loss: 2.115943356610124, Val Loss: 1.7639530877704206
Epoch 8/300, Train Loss: 1.7449742970497986, Val Loss: 1.254907101392746
Epoch 9/300, Train Loss: 1.7244137174584657, Val Loss: 1.0872512304264565
Epoch 10/300, Train Loss: 1.2708122685429102, Val Loss: 1.4246499369973722
Epoch 11/300, Train Loss: 1.5925909910056937, Val Loss: 1.2062592273173125
Epoch 12/300, Train Loss: 1.3739116858029248, Val Loss: 1.266965793526691
Epoch 13/300, Train Loss: 1.375488561725146, Val Loss: 1.2025501831718113
Epoch 14/300, Train Loss: 0.9365127871303182, Val Loss: 1.0511256547077843
Epoch 15/300, Train Loss: 1.4607242077883138, Val Loss: 0.976870203309733
Epoch 16/300, Train Loss: 0.9861445549434344, Val Loss: 1.071435828247796
Epoch 17/300, Train Loss: 1.1776034621619864, Val Loss: 1.0205496698617935
Epoch 18/300, Train Loss: 0.9985110677386585, Val Loss: 0.9828964254778364
Epoch 19/300, Train Loss: 1.0973126542019216, Val Loss: 1.0507740093314129
Epoch 20/300, Train Loss: 1.0426201152076062, Val Loss: 1.2004637313277826
Epoch 21/300, Train Loss: 1.0662697295707306, Val Loss: 0.9556659939496414
Epoch 22/300, Train Loss: 0.9948554093998514, Val Loss: 1.0863801629646965
Epoch 23/300, Train Loss: 1.132201692888415, Val Loss: 1.0949801686017409
Epoch 24/300, Train Loss: 1.033631428487991, Val Loss: 0.9743928067062212
Epoch 25/300, Train Loss: 1.0110527105813258, Val Loss: 1.0094179284313451
Epoch 26/300, Train Loss: 0.9300872693720617, Val Loss: 1.0604531055559283
Epoch 27/300, Train Loss: 1.1967551229619666, Val Loss: 1.0216423328156057
Epoch 28/300, Train Loss: 0.8882590559948432, Val Loss: 1.0040806818591512
Epoch 29/300, Train Loss: 0.9718308840927324, Val Loss: 1.082347188954768
Epoch 30/300, Train Loss: 0.8695279341681224, Val Loss: 1.1106098244047684
Epoch 31/300, Train Loss: 0.9980947310987272, Val Loss: 1.2090173792903838
Epoch 32/300, Train Loss: 0.876679018061412, Val Loss: 0.993647272820058
Epoch 33/300, Train Loss: 1.0005497501280747, Val Loss: 0.9699261136676954
Epoch 34/300, Train Loss: 0.8566739675883007, Val Loss: 0.9957563514294832
Epoch 35/300, Train Loss: 0.9407340778724144, Val Loss: 1.0016597677832064
Epoch 36/300, Train Loss: 0.9062085637920781, Val Loss: 0.9995110221207142
Epoch 37/300, Train Loss: 0.8516669056084203, Val Loss: 1.0150928928152374
Epoch 38/300, Train Loss: 0.7978950258246378, Val Loss: 1.1555502876315429
Epoch 39/300, Train Loss: 0.7850148650033302, Val Loss: 1.1075756831661514
Epoch 40/300, Train Loss: 0.800235408809232, Val Loss: 1.0782699209192526
Epoch 41/300, Train Loss: 1.0250514082540145, Val Loss: 1.1644494324598624
Epoch 42/300, Train Loss: 0.7732486607727448, Val Loss: 1.0496183701021515
Epoch 43/300, Train Loss: 0.9159960484438526, Val Loss: 1.080755366700823
Epoch 44/300, Train Loss: 0.7424011286299087, Val Loss: 1.0921624028326378
Epoch 45/300, Train Loss: 0.8356350121927741, Val Loss: 1.1919541948920358
Epoch 46/300, Train Loss: 0.8144326982903294, Val Loss: 1.120725726303847
Epoch 47/300, Train Loss: 0.9261186589707473, Val Loss: 1.0487086788710693
Epoch 48/300, Train Loss: 0.8545589714311064, Val Loss: 1.2185464818435519
Epoch 49/300, Train Loss: 0.7337471071085403, Val Loss: 1.1029560557040183
Epoch 50/300, Train Loss: 0.6866880826811356, Val Loss: 1.0257102529639783
Epoch 51/300, Train Loss: 0.8061690861163171, Val Loss: 1.01789026958463
Epoch 52/300, Train Loss: 0.8602809808192481, Val Loss: 1.1460561515844387
Epoch 53/300, Train Loss: 0.7239376767069763, Val Loss: 1.2258206338054785
Epoch 54/300, Train Loss: 0.777150480386703, Val Loss: 1.169497899265717
Epoch 55/300, Train Loss: 0.876923985378495, Val Loss: 1.250574598149599
Epoch 56/300, Train Loss: 0.6623103814273092, Val Loss: 1.1670680352000762
Epoch 57/300, Train Loss: 0.7517756927488862, Val Loss: 1.135230759786361
Epoch 58/300, Train Loss: 0.7687696813002204, Val Loss: 1.1637656222623975
Epoch 59/300, Train Loss: 0.6172372700438198, Val Loss: 1.2427216347144998
Epoch 60/300, Train Loss: 0.7320586315711568, Val Loss: 1.2547224574702103
Epoch 61/300, Train Loss: 0.5201969391471015, Val Loss: 1.2264628632072583
Epoch 62/300, Train Loss: 0.818069372442551, Val Loss: 1.1605166812710788
Epoch 63/300, Train Loss: 0.782754695812879, Val Loss: 1.2420425004346054
Epoch 64/300, Train Loss: 0.6791877954895761, Val Loss: 1.2640960419945337
Epoch 65/300, Train Loss: 0.6559463767604412, Val Loss: 1.3590753421227892
Epoch 66/300, Train Loss: 0.659651068504898, Val Loss: 1.2667059874890938
Epoch 67/300, Train Loss: 0.5929845334226755, Val Loss: 1.3738885609934146
Epoch 68/300, Train Loss: 0.5751837986255276, Val Loss: 1.3916277756013542
Epoch 69/300, Train Loss: 0.7114672862589175, Val Loss: 1.429508117579288
Epoch 70/300, Train Loss: 0.6486440630031498, Val Loss: 1.6961041237506003
Epoch 71/300, Train Loss: 0.6619124477256264, Val Loss: 1.3039020791576426
Epoch 72/300, Train Loss: 0.5682814068511729, Val Loss: 1.544068286783801
Epoch 73/300, Train Loss: 0.7066081752963854, Val Loss: 1.7523209316435817
Epoch 74/300, Train Loss: 0.7274715034959004, Val Loss: 1.3273221520699419
Epoch 75/300, Train Loss: 0.6026813553572682, Val Loss: 1.4250467576734398
Epoch 76/300, Train Loss: 0.6847733657717503, Val Loss: 1.5641741741792825
Epoch 77/300, Train Loss: 0.6055162183401224, Val Loss: 1.5539514357780875
Epoch 78/300, Train Loss: 0.6485183056278497, Val Loss: 1.4719740586006083
Epoch 79/300, Train Loss: 0.6239950875655172, Val Loss: 1.6539905516749613
Epoch 80/300, Train Loss: 0.5631508831597258, Val Loss: 1.7312027725957981
Epoch 81/300, Train Loss: 0.5450134315825189, Val Loss: 1.68222828254954
Epoch 82/300, Train Loss: 0.6080834935588523, Val Loss: 1.6364670811700583
Epoch 83/300, Train Loss: 0.6094996524880116, Val Loss: 1.9164034902211784
Epoch 84/300, Train Loss: 0.5718921701259917, Val Loss: 1.9040837578207215
Epoch 85/300, Train Loss: 0.6327959287646339, Val Loss: 1.5803412649617277
Epoch 86/300, Train Loss: 0.5830466334189504, Val Loss: 1.6596312861852904
Epoch 87/300, Train Loss: 0.5903505392118715, Val Loss: 1.6745836030890053
Epoch 88/300, Train Loss: 0.5569197099450608, Val Loss: 1.7464850526988733
Epoch 89/300, Train Loss: 0.5796088037714442, Val Loss: 1.6230691544685174
Epoch 90/300, Train Loss: 0.5937142030579277, Val Loss: 1.7192710285241406
Epoch 91/300, Train Loss: 0.5953431445695491, Val Loss: 1.859925596811081
Epoch 92/300, Train Loss: 0.4785765369782134, Val Loss: 1.7815600463397814
Epoch 93/300, Train Loss: 0.4040536296558852, Val Loss: 1.8454549707366033
Epoch 94/300, Train Loss: 0.6443983037635438, Val Loss: 1.8330780416271528
Epoch 95/300, Train Loss: 0.44726176108794646, Val Loss: 1.8451142202387059
Epoch 96/300, Train Loss: 0.4822507797662276, Val Loss: 2.427911669945151
Epoch 97/300, Train Loss: 0.5474428791682373, Val Loss: 1.85951062070885
Epoch 98/300, Train Loss: 0.5618000762939883, Val Loss: 1.8985736324810987
Epoch 99/300, Train Loss: 0.47195840198770184, Val Loss: 1.968527374985965
Epoch 100/300, Train Loss: 0.5255539123847561, Val Loss: 2.1081726596289427
Epoch 101/300, Train Loss: 0.4142072874478967, Val Loss: 2.190285597302927
Epoch 102/300, Train Loss: 0.5564906205876086, Val Loss: 2.11450961063397
Epoch 103/300, Train Loss: 0.47010284197753155, Val Loss: 2.0601779929994612
Epoch 104/300, Train Loss: 0.5692272349753879, Val Loss: 1.9253813004756724
Epoch 105/300, Train Loss: 0.5016970304266721, Val Loss: 1.9414930696578703
Epoch 106/300, Train Loss: 0.47058245361526085, Val Loss: 2.1456502905918033
Epoch 107/300, Train Loss: 0.4267045455096135, Val Loss: 2.1020409712016206
Epoch 108/300, Train Loss: 0.35752140699928264, Val Loss: 2.614692742478076
Epoch 109/300, Train Loss: 0.5448708758331181, Val Loss: 2.3729391228364496
Epoch 110/300, Train Loss: 0.4736460167748329, Val Loss: 2.5410075553730898
Epoch 111/300, Train Loss: 0.4690264577104932, Val Loss: 2.434285630876532
Epoch 112/300, Train Loss: 0.4980444482056244, Val Loss: 2.6060283515275176
Epoch 113/300, Train Loss: 0.479787591226075, Val Loss: 2.364167342023022
Epoch 114/300, Train Loss: 0.4068008889295877, Val Loss: 2.403574336237199
Epoch 115/300, Train Loss: 0.4167552487254009, Val Loss: 2.135591067149463
Epoch 116/300, Train Loss: 0.4802904376994918, Val Loss: 2.311618353644304
Epoch 117/300, Train Loss: 0.43636266754316516, Val Loss: 2.5564296519704315
Epoch 118/300, Train Loss: 0.3859636467198272, Val Loss: 2.785091135503219
Epoch 119/300, Train Loss: 0.37861626206286847, Val Loss: 2.7785246417776426
Epoch 120/300, Train Loss: 0.4238794341269065, Val Loss: 2.5269669480314763
Epoch 121/300, Train Loss: 0.35100790468620263, Val Loss: 2.789128655132466
Epoch 122/300, Train Loss: 0.4395664278634931, Val Loss: 2.5239662228850546
Epoch 123/300, Train Loss: 0.35445060339077133, Val Loss: 2.7319641919876907
Epoch 124/300, Train Loss: 0.3633828538010662, Val Loss: 2.836184981015874
Epoch 125/300, Train Loss: 0.4822969072719172, Val Loss: 2.8320532974422377
Epoch 126/300, Train Loss: 0.44708565714039067, Val Loss: 2.5817289638697245
Epoch 127/300, Train Loss: 0.30565803572480404, Val Loss: 2.557385653986152
Epoch 128/300, Train Loss: 0.3354149402810938, Val Loss: 2.8983151238339717
Epoch 129/300, Train Loss: 0.29627919224837546, Val Loss: 2.7388690453751567
Epoch 130/300, Train Loss: 0.4052791248619524, Val Loss: 2.9393892668734116
Epoch 131/300, Train Loss: 0.4827242318293848, Val Loss: 2.6325220918161314
Epoch 132/300, Train Loss: 0.28570431168772104, Val Loss: 2.6657689425324547
Epoch 133/300, Train Loss: 0.31016416260088614, Val Loss: 2.9620980905854832
Epoch 134/300, Train Loss: 0.3918804180306892, Val Loss: 2.8116739539470013
Epoch 135/300, Train Loss: 0.3673009437552845, Val Loss: 2.525078286103013
Epoch 136/300, Train Loss: 0.4735285449915214, Val Loss: 2.608744814424703
Epoch 137/300, Train Loss: 0.2853262180938729, Val Loss: 3.0232981792676425
Epoch 138/300, Train Loss: 0.3288364899783118, Val Loss: 2.8840650663832594
Epoch 139/300, Train Loss: 0.48080293782982514, Val Loss: 2.5416580487406946
Epoch 140/300, Train Loss: 0.3571501864502351, Val Loss: 2.68996730438717
Epoch 141/300, Train Loss: 0.35410663297156325, Val Loss: 2.561630890583185
Epoch 142/300, Train Loss: 0.3399538893293215, Val Loss: 3.093865575529534
Epoch 143/300, Train Loss: 0.3134562366250837, Val Loss: 3.098740303362517
Epoch 144/300, Train Loss: 0.29405312415473245, Val Loss: 3.4807720216935114
Epoch 145/300, Train Loss: 0.297376631007515, Val Loss: 3.2159105506319996
Epoch 146/300, Train Loss: 0.3250026464451557, Val Loss: 3.133776251145679
Epoch 147/300, Train Loss: 0.3987522585547378, Val Loss: 3.093312040760951
Epoch 148/300, Train Loss: 0.35981170356592035, Val Loss: 3.157354491924786
Epoch 149/300, Train Loss: 0.319287971664805, Val Loss: 3.0780219057898783
Epoch 150/300, Train Loss: 0.26747561428284206, Val Loss: 3.1623106588730994
Epoch 151/300, Train Loss: 0.251645556795809, Val Loss: 3.194696507882327
Epoch 152/300, Train Loss: 0.3123871877696753, Val Loss: 3.1063159166065897
Epoch 153/300, Train Loss: 0.2953241937724483, Val Loss: 3.1496030850052508
Epoch 154/300, Train Loss: 0.2718206396851464, Val Loss: 3.2634791731227026
Epoch 155/300, Train Loss: 0.31129350668278083, Val Loss: 3.7163167689675745
Epoch 156/300, Train Loss: 0.3616148448564551, Val Loss: 3.250433737543695
Epoch 157/300, Train Loss: 0.31071191972472484, Val Loss: 3.2681569859446156
Epoch 158/300, Train Loss: 0.4533646525446819, Val Loss: 2.87977376064974
Epoch 159/300, Train Loss: 0.13453141050576423, Val Loss: 2.8354500111941574
Epoch 160/300, Train Loss: 0.22257557673000009, Val Loss: 3.56295460337487
Epoch 161/300, Train Loss: 0.264453537959141, Val Loss: 3.222041075861932
Epoch 162/300, Train Loss: 0.2817684511722088, Val Loss: 3.28402092393346
Epoch 163/300, Train Loss: 0.3599936903373465, Val Loss: 3.478240120690316
Epoch 164/300, Train Loss: 0.20157994807223525, Val Loss: 3.3505322296974636
Epoch 165/300, Train Loss: 0.20147375113284086, Val Loss: 3.8477537174096694
Epoch 166/300, Train Loss: 0.2834854063751185, Val Loss: 3.590492845778657
Epoch 167/300, Train Loss: 0.18117939132064173, Val Loss: 3.2886842451597382
Epoch 168/300, Train Loss: 0.21069666589647346, Val Loss: 3.735296787257539
Epoch 169/300, Train Loss: 0.1731029265640718, Val Loss: 3.5885187508721845
Epoch 170/300, Train Loss: 0.2942187431363986, Val Loss: 4.193545727023815
Epoch 171/300, Train Loss: 0.2504533633578435, Val Loss: 4.109538305837819
Epoch 172/300, Train Loss: 0.3842542820841204, Val Loss: 3.2695939444111732
Epoch 173/300, Train Loss: 0.22589398912871747, Val Loss: 3.68244633050104
Epoch 174/300, Train Loss: 0.25279239085128546, Val Loss: 3.74165225439071
Epoch 175/300, Train Loss: 0.14126750690567635, Val Loss: 3.8314212077504792
Epoch 176/300, Train Loss: 0.2863071965010965, Val Loss: 4.037688780945483
Epoch 177/300, Train Loss: 0.2937225526440884, Val Loss: 3.8417130808583866
Epoch 178/300, Train Loss: 0.2523024823571314, Val Loss: 3.9276251606921586
Epoch 179/300, Train Loss: 0.1943247074789897, Val Loss: 3.7985849795868094
Epoch 180/300, Train Loss: 0.2833519922336416, Val Loss: 4.000591610210351
Epoch 181/300, Train Loss: 0.19413584113985244, Val Loss: 4.27984317647402
Epoch 182/300, Train Loss: 0.2382522276347567, Val Loss: 3.6403251795715694
Epoch 183/300, Train Loss: 0.2635728803908769, Val Loss: 4.0631153926774655
Epoch 184/300, Train Loss: 0.16794676319129961, Val Loss: 3.7350865597507674
Epoch 185/300, Train Loss: 0.18786489003876236, Val Loss: 3.7692980176655944
Epoch 186/300, Train Loss: 0.19018169343243255, Val Loss: 3.7558588975782343
Epoch 187/300, Train Loss: 0.15030085846386926, Val Loss: 4.167988538411998
Epoch 188/300, Train Loss: 0.2145057443540122, Val Loss: 4.1550867520057615
Epoch 189/300, Train Loss: 0.1640894930705646, Val Loss: 3.753875890200067
Epoch 190/300, Train Loss: 0.09228783594843547, Val Loss: 3.843682414502204
Epoch 191/300, Train Loss: 0.20956422549617293, Val Loss: 4.196455790921549
Epoch 192/300, Train Loss: 0.1943517293793054, Val Loss: 4.034973716108336
Epoch 193/300, Train Loss: 0.16674305577719345, Val Loss: 4.296818956271359
Epoch 194/300, Train Loss: 0.1847873407026521, Val Loss: 4.05654279250682
Epoch 195/300, Train Loss: 0.31714565744048995, Val Loss: 4.19338804678789
Epoch 196/300, Train Loss: 0.15911080933275717, Val Loss: 4.10427151725668
Epoch 197/300, Train Loss: 0.19212307136732049, Val Loss: 3.9984471569786484
Epoch 198/300, Train Loss: 0.16082074521428735, Val Loss: 4.187118137323642
Epoch 199/300, Train Loss: 0.18933025122637445, Val Loss: 4.5075663285185685
Epoch 200/300, Train Loss: 0.12170648293810533, Val Loss: 4.437111305762538
Epoch 201/300, Train Loss: 0.19795867922296187, Val Loss: 4.417482846196356
Epoch 202/300, Train Loss: 0.19546479113404439, Val Loss: 4.679473807380972
Epoch 203/300, Train Loss: 0.1411957876738979, Val Loss: 4.476315124250148
Epoch 204/300, Train Loss: 0.09975199165101849, Val Loss: 4.4608511971545655
Epoch 205/300, Train Loss: 0.25431027022712105, Val Loss: 4.5091241248079
Epoch 206/300, Train Loss: 0.1546688530505369, Val Loss: 4.755163452546838
Epoch 207/300, Train Loss: 0.16033089374970674, Val Loss: 5.005505137469226
Epoch 208/300, Train Loss: 0.14110612103677528, Val Loss: 5.455461216292525
Epoch 209/300, Train Loss: 0.19240427148560743, Val Loss: 5.251280917116298
Epoch 210/300, Train Loss: 0.23068361494659873, Val Loss: 5.055407879497065
Epoch 211/300, Train Loss: 0.19964188251623324, Val Loss: 4.584505818244392
Epoch 212/300, Train Loss: 0.15184698333530855, Val Loss: 4.7961578701749366
Epoch 213/300, Train Loss: 0.11215975006246924, Val Loss: 4.999342296896034
Epoch 214/300, Train Loss: 0.2401261224801435, Val Loss: 4.759599104911499
Epoch 215/300, Train Loss: 0.153124567989546, Val Loss: 4.816038914797031
Epoch 216/300, Train Loss: 0.16878486090338954, Val Loss: 4.797406202830366
Epoch 217/300, Train Loss: 0.06513399583474525, Val Loss: 5.333480294271419
Epoch 218/300, Train Loss: 0.11026030653571192, Val Loss: 5.548667723878699
Epoch 219/300, Train Loss: 0.06449779660291911, Val Loss: 5.0192475545692385
Epoch 220/300, Train Loss: 0.07659133565318907, Val Loss: 5.4387643405124155
Epoch 221/300, Train Loss: 0.07214373444346792, Val Loss: 4.807292406365135
Epoch 222/300, Train Loss: 0.0866209818592648, Val Loss: 6.206505507878438
Epoch 223/300, Train Loss: 0.3014602848558489, Val Loss: 5.681984443356501
Epoch 224/300, Train Loss: 0.14532789100259078, Val Loss: 5.697844695790669
Epoch 225/300, Train Loss: 0.13250390827406217, Val Loss: 5.3958435059991805
Epoch 226/300, Train Loss: 0.12663597361727633, Val Loss: 5.139962369239821
Epoch 227/300, Train Loss: 0.16538058372594377, Val Loss: 5.494745767714884
Epoch 228/300, Train Loss: 0.26385809419234346, Val Loss: 5.450804579187997
Epoch 229/300, Train Loss: 0.24211766969900145, Val Loss: 5.6885366466697525
Epoch 230/300, Train Loss: 0.0628627122003432, Val Loss: 5.815976685466299
Epoch 231/300, Train Loss: 0.06022565668354256, Val Loss: 5.934745487787394
Epoch 232/300, Train Loss: 0.14509520427565578, Val Loss: 5.5824587866361925
Epoch 233/300, Train Loss: 0.14941695352642148, Val Loss: 5.320555472239843
Epoch 234/300, Train Loss: 0.13185046280703455, Val Loss: 5.667951316511963
Epoch 235/300, Train Loss: 0.13206778247475529, Val Loss: 5.991517381175685
Epoch 236/300, Train Loss: 0.11445457796026703, Val Loss: 5.9901715900895445
Epoch 237/300, Train Loss: 0.0994735393283941, Val Loss: 5.713285697495448
Epoch 238/300, Train Loss: 0.04951402254301754, Val Loss: 5.948679296906289
Epoch 239/300, Train Loss: 0.1273773540890931, Val Loss: 6.070422420601932
Epoch 240/300, Train Loss: 0.05909019800894503, Val Loss: 6.487176865136668
Epoch 241/300, Train Loss: 0.19488654958385385, Val Loss: 6.342021003319706
Epoch 242/300, Train Loss: 0.13249481464025412, Val Loss: 6.497778352390486
Epoch 243/300, Train Loss: 0.10564002091197774, Val Loss: 6.0432919796956055
Epoch 244/300, Train Loss: 0.03679154527107987, Val Loss: 6.142413047329428
Epoch 245/300, Train Loss: 0.11763703510116062, Val Loss: 6.373808186865594
Epoch 246/300, Train Loss: 0.2242748410838399, Val Loss: 6.442047128515627
Epoch 247/300, Train Loss: 0.06988974123179752, Val Loss: 6.8851017350857315
Epoch 248/300, Train Loss: 0.11959709860438891, Val Loss: 7.1363906192228646
Epoch 249/300, Train Loss: 0.05106123167148665, Val Loss: 7.102951248459839
Epoch 250/300, Train Loss: 0.13620997739119076, Val Loss: 6.62474783801577
Epoch 251/300, Train Loss: 0.18837332364437173, Val Loss: 6.597707488289668
Epoch 252/300, Train Loss: 0.15976065562185138, Val Loss: 6.751733078611124
Epoch 253/300, Train Loss: 0.06577575276287499, Val Loss: 6.6153027515696285
Epoch 254/300, Train Loss: 0.06465511986435839, Val Loss: 5.906521972537298
Epoch 255/300, Train Loss: 0.07009551703924742, Val Loss: 6.036691403866217
Epoch 256/300, Train Loss: 0.0838192813394344, Val Loss: 6.216737978726166
Epoch 257/300, Train Loss: 0.1803791582619422, Val Loss: 6.498910940223719
Epoch 258/300, Train Loss: 0.11589840208910941, Val Loss: 6.700397233357228
Epoch 259/300, Train Loss: 0.13383358811670465, Val Loss: 6.341272748763557
Epoch 260/300, Train Loss: 0.03957967834945195, Val Loss: 6.069122083318175
Epoch 261/300, Train Loss: 0.14074597400568942, Val Loss: 6.44290734265556
Epoch 262/300, Train Loss: 0.15033728833565552, Val Loss: 6.202781389587424
Epoch 263/300, Train Loss: 0.1775950930465478, Val Loss: 5.678832898798409
Epoch 264/300, Train Loss: 0.04132104293635495, Val Loss: 6.17669320373661
Epoch 265/300, Train Loss: 0.11672742304759269, Val Loss: 6.610408266601265
Epoch 266/300, Train Loss: 0.10002446130227455, Val Loss: 6.488660389962374
Epoch 267/300, Train Loss: 0.05351480471113916, Val Loss: 7.300851513211495
Epoch 268/300, Train Loss: 0.20935687200161823, Val Loss: 6.553689282711431
Epoch 269/300, Train Loss: 0.08516463366337139, Val Loss: 6.533650216929939
Epoch 270/300, Train Loss: 0.1301721208954204, Val Loss: 5.904815738282215
Epoch 271/300, Train Loss: 0.08016790316114962, Val Loss: 6.565799154346275
Epoch 272/300, Train Loss: 0.0935907343149242, Val Loss: 6.2970056579164835
Epoch 273/300, Train Loss: 0.24074810422319615, Val Loss: 7.166144845703536
Epoch 274/300, Train Loss: 0.04792595098579659, Val Loss: 7.665808785301835
Epoch 275/300, Train Loss: 0.06657882044593905, Val Loss: 7.237380898091941
Epoch 276/300, Train Loss: 0.04453724439223102, Val Loss: 7.424677902427704
Epoch 277/300, Train Loss: 0.07302737586697136, Val Loss: 7.580543535113659
Epoch 278/300, Train Loss: 0.03606475931454717, Val Loss: 6.933117437216869
Epoch 279/300, Train Loss: 0.05271135739974532, Val Loss: 7.078490120986388
Epoch 280/300, Train Loss: 0.05173365268230583, Val Loss: 6.433308628229611
Epoch 281/300, Train Loss: 0.08389394767263121, Val Loss: 7.433772098070572
Epoch 282/300, Train Loss: 0.11827915803189648, Val Loss: 7.549561892190562
Epoch 283/300, Train Loss: 0.04090054931141988, Val Loss: 7.785900343599716
Epoch 284/300, Train Loss: 0.11835865188741336, Val Loss: 7.577383354305385
Epoch 285/300, Train Loss: 0.056063710081156536, Val Loss: 7.274998845329873
Epoch 286/300, Train Loss: 0.1620648274219318, Val Loss: 6.872838170181596
Epoch 287/300, Train Loss: 0.05071392360798939, Val Loss: 6.844125758289623
Epoch 288/300, Train Loss: 0.020942076995668097, Val Loss: 7.277533669386603
Epoch 289/300, Train Loss: 0.029486816055498143, Val Loss: 6.892340907558753
Epoch 290/300, Train Loss: 0.12705181802507962, Val Loss: 6.945786714852448
Epoch 291/300, Train Loss: 0.18960281980034135, Val Loss: 7.8450117694432775
Epoch 292/300, Train Loss: 0.09582763440073419, Val Loss: 8.28955164614498
Epoch 293/300, Train Loss: 0.03751040177258034, Val Loss: 7.718199396662857
Epoch 294/300, Train Loss: 0.09016990892657392, Val Loss: 7.527273745837858
Epoch 295/300, Train Loss: 0.05218309192613707, Val Loss: 8.60988839217664
Epoch 296/300, Train Loss: 0.09615265478480456, Val Loss: 7.175392981198229
Epoch 297/300, Train Loss: 0.03637828921947922, Val Loss: 7.26742380914663
Epoch 298/300, Train Loss: 0.03700735804036771, Val Loss: 7.437423147817912
Epoch 299/300, Train Loss: 0.09949459546414562, Val Loss: 7.6740490277095335
Epoch 300/300, Train Loss: 0.04386297160677896, Val Loss: 7.043663709929967"""
        
output_yolo_kp_angle_classifier = output_yolo_kp_angle_classifier.split("\n")
train_loss = [float(x.split(":")[1].split(",")[0]) for x in output_yolo_kp_angle_classifier]
val_loss = [float(x.split(":")[2]) for x in output_yolo_kp_angle_classifier]

plt.figure(figsize=(10,5))

plt.title("YOLO as Keypoint Detector with Calculated Angles + Classifier Train/Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.plot(train_loss, label="Train Loss")
plt.plot(val_loss, label="Val Loss")

# %%
output_yolo_kp_angle_scorer = """Epoch 1/200, Train Loss: 19.52698238690694, Val Loss: 10.80599594116211
Epoch 2/200, Train Loss: 9.191616614659628, Val Loss: 3.209649443626404
Epoch 3/200, Train Loss: 6.413087526957194, Val Loss: 6.201873540878296
Epoch 4/200, Train Loss: 6.03652040163676, Val Loss: 6.067053556442261
Epoch 5/200, Train Loss: 5.125003337860107, Val Loss: 4.789948225021362
Epoch 6/200, Train Loss: 4.9311033089955645, Val Loss: 6.245456218719482
Epoch 7/200, Train Loss: 5.064075072606404, Val Loss: 7.221912622451782
Epoch 8/200, Train Loss: 4.8594701290130615, Val Loss: 5.4642064571380615
Epoch 9/200, Train Loss: 4.851705074310303, Val Loss: 6.487718343734741
Epoch 10/200, Train Loss: 4.686939994494121, Val Loss: 7.188339948654175
Epoch 11/200, Train Loss: 4.859037399291992, Val Loss: 6.804493427276611
Epoch 12/200, Train Loss: 4.512417793273926, Val Loss: 6.932713747024536
Epoch 13/200, Train Loss: 4.4545789162317915, Val Loss: 6.266381740570068
Epoch 14/200, Train Loss: 4.4712783098220825, Val Loss: 6.5986716747283936
Epoch 15/200, Train Loss: 4.526876091957092, Val Loss: 7.080205678939819
Epoch 16/200, Train Loss: 4.645954171816508, Val Loss: 6.6445982456207275
Epoch 17/200, Train Loss: 4.420384049415588, Val Loss: 6.593350410461426
Epoch 18/200, Train Loss: 4.508812665939331, Val Loss: 6.752227306365967
Epoch 19/200, Train Loss: 4.516736149787903, Val Loss: 5.996522426605225
Epoch 20/200, Train Loss: 4.319928844769795, Val Loss: 6.789256811141968
Epoch 21/200, Train Loss: 4.316612561543782, Val Loss: 7.642825603485107
Epoch 22/200, Train Loss: 4.3876214027404785, Val Loss: 6.779022932052612
Epoch 23/200, Train Loss: 4.255369504292806, Val Loss: 6.245836496353149
Epoch 24/200, Train Loss: 4.439236044883728, Val Loss: 7.061020374298096
Epoch 25/200, Train Loss: 4.345295985539754, Val Loss: 7.885088920593262
Epoch 26/200, Train Loss: 4.293999632199605, Val Loss: 6.948625326156616
Epoch 27/200, Train Loss: 4.373022158940633, Val Loss: 7.164608478546143
Epoch 28/200, Train Loss: 4.369239290555318, Val Loss: 7.058751821517944
Epoch 29/200, Train Loss: 4.231057008107503, Val Loss: 6.696130037307739
Epoch 30/200, Train Loss: 4.297124743461609, Val Loss: 6.727347373962402
Epoch 31/200, Train Loss: 4.253760417302449, Val Loss: 6.357110023498535
Epoch 32/200, Train Loss: 4.299635728200276, Val Loss: 6.468590497970581
Epoch 33/200, Train Loss: 4.35140045483907, Val Loss: 6.859468698501587
Epoch 34/200, Train Loss: 4.2391393184661865, Val Loss: 6.430889844894409
Epoch 35/200, Train Loss: 4.175821145375569, Val Loss: 6.43309760093689
Epoch 36/200, Train Loss: 4.091822147369385, Val Loss: 6.478345632553101
Epoch 37/200, Train Loss: 4.299161195755005, Val Loss: 7.479987382888794
Epoch 38/200, Train Loss: 4.306155403455098, Val Loss: 6.777063369750977
Epoch 39/200, Train Loss: 4.3523731629053755, Val Loss: 6.724440813064575
Epoch 40/200, Train Loss: 4.1772860288619995, Val Loss: 7.115976095199585
Epoch 41/200, Train Loss: 4.193075497945149, Val Loss: 6.6266772747039795
Epoch 42/200, Train Loss: 4.128275434176127, Val Loss: 6.2016565799713135
Epoch 43/200, Train Loss: 4.285281697909038, Val Loss: 6.874053239822388
Epoch 44/200, Train Loss: 4.234079082806905, Val Loss: 6.830281496047974
Epoch 45/200, Train Loss: 4.216843883196513, Val Loss: 6.094362735748291
Epoch 46/200, Train Loss: 4.109288652737935, Val Loss: 6.541409969329834
Epoch 47/200, Train Loss: 4.1575567324956255, Val Loss: 6.2519612312316895
Epoch 48/200, Train Loss: 4.193061749140422, Val Loss: 6.995781183242798
Epoch 49/200, Train Loss: 4.276430328687032, Val Loss: 5.88971209526062
Epoch 50/200, Train Loss: 4.140629013379415, Val Loss: 6.555201530456543
Epoch 51/200, Train Loss: 4.078378160794576, Val Loss: 6.906909704208374
Epoch 52/200, Train Loss: 4.21662437915802, Val Loss: 5.828714609146118
Epoch 53/200, Train Loss: 4.100795308748881, Val Loss: 6.0370049476623535
Epoch 54/200, Train Loss: 4.166208783785502, Val Loss: 6.3983564376831055
Epoch 55/200, Train Loss: 4.129346052805583, Val Loss: 6.291213750839233
Epoch 56/200, Train Loss: 4.186227202415466, Val Loss: 6.393732309341431
Epoch 57/200, Train Loss: 4.2643595933914185, Val Loss: 6.1867358684539795
Epoch 58/200, Train Loss: 4.0536917845408125, Val Loss: 6.856560945510864
Epoch 59/200, Train Loss: 4.202036142349243, Val Loss: 6.270043849945068
Epoch 60/200, Train Loss: 4.011082649230957, Val Loss: 6.663916826248169
Epoch 61/200, Train Loss: 4.149072090784709, Val Loss: 6.5810227394104
Epoch 62/200, Train Loss: 4.0908741156260175, Val Loss: 6.423683166503906
Epoch 63/200, Train Loss: 4.06702967484792, Val Loss: 5.959707021713257
Epoch 64/200, Train Loss: 4.314011414845784, Val Loss: 6.763195037841797
Epoch 65/200, Train Loss: 4.19004225730896, Val Loss: 6.5478620529174805
Epoch 66/200, Train Loss: 4.036785324414571, Val Loss: 6.380395412445068
Epoch 67/200, Train Loss: 4.152458866437276, Val Loss: 6.683600187301636
Epoch 68/200, Train Loss: 4.033236543337504, Val Loss: 6.05401086807251
Epoch 69/200, Train Loss: 4.037164211273193, Val Loss: 5.74842095375061
Epoch 70/200, Train Loss: 4.0511118570963545, Val Loss: 5.537421226501465
Epoch 71/200, Train Loss: 4.141341686248779, Val Loss: 6.023462533950806
Epoch 72/200, Train Loss: 4.058939099311829, Val Loss: 6.315929651260376
Epoch 73/200, Train Loss: 4.1326033274332685, Val Loss: 6.063656806945801
Epoch 74/200, Train Loss: 4.019203583399455, Val Loss: 6.1794116497039795
Epoch 75/200, Train Loss: 4.031225840250651, Val Loss: 6.263180732727051
Epoch 76/200, Train Loss: 4.164955337842305, Val Loss: 5.437964200973511
Epoch 77/200, Train Loss: 4.024729251861572, Val Loss: 6.1932172775268555
Epoch 78/200, Train Loss: 4.228835503260295, Val Loss: 6.921904563903809
Epoch 79/200, Train Loss: 4.054211338361104, Val Loss: 5.773808240890503
Epoch 80/200, Train Loss: 4.14016071955363, Val Loss: 5.989696025848389
Epoch 81/200, Train Loss: 4.015066822369893, Val Loss: 6.291577577590942
Epoch 82/200, Train Loss: 4.13933797677358, Val Loss: 6.011595964431763
Epoch 83/200, Train Loss: 4.142965793609619, Val Loss: 5.891213417053223
Epoch 84/200, Train Loss: 3.986124555269877, Val Loss: 5.763123989105225
Epoch 85/200, Train Loss: 4.050522883733113, Val Loss: 6.269215822219849
Epoch 86/200, Train Loss: 4.114778439203898, Val Loss: 6.010471343994141
Epoch 87/200, Train Loss: 4.105368415514628, Val Loss: 5.998415231704712
Epoch 88/200, Train Loss: 3.9321302572886148, Val Loss: 5.997199773788452
Epoch 89/200, Train Loss: 4.050057848294576, Val Loss: 6.134215593338013
Epoch 90/200, Train Loss: 4.174620429674785, Val Loss: 5.925726652145386
Epoch 91/200, Train Loss: 4.269124070803325, Val Loss: 6.680165529251099
Epoch 92/200, Train Loss: 4.186689019203186, Val Loss: 5.474282503128052
Epoch 93/200, Train Loss: 3.9995099703470864, Val Loss: 5.912574052810669
Epoch 94/200, Train Loss: 4.074166099230449, Val Loss: 6.246272325515747
Epoch 95/200, Train Loss: 4.094493746757507, Val Loss: 6.0890374183654785
Epoch 96/200, Train Loss: 4.109251022338867, Val Loss: 5.5586512088775635
Epoch 97/200, Train Loss: 4.152320822079976, Val Loss: 6.114441394805908
Epoch 98/200, Train Loss: 3.9800594250361123, Val Loss: 5.7748329639434814
Epoch 99/200, Train Loss: 3.976275086402893, Val Loss: 5.210310220718384
Epoch 100/200, Train Loss: 4.119267304738362, Val Loss: 5.691093444824219
Epoch 101/200, Train Loss: 4.077335238456726, Val Loss: 6.176124334335327
Epoch 102/200, Train Loss: 3.9667797485987344, Val Loss: 5.884374380111694
Epoch 103/200, Train Loss: 4.027426203091939, Val Loss: 5.856847286224365
Epoch 104/200, Train Loss: 4.109718124071757, Val Loss: 5.976802587509155
Epoch 105/200, Train Loss: 4.112247586250305, Val Loss: 5.385363578796387
Epoch 106/200, Train Loss: 3.990128000577291, Val Loss: 5.658891201019287
Epoch 107/200, Train Loss: 3.993820230166117, Val Loss: 5.99787163734436
Epoch 108/200, Train Loss: 3.9928818941116333, Val Loss: 5.842050552368164
Epoch 109/200, Train Loss: 4.074708739916484, Val Loss: 5.67204475402832
Epoch 110/200, Train Loss: 3.9943789641062417, Val Loss: 5.657705783843994
Epoch 111/200, Train Loss: 4.140514850616455, Val Loss: 5.541891574859619
Epoch 112/200, Train Loss: 3.9938465356826782, Val Loss: 6.132702827453613
Epoch 113/200, Train Loss: 4.033350825309753, Val Loss: 6.0526347160339355
Epoch 114/200, Train Loss: 4.093377749125163, Val Loss: 5.694509029388428
Epoch 115/200, Train Loss: 3.9878760973612466, Val Loss: 6.195200443267822
Epoch 116/200, Train Loss: 4.11173955599467, Val Loss: 6.074878931045532
Epoch 117/200, Train Loss: 4.142850915590922, Val Loss: 5.190885305404663
Epoch 118/200, Train Loss: 4.027684370676677, Val Loss: 5.586101293563843
Epoch 119/200, Train Loss: 4.13421356678009, Val Loss: 5.921136140823364
Epoch 120/200, Train Loss: 4.09715207417806, Val Loss: 6.6153175830841064
Epoch 121/200, Train Loss: 4.131600578625997, Val Loss: 5.232991933822632
Epoch 122/200, Train Loss: 4.05190642674764, Val Loss: 5.658243417739868
Epoch 123/200, Train Loss: 4.017125646273295, Val Loss: 6.552492380142212
Epoch 124/200, Train Loss: 4.230403224627177, Val Loss: 5.705751895904541
Epoch 125/200, Train Loss: 4.282992521921794, Val Loss: 5.665987014770508
Epoch 126/200, Train Loss: 3.996171712875366, Val Loss: 5.877511024475098
Epoch 127/200, Train Loss: 4.0597918430964155, Val Loss: 6.0496985912323
Epoch 128/200, Train Loss: 4.078287084897359, Val Loss: 4.9557578563690186
Epoch 129/200, Train Loss: 4.120550155639648, Val Loss: 5.592641830444336
Epoch 130/200, Train Loss: 4.048260688781738, Val Loss: 5.431744813919067
Epoch 131/200, Train Loss: 4.095754265785217, Val Loss: 5.8704235553741455
Epoch 132/200, Train Loss: 4.001321077346802, Val Loss: 5.849055528640747
Epoch 133/200, Train Loss: 4.115197459856669, Val Loss: 5.3709797859191895
Epoch 134/200, Train Loss: 4.043294429779053, Val Loss: 5.981903553009033
Epoch 135/200, Train Loss: 4.11702028910319, Val Loss: 5.94464373588562
Epoch 136/200, Train Loss: 4.0174200137456255, Val Loss: 5.45645809173584
Epoch 137/200, Train Loss: 4.011149962743123, Val Loss: 6.046992540359497
Epoch 138/200, Train Loss: 3.991654952367147, Val Loss: 5.64821720123291
Epoch 139/200, Train Loss: 4.030932505925496, Val Loss: 5.481761932373047
Epoch 140/200, Train Loss: 3.9916393756866455, Val Loss: 5.92230486869812
Epoch 141/200, Train Loss: 3.9672585328420005, Val Loss: 5.974685430526733
Epoch 142/200, Train Loss: 3.9291773239771524, Val Loss: 5.792937517166138
Epoch 143/200, Train Loss: 4.105036656061809, Val Loss: 5.583316326141357
Epoch 144/200, Train Loss: 3.9387560288111367, Val Loss: 5.3752946853637695
Epoch 145/200, Train Loss: 4.021330555280049, Val Loss: 6.078016757965088
Epoch 146/200, Train Loss: 4.108735879262288, Val Loss: 5.600298881530762
Epoch 147/200, Train Loss: 4.064799904823303, Val Loss: 5.274227857589722
Epoch 148/200, Train Loss: 3.980383515357971, Val Loss: 5.607201099395752
Epoch 149/200, Train Loss: 3.9736894369125366, Val Loss: 5.90966796875
Epoch 150/200, Train Loss: 4.126784761746724, Val Loss: 5.36040997505188
Epoch 151/200, Train Loss: 4.146170377731323, Val Loss: 5.838120698928833
Epoch 152/200, Train Loss: 3.984068989753723, Val Loss: 5.397672891616821
Epoch 153/200, Train Loss: 3.9624470869700112, Val Loss: 4.974993705749512
Epoch 154/200, Train Loss: 3.979877988497416, Val Loss: 5.812142372131348
Epoch 155/200, Train Loss: 4.014947533607483, Val Loss: 5.583895921707153
Epoch 156/200, Train Loss: 4.002417842547099, Val Loss: 5.188433647155762
Epoch 157/200, Train Loss: 3.9638886054356894, Val Loss: 5.732889652252197
Epoch 158/200, Train Loss: 4.005273898442586, Val Loss: 6.040917634963989
Epoch 159/200, Train Loss: 4.103217085202535, Val Loss: 5.3133485317230225
Epoch 160/200, Train Loss: 4.021339376767476, Val Loss: 5.714968919754028
Epoch 161/200, Train Loss: 4.135601838429769, Val Loss: 6.2235729694366455
Epoch 162/200, Train Loss: 4.032009522120158, Val Loss: 5.381975889205933
Epoch 163/200, Train Loss: 4.01110053062439, Val Loss: 5.458468437194824
Epoch 164/200, Train Loss: 3.902358333269755, Val Loss: 6.129000186920166
Epoch 165/200, Train Loss: 3.9437777201334634, Val Loss: 5.76550030708313
Epoch 166/200, Train Loss: 3.9833809534708657, Val Loss: 5.251676559448242
Epoch 167/200, Train Loss: 4.0232001940409345, Val Loss: 5.484290838241577
Epoch 168/200, Train Loss: 3.9953150749206543, Val Loss: 5.906623840332031
Epoch 169/200, Train Loss: 4.278180360794067, Val Loss: 6.051311492919922
Epoch 170/200, Train Loss: 3.9572827021280923, Val Loss: 5.172696828842163
Epoch 171/200, Train Loss: 4.0330807367960615, Val Loss: 5.8512022495269775
Epoch 172/200, Train Loss: 3.9785006443659463, Val Loss: 5.904833555221558
Epoch 173/200, Train Loss: 4.037681698799133, Val Loss: 5.568234920501709
Epoch 174/200, Train Loss: 3.9359371662139893, Val Loss: 5.52973484992981
Epoch 175/200, Train Loss: 4.140296618143718, Val Loss: 5.286177396774292
Epoch 176/200, Train Loss: 4.207776109377543, Val Loss: 6.550422191619873
Epoch 177/200, Train Loss: 4.091326793034871, Val Loss: 5.5638086795806885
Epoch 178/200, Train Loss: 4.1812424659729, Val Loss: 5.399933815002441
Epoch 179/200, Train Loss: 4.073634187380473, Val Loss: 6.006758451461792
Epoch 180/200, Train Loss: 4.01405652364095, Val Loss: 5.3880860805511475
Epoch 181/200, Train Loss: 3.9846580823262534, Val Loss: 5.459086179733276
Epoch 182/200, Train Loss: 4.011220494906108, Val Loss: 5.758375406265259
Epoch 183/200, Train Loss: 4.053437312444051, Val Loss: 5.233500242233276
Epoch 184/200, Train Loss: 4.0242840051651, Val Loss: 6.032402992248535
Epoch 185/200, Train Loss: 3.975215514500936, Val Loss: 5.764335870742798
Epoch 186/200, Train Loss: 3.933690865834554, Val Loss: 5.536867380142212
Epoch 187/200, Train Loss: 4.057160099347432, Val Loss: 5.48572039604187
Epoch 188/200, Train Loss: 4.003525336583455, Val Loss: 6.265676736831665
Epoch 189/200, Train Loss: 4.103461464246114, Val Loss: 6.302495718002319
Epoch 190/200, Train Loss: 4.150445858637492, Val Loss: 5.05703330039978
Epoch 191/200, Train Loss: 4.001520395278931, Val Loss: 5.795716285705566
Epoch 192/200, Train Loss: 4.010133743286133, Val Loss: 5.331615209579468
Epoch 193/200, Train Loss: 4.0747973918914795, Val Loss: 5.834016561508179
Epoch 194/200, Train Loss: 3.9866373936335244, Val Loss: 5.213129758834839
Epoch 195/200, Train Loss: 3.990683913230896, Val Loss: 5.707282066345215
Epoch 196/200, Train Loss: 4.027395049730937, Val Loss: 5.676084280014038
Epoch 197/200, Train Loss: 4.0345427592595415, Val Loss: 5.780486345291138
Epoch 198/200, Train Loss: 4.045169870058696, Val Loss: 5.744914531707764
Epoch 199/200, Train Loss: 4.021007617314656, Val Loss: 5.862597703933716
Epoch 200/200, Train Loss: 4.076933026313782, Val Loss: 5.319453716278076"""

output_yolo_kp_angle_classifier = output_yolo_kp_angle_classifier.split("\n")
train_loss = [float(x.split(":")[1].split(",")[0]) for x in output_yolo_kp_angle_classifier]
val_loss = [float(x.split(":")[2]) for x in output_yolo_kp_angle_classifier]

plt.figure(figsize=(10,5))

plt.title("YOLO as Keypoint Detector + Calculated Angles with Keypoints for Scorer Train/Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.plot(train_loss, label="Train Loss")
plt.plot(val_loss, label="Val Loss")

# %%
output_yolo_finetuning_classifier = """Epoch 1/100, Loss: 596.3466152758975
        Epoch 2/100, Loss: 413.26326055903183
        Epoch 3/100, Loss: 291.17308353305253
        Epoch 4/100, Loss: 210.93619030996373
        Epoch 5/100, Loss: 108.99830118081935
        Epoch 6/100, Loss: 32.79658967213463
        Epoch 7/100, Loss: 1.1482165157794952
        Epoch 8/100, Loss: 1.0954126031775224
        Epoch 9/100, Loss: 1.0951145347795987
        Epoch 10/100, Loss: 1.0945170364881818
        Epoch 11/100, Loss: 1.0938329106882998
        Epoch 12/100, Loss: 2.3863540304776842
        Epoch 13/100, Loss: 1.0935362953888743
        Epoch 14/100, Loss: 1.093220325520164
        Epoch 15/100, Loss: 1.092881841408579
        Epoch 16/100, Loss: 1.0925839348843223
        Epoch 17/100, Loss: 1.0924056266483508
        Epoch 18/100, Loss: 1.0923102265910098
        Epoch 19/100, Loss: 1.0922410839482357
        Epoch 20/100, Loss: 1.0924587965011596
        Epoch 21/100, Loss: 1.091531249096519
        Epoch 22/100, Loss: 1.091374875369825
        Epoch 23/100, Loss: 1.0911536605734573
        Epoch 24/100, Loss: 1.0913041478709171
        Epoch 25/100, Loss: 1.0909645419371756
        Epoch 26/100, Loss: 1.0906797020058883
        Epoch 27/100, Loss: 1.0904540770932247
        Epoch 28/100, Loss: 1.0905370574248465
        Epoch 29/100, Loss: 1.0907651449504652
        Epoch 30/100, Loss: 1.0900208812010916
        Epoch 31/100, Loss: 1.0900680378863685
        Epoch 32/100, Loss: 1.0900025581058703
        Epoch 33/100, Loss: 1.0900650626734683
        Epoch 34/100, Loss: 1.0898285250914723
        Epoch 35/100, Loss: 1.0896445117498699
        Epoch 36/100, Loss: 1.0897471139305517
        Epoch 37/100, Loss: 1.089700094022249
        Epoch 38/100, Loss: 1.089618578710054
        Epoch 39/100, Loss: 1.0893570642722281
        Epoch 40/100, Loss: 1.0897135420849449
        Epoch 41/100, Loss: 1.0894870243574444
        Epoch 42/100, Loss: 1.089385567840777
        Epoch 43/100, Loss: 1.0891775833932977
        Epoch 44/100, Loss: 1.0894088337295933
        Epoch 45/100, Loss: 1.0896284442198905
        Epoch 46/100, Loss: 1.0895136500659741
        Epoch 47/100, Loss: 1.0889637896889135
        Epoch 48/100, Loss: 1.0886209205577249
        Epoch 49/100, Loss: 1.089280058208265
        Epoch 50/100, Loss: 1.0887356174619574
        Epoch 51/100, Loss: 1.0886149663674205
        Epoch 52/100, Loss: 1.0888869781243173
        Epoch 53/100, Loss: 1.0889366777319658
        Epoch 54/100, Loss: 1.0892220396744579
        Epoch 55/100, Loss: 1.0887015530937596
        Epoch 56/100, Loss: 1.0884976462314004
        Epoch 57/100, Loss: 1.0886601059060348
        Epoch 58/100, Loss: 1.089114056762896
        Epoch 59/100, Loss: 1.0883119382356343
        Epoch 60/100, Loss: 1.0889366927899813
        Epoch 61/100, Loss: 1.0889121607730263
        Epoch 62/100, Loss: 1.0886799304108872
        Epoch 63/100, Loss: 1.0888768070622494
        Epoch 64/100, Loss: 1.0885006754021895
        Epoch 65/100, Loss: 1.0886737014117993
        Epoch 66/100, Loss: 1.0885996768349095
        Epoch 67/100, Loss: 1.08832585811615
        Epoch 68/100, Loss: 1.0889891630724857
        Epoch 69/100, Loss: 1.08819828096189
        Epoch 70/100, Loss: 1.0888070213167291
        Epoch 71/100, Loss: 1.0885787581142625
        Epoch 72/100, Loss: 1.0881005851845993
        Epoch 73/100, Loss: 1.088556856858103
        Epoch 74/100, Loss: 1.0886931827193813
        Epoch 75/100, Loss: 1.0891240270514237
        Epoch 76/100, Loss: 1.0881185136343303
        Epoch 77/100, Loss: 1.0881752754512586
        Epoch 78/100, Loss: 1.0886400856469807
        Epoch 79/100, Loss: 1.0885550749929327
        Epoch 80/100, Loss: 1.088283360004425
        Epoch 81/100, Loss: 1.0882359385490417
        Epoch 82/100, Loss: 1.0882998460217526
        Epoch 83/100, Loss: 1.0886448922910188
        Epoch 84/100, Loss: 1.0887338625757317
        Epoch 85/100, Loss: 1.088698207077227
        Epoch 86/100, Loss: 1.0883437972319754
        Epoch 87/100, Loss: 1.0886069573854145
        Epoch 88/100, Loss: 1.088475975864812
        Epoch 89/100, Loss: 1.0878600961283633
        Epoch 90/100, Loss: 1.0883057148833024
        Epoch 91/100, Loss: 1.0883820395720631
        Epoch 92/100, Loss: 1.0882131036959197
        Epoch 93/100, Loss: 1.0881353052038896
        Epoch 94/100, Loss: 1.0881876230239869
        Epoch 95/100, Loss: 1.088344062629499
        Epoch 96/100, Loss: 1.0884518278272528
        Epoch 97/100, Loss: 1.0884414302675347
        Epoch 98/100, Loss: 1.0886765705911736
        Epoch 99/100, Loss: 1.08864279483494
        Epoch 100/100, Loss: 1.0882219107527482"""

output_yolo_finetuning_classifier = output_yolo_finetuning_classifier.split("\n")
train_loss = [float(x.split(":")[1].split(",")[0]) for x in output_yolo_finetuning_classifier]
val_loss = [float(x.split(":")[2]) for x in output_yolo_finetuning_classifier]

plt.figure(figsize=(10,5))

plt.title("YOLO Finetuning Train/Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.plot(train_loss, label="Train Loss")
plt.plot(val_loss, label="Val Loss")
