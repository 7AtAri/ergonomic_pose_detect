# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
output_yolo_classifier = """Epoch 1/300, Loss: 1.0935969576239586
Epoch 2/300, Loss: 1.0748881697654724
Epoch 3/300, Loss: 1.0511314397056897
Epoch 4/300, Loss: 1.0424357429146767
Epoch 5/300, Loss: 1.0087338214119275
Epoch 6/300, Loss: 0.9865599249800047
Epoch 7/300, Loss: 0.9909304802616438
Epoch 8/300, Loss: 0.9701386714975039
Epoch 9/300, Loss: 0.9463426470756531
Epoch 10/300, Loss: 0.9417004187901815
Epoch 11/300, Loss: 0.9137833416461945
Epoch 12/300, Loss: 0.9084679409861565
Epoch 13/300, Loss: 0.8744018326203028
Epoch 14/300, Loss: 0.8651694469153881
Epoch 15/300, Loss: 0.8437974403301874
Epoch 16/300, Loss: 0.7914359346032143
Epoch 17/300, Loss: 0.7825812126199404
Epoch 18/300, Loss: 0.8143755284448465
Epoch 19/300, Loss: 0.7435722462832928
Epoch 20/300, Loss: 0.7707535959780216
Epoch 21/300, Loss: 0.7695980357627074
Epoch 22/300, Loss: 0.6853256411850452
Epoch 23/300, Loss: 0.6554677101473013
Epoch 24/300, Loss: 0.6855444063742956
Epoch 25/300, Loss: 0.6339927744120359
Epoch 26/300, Loss: 0.6788816725214323
Epoch 27/300, Loss: 0.5402416217451295
Epoch 28/300, Loss: 0.5651418914397558
Epoch 29/300, Loss: 0.5761437571297089
Epoch 30/300, Loss: 0.5487603768706322
Epoch 31/300, Loss: 0.6125150887916485
Epoch 32/300, Loss: 0.6067640955249468
Epoch 33/300, Loss: 0.5190965592240294
Epoch 34/300, Loss: 0.5409963177517056
Epoch 35/300, Loss: 0.5234754544993242
Epoch 36/300, Loss: 0.4172169417142868
Epoch 37/300, Loss: 0.4092185286184152
Epoch 38/300, Loss: 0.4681080548713605
Epoch 39/300, Loss: 0.43280068195114535
Epoch 40/300, Loss: 0.43625444763650495
Epoch 41/300, Loss: 0.4473637494569023
Epoch 42/300, Loss: 0.4339936214188735
Epoch 43/300, Loss: 0.37492072163149714
Epoch 44/300, Loss: 0.32947245907659334
Epoch 45/300, Loss: 0.3902648657870789
Epoch 46/300, Loss: 0.34978601910794777
Epoch 47/300, Loss: 0.39885476340229314
Epoch 48/300, Loss: 0.4771421554032713
Epoch 49/300, Loss: 0.34541711242248613
Epoch 50/300, Loss: 0.4276414904743433
Epoch 51/300, Loss: 0.36784798993418616
Epoch 52/300, Loss: 0.36897036867837113
Epoch 53/300, Loss: 0.38663527090102434
Epoch 54/300, Loss: 0.37306336623926956
Epoch 55/300, Loss: 0.30805150015900534
Epoch 56/300, Loss: 0.30777673594032723
Epoch 57/300, Loss: 0.4185692439010988
Epoch 58/300, Loss: 0.3632772153553863
Epoch 59/300, Loss: 0.2822687653824687
Epoch 60/300, Loss: 0.33066667430102825
Epoch 61/300, Loss: 0.3797643771395087
Epoch 62/300, Loss: 0.26613706815987825
Epoch 63/300, Loss: 0.29698950323897105
Epoch 64/300, Loss: 0.279721627322336
Epoch 65/300, Loss: 0.2376918239169754
Epoch 66/300, Loss: 0.20836125477217138
Epoch 67/300, Loss: 0.24071187417333326
Epoch 68/300, Loss: 0.22251536883413792
Epoch 69/300, Loss: 0.2238082179101184
Epoch 70/300, Loss: 0.3391941343434155
Epoch 71/300, Loss: 0.2642467405336599
Epoch 72/300, Loss: 0.19183143809398948
Epoch 73/300, Loss: 0.38128698578414816
Epoch 74/300, Loss: 0.3742489623837173
Epoch 75/300, Loss: 0.27705204766243696
Epoch 76/300, Loss: 0.23017592642766735
Epoch 77/300, Loss: 0.24090713823291784
Epoch 78/300, Loss: 0.22737064944036925
Epoch 79/300, Loss: 0.30373112610929337
Epoch 80/300, Loss: 0.18119708883265653
Epoch 81/300, Loss: 0.288446288817795
Epoch 82/300, Loss: 0.3235772733169142
Epoch 83/300, Loss: 0.27560115727828816
Epoch 84/300, Loss: 0.19918428796033064
Epoch 85/300, Loss: 0.2110004352677303
Epoch 86/300, Loss: 0.2298621052565674
Epoch 87/300, Loss: 0.2484758687981715
Epoch 88/300, Loss: 0.23642839790166667
Epoch 89/300, Loss: 0.19344795045132437
Epoch 90/300, Loss: 0.203454072883081
Epoch 91/300, Loss: 0.244399586711855
Epoch 92/300, Loss: 0.2904014191105186
Epoch 93/300, Loss: 0.23604884287245417
Epoch 94/300, Loss: 0.20750102567641684
Epoch 95/300, Loss: 0.20219450149064264
Epoch 96/300, Loss: 0.1689548661427883
Epoch 97/300, Loss: 0.16084174363641068
Epoch 98/300, Loss: 0.28631290153134614
Epoch 99/300, Loss: 0.19026082703203429
Epoch 100/300, Loss: 0.16041377586467812
Epoch 101/300, Loss: 0.1967901885509491
Epoch 102/300, Loss: 0.20701184457478425
Epoch 103/300, Loss: 0.1840103289966161
Epoch 104/300, Loss: 0.1754984441989412
Epoch 105/300, Loss: 0.12298703232469659
Epoch 106/300, Loss: 0.13925189536530524
Epoch 107/300, Loss: 0.15076388946423927
Epoch 108/300, Loss: 0.1263112905774809
Epoch 109/300, Loss: 0.10004028431527938
Epoch 110/300, Loss: 0.14430752015808443
Epoch 111/300, Loss: 0.16882320242196633
Epoch 112/300, Loss: 0.08777731848628416
Epoch 113/300, Loss: 0.10047204065388844
Epoch 114/300, Loss: 0.1216054335818626
Epoch 115/300, Loss: 0.16420325807606181
Epoch 116/300, Loss: 0.15564656474937996
Epoch 117/300, Loss: 0.12163861569812677
Epoch 118/300, Loss: 0.12561523626209237
Epoch 119/300, Loss: 0.1199741342576696
Epoch 120/300, Loss: 0.12078367464710027
Epoch 121/300, Loss: 0.1256730005843565
Epoch 122/300, Loss: 0.18187675565908043
Epoch 123/300, Loss: 0.09255316251559027
Epoch 124/300, Loss: 0.1579272893820113
Epoch 125/300, Loss: 0.09429784811800346
Epoch 126/300, Loss: 0.11279484263892907
Epoch 127/300, Loss: 0.09175003596889535
Epoch 128/300, Loss: 0.08373255943782472
Epoch 129/300, Loss: 0.17758494232354374
Epoch 130/300, Loss: 0.1387359361857913
Epoch 131/300, Loss: 0.09988453366289225
Epoch 132/300, Loss: 0.07761888034292497
Epoch 133/300, Loss: 0.07705719697211559
Epoch 134/300, Loss: 0.12029740249029904
Epoch 135/300, Loss: 0.10406110882710588
Epoch 136/300, Loss: 0.11223803423490608
Epoch 137/300, Loss: 0.1074223965794469
Epoch 138/300, Loss: 0.1331837140120721
Epoch 139/300, Loss: 0.13457737070469497
Epoch 140/300, Loss: 0.21523614787050369
Epoch 141/300, Loss: 0.08460601534413097
Epoch 142/300, Loss: 0.12768627731808616
Epoch 143/300, Loss: 0.14738772009089493
Epoch 144/300, Loss: 0.08219181472607791
Epoch 145/300, Loss: 0.1724952634976944
Epoch 146/300, Loss: 0.1000794238546708
Epoch 147/300, Loss: 0.11108571257985507
Epoch 148/300, Loss: 0.140198982936757
Epoch 149/300, Loss: 0.09268847447431956
Epoch 150/300, Loss: 0.13501835004232512
Epoch 151/300, Loss: 0.09795876924908953
Epoch 152/300, Loss: 0.16149355338560176
Epoch 153/300, Loss: 0.08416898718860466
Epoch 154/300, Loss: 0.07201540257665329
Epoch 155/300, Loss: 0.1116148714972951
Epoch 156/300, Loss: 0.05362020062542191
Epoch 157/300, Loss: 0.1160529418727189
Epoch 158/300, Loss: 0.10306359814361106
Epoch 159/300, Loss: 0.05680666830691431
Epoch 160/300, Loss: 0.08225669484818354
Epoch 161/300, Loss: 0.06271865149028599
Epoch 162/300, Loss: 0.06449875362523017
Epoch 163/300, Loss: 0.057845884077930045
Epoch 164/300, Loss: 0.055277188796026167
Epoch 165/300, Loss: 0.17859458315069787
Epoch 166/300, Loss: 0.046304192774793286
Epoch 167/300, Loss: 0.04833573976672293
Epoch 168/300, Loss: 0.053939533709732736
Epoch 169/300, Loss: 0.2273549116362119
Epoch 170/300, Loss: 0.036330546554381726
Epoch 171/300, Loss: 0.057548017570297816
Epoch 172/300, Loss: 0.07806968687570286
Epoch 173/300, Loss: 0.09484598864279785
Epoch 174/300, Loss: 0.09395233116932407
Epoch 175/300, Loss: 0.06949370939400978
Epoch 176/300, Loss: 0.12480114849798458
Epoch 177/300, Loss: 0.09826429880680128
Epoch 178/300, Loss: 0.08638525018614018
Epoch 179/300, Loss: 0.07765607763819087
Epoch 180/300, Loss: 0.04499160357439299
Epoch 181/300, Loss: 0.09643123417239015
Epoch 182/300, Loss: 0.09874146325516146
Epoch 183/300, Loss: 0.059181548441605024
Epoch 184/300, Loss: 0.08035458204297659
Epoch 185/300, Loss: 0.06265878627164057
Epoch 186/300, Loss: 0.04598822939925166
Epoch 187/300, Loss: 0.06692425117944367
Epoch 188/300, Loss: 0.07356133344759049
Epoch 189/300, Loss: 0.07057108317349048
Epoch 190/300, Loss: 0.025577069762827403
Epoch 191/300, Loss: 0.04015538586372713
Epoch 192/300, Loss: 0.03242222518974813
Epoch 193/300, Loss: 0.03062965694516606
Epoch 194/300, Loss: 0.04819481601589359
Epoch 195/300, Loss: 0.08069663675041738
Epoch 196/300, Loss: 0.07883373531937347
Epoch 197/300, Loss: 0.12098960356161115
Epoch 198/300, Loss: 0.02576844298528158
Epoch 199/300, Loss: 0.08578700478634953
Epoch 200/300, Loss: 0.03312260994061944
Epoch 201/300, Loss: 0.05187228289332779
Epoch 202/300, Loss: 0.054753009663727426
Epoch 203/300, Loss: 0.06362094317106919
Epoch 204/300, Loss: 0.10373110268604553
Epoch 205/300, Loss: 0.05728105027507505
Epoch 206/300, Loss: 0.03382135949702084
Epoch 207/300, Loss: 0.06052684529390717
Epoch 208/300, Loss: 0.02637240311014466
Epoch 209/300, Loss: 0.08886616727613728
Epoch 210/300, Loss: 0.05327502933020393
Epoch 211/300, Loss: 0.05495558827775918
Epoch 212/300, Loss: 0.10096012303741493
Epoch 213/300, Loss: 0.1373716965534489
Epoch 214/300, Loss: 0.0819363864850402
Epoch 215/300, Loss: 0.019707989840147395
Epoch 216/300, Loss: 0.059862090659786794
Epoch 217/300, Loss: 0.07403372888802551
Epoch 218/300, Loss: 0.04004940040249494
Epoch 219/300, Loss: 0.03301719647333812
Epoch 220/300, Loss: 0.07090289327849557
Epoch 221/300, Loss: 0.0701171029291648
Epoch 222/300, Loss: 0.06507496957025675
Epoch 223/300, Loss: 0.0716912730022159
Epoch 224/300, Loss: 0.043160934239494964
Epoch 225/300, Loss: 0.04845365979902757
Epoch 226/300, Loss: 0.044706660410156474
Epoch 227/300, Loss: 0.051757315940752356
Epoch 228/300, Loss: 0.06786001781407928
Epoch 229/300, Loss: 0.07394915896535774
Epoch 230/300, Loss: 0.04028639477049486
Epoch 231/300, Loss: 0.06867392305897131
Epoch 232/300, Loss: 0.0216183573914653
Epoch 233/300, Loss: 0.02942643612126024
Epoch 234/300, Loss: 0.015319961793162898
Epoch 235/300, Loss: 0.04171735869416201
Epoch 236/300, Loss: 0.014088781081833682
Epoch 237/300, Loss: 0.03601154337350939
Epoch 238/300, Loss: 0.09640442326296277
Epoch 239/300, Loss: 0.038009177698086205
Epoch 240/300, Loss: 0.030205346131576032
Epoch 241/300, Loss: 0.013650862636192565
Epoch 242/300, Loss: 0.02862143985809477
Epoch 243/300, Loss: 0.013930192436722185
Epoch 244/300, Loss: 0.023583450437210256
Epoch 245/300, Loss: 0.01631602627458051
Epoch 246/300, Loss: 0.013676371349750601
Epoch 247/300, Loss: 0.025432662338289447
Epoch 248/300, Loss: 0.07245708094948593
Epoch 249/300, Loss: 0.029464236552636674
Epoch 250/300, Loss: 0.04311331982292662
Epoch 251/300, Loss: 0.026295404486556134
Epoch 252/300, Loss: 0.04663800089292636
Epoch 253/300, Loss: 0.05069326332598697
Epoch 254/300, Loss: 0.026917188248565555
Epoch 255/300, Loss: 0.017398082328024127
Epoch 256/300, Loss: 0.039226612837713525
Epoch 257/300, Loss: 0.04817811706565559
Epoch 258/300, Loss: 0.07223463622888933
Epoch 259/300, Loss: 0.08795127891547357
Epoch 260/300, Loss: 0.03154161046601681
Epoch 261/300, Loss: 0.017499799415418238
Epoch 262/300, Loss: 0.10179632515835617
Epoch 263/300, Loss: 0.02237381230634128
Epoch 264/300, Loss: 0.07977026177055298
Epoch 265/300, Loss: 0.046260874634413085
Epoch 266/300, Loss: 0.051815618766795524
Epoch 267/300, Loss: 0.025355574772371863
Epoch 268/300, Loss: 0.01896325828359598
Epoch 269/300, Loss: 0.03682603937704698
Epoch 270/300, Loss: 0.0231388020885485
Epoch 271/300, Loss: 0.04828386811242543
Epoch 272/300, Loss: 0.11098721540171634
Epoch 273/300, Loss: 0.07329200707575485
Epoch 274/300, Loss: 0.0620039562020717
Epoch 275/300, Loss: 0.0108832561275752
Epoch 276/300, Loss: 0.013052246163321493
Epoch 277/300, Loss: 0.02629140803789672
Epoch 278/300, Loss: 0.0216736902222389
Epoch 279/300, Loss: 0.01128168868907172
Epoch 280/300, Loss: 0.02425823193730044
Epoch 281/300, Loss: 0.012085031254779702
Epoch 282/300, Loss: 0.011109817017351512
Epoch 283/300, Loss: 0.023338470164314156
Epoch 284/300, Loss: 0.028887083950467723
Epoch 285/300, Loss: 0.06758583404962337
Epoch 286/300, Loss: 0.061816879868274555
Epoch 287/300, Loss: 0.03947353137580952
Epoch 288/300, Loss: 0.014222115480151842
Epoch 289/300, Loss: 0.0036772351014633387
Epoch 290/300, Loss: 0.017032463327116904
Epoch 291/300, Loss: 0.04772544813871112
Epoch 292/300, Loss: 0.01047177422663026
Epoch 293/300, Loss: 0.046645809467501444
Epoch 294/300, Loss: 0.040093819327760606
Epoch 295/300, Loss: 0.02913396294695758
Epoch 296/300, Loss: 0.05180964241534033
Epoch 297/300, Loss: 0.016651131449104167
Epoch 298/300, Loss: 0.018764142645371296
Epoch 299/300, Loss: 0.026073992691848957
Epoch 300/300, Loss: 0.01126254964318226"""
    
output_yolo_classifier = output_yolo_classifier.split("\n")
output_yolo_classifier = [float(x.split(": ")[1]) for x in output_yolo_classifier]
output_yolo_classifier = np.array(output_yolo_classifier)

plt.figure(figsize=(10,5))

plt.title("YOLO as Keypoint Detector + Classifier Train Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.plot(output_yolo_classifier)

# %%
output_yolo_scorer = """Epoch 1/200, Loss: 10.267204523086548
Epoch 2/200, Loss: 5.815498431523641
Epoch 3/200, Loss: 4.471995671590169
Epoch 4/200, Loss: 4.259305477142334
Epoch 5/200, Loss: 4.089659333229065
Epoch 6/200, Loss: 4.081759691238403
Epoch 7/200, Loss: 4.09669041633606
Epoch 8/200, Loss: 4.102547367413838
Epoch 9/200, Loss: 4.124715288480123
Epoch 10/200, Loss: 4.043172399202983
Epoch 11/200, Loss: 4.116622010866801
Epoch 12/200, Loss: 4.022258877754211
Epoch 13/200, Loss: 4.079744021097819
Epoch 14/200, Loss: 4.040886680285136
Epoch 15/200, Loss: 4.171689510345459
Epoch 16/200, Loss: 4.092080473899841
Epoch 17/200, Loss: 4.044727166493733
Epoch 18/200, Loss: 4.046770811080933
Epoch 19/200, Loss: 4.012217203776042
Epoch 20/200, Loss: 4.0511659781138105
Epoch 21/200, Loss: 4.062447826067607
Epoch 22/200, Loss: 4.046991070111592
Epoch 23/200, Loss: 3.9613842566808066
Epoch 24/200, Loss: 4.194707711537679
Epoch 25/200, Loss: 4.08072825272878
Epoch 26/200, Loss: 4.004677851994832
Epoch 27/200, Loss: 4.101745963096619
Epoch 28/200, Loss: 4.093260924021403
Epoch 29/200, Loss: 4.228667179743449
Epoch 30/200, Loss: 4.117721319198608
Epoch 31/200, Loss: 4.258166074752808
Epoch 32/200, Loss: 4.054980794588725
Epoch 33/200, Loss: 4.038478533426921
Epoch 34/200, Loss: 4.018138567606608
Epoch 35/200, Loss: 4.008675932884216
Epoch 36/200, Loss: 4.231860399246216
Epoch 37/200, Loss: 4.1681831280390425
Epoch 38/200, Loss: 4.063649614651998
Epoch 39/200, Loss: 4.182234287261963
Epoch 40/200, Loss: 4.062503337860107
Epoch 41/200, Loss: 4.102120200792949
Epoch 42/200, Loss: 4.109672983487447
Epoch 43/200, Loss: 4.155847589174907
Epoch 44/200, Loss: 3.9962151447931924
Epoch 45/200, Loss: 4.093624273935954
Epoch 46/200, Loss: 4.278957962989807
Epoch 47/200, Loss: 4.07707945505778
Epoch 48/200, Loss: 4.083312710126241
Epoch 49/200, Loss: 4.121160984039307
Epoch 50/200, Loss: 4.1759263674418134
Epoch 51/200, Loss: 3.999652862548828
Epoch 52/200, Loss: 4.007978955904643
Epoch 53/200, Loss: 4.062219858169556
Epoch 54/200, Loss: 4.053925355275472
Epoch 55/200, Loss: 4.115513165791829
Epoch 56/200, Loss: 4.09899898370107
Epoch 57/200, Loss: 4.0099178949991865
Epoch 58/200, Loss: 3.9030423959096274
Epoch 59/200, Loss: 4.030950665473938
Epoch 60/200, Loss: 4.012695988019307
Epoch 61/200, Loss: 3.998447855313619
Epoch 62/200, Loss: 3.950743397076925
Epoch 63/200, Loss: 4.031810839970906
Epoch 64/200, Loss: 4.066174189249675
Epoch 65/200, Loss: 4.19804847240448
Epoch 66/200, Loss: 4.059653917948405
Epoch 67/200, Loss: 4.134226004282634
Epoch 68/200, Loss: 4.048281311988831
Epoch 69/200, Loss: 3.9968398014704385
Epoch 70/200, Loss: 4.027405420939128
Epoch 71/200, Loss: 3.962503433227539
Epoch 72/200, Loss: 3.986684719721476
Epoch 73/200, Loss: 4.040432612101237
Epoch 74/200, Loss: 4.130968530972798
Epoch 75/200, Loss: 4.099788586298625
Epoch 76/200, Loss: 3.9398520390192666
Epoch 77/200, Loss: 3.9954340060551963
Epoch 78/200, Loss: 4.105117479960124
Epoch 79/200, Loss: 4.0817699035008745
Epoch 80/200, Loss: 3.9897296031316123
Epoch 81/200, Loss: 4.040576100349426
Epoch 82/200, Loss: 3.9993478059768677
Epoch 83/200, Loss: 4.033500035603841
Epoch 84/200, Loss: 4.095432122548421
Epoch 85/200, Loss: 3.9445104201634726
Epoch 86/200, Loss: 3.98873770236969
Epoch 87/200, Loss: 4.0096657276153564
Epoch 88/200, Loss: 4.073277672131856
Epoch 89/200, Loss: 4.014779686927795
Epoch 90/200, Loss: 4.016543348630269
Epoch 91/200, Loss: 3.976623813311259
Epoch 92/200, Loss: 3.982704679171244
Epoch 93/200, Loss: 4.0308827956517534
Epoch 94/200, Loss: 4.222949147224426
Epoch 95/200, Loss: 3.898190418879191
Epoch 96/200, Loss: 4.1115158796310425
Epoch 97/200, Loss: 3.9368167320887246
Epoch 98/200, Loss: 4.081241210301717
Epoch 99/200, Loss: 4.006042957305908
Epoch 100/200, Loss: 4.03505798180898
Epoch 101/200, Loss: 4.036309917767842
Epoch 102/200, Loss: 4.110203782717387
Epoch 103/200, Loss: 4.078107674916585
Epoch 104/200, Loss: 3.983745296796163
Epoch 105/200, Loss: 4.068551858266194
Epoch 106/200, Loss: 4.125027179718018
Epoch 107/200, Loss: 3.9406615098317466
Epoch 108/200, Loss: 4.013379057248433
Epoch 109/200, Loss: 4.141273736953735
Epoch 110/200, Loss: 4.104996164639791
Epoch 111/200, Loss: 3.978485902150472
Epoch 112/200, Loss: 3.9928411642710366
Epoch 113/200, Loss: 3.971883495648702
Epoch 114/200, Loss: 3.9132861693700156
Epoch 115/200, Loss: 3.978091239929199
Epoch 116/200, Loss: 3.988124132156372
Epoch 117/200, Loss: 4.039031823476155
Epoch 118/200, Loss: 3.9136239290237427
Epoch 119/200, Loss: 4.003872513771057
Epoch 120/200, Loss: 4.082528432210286
Epoch 121/200, Loss: 3.959963003794352
Epoch 122/200, Loss: 3.975009799003601
Epoch 123/200, Loss: 4.018740177154541
Epoch 124/200, Loss: 3.937243660291036
Epoch 125/200, Loss: 3.9541908899943032
Epoch 126/200, Loss: 3.953382134437561
Epoch 127/200, Loss: 3.964933673540751
Epoch 128/200, Loss: 4.044871528943379
Epoch 129/200, Loss: 4.107794165611267
Epoch 130/200, Loss: 4.101351539293925
Epoch 131/200, Loss: 3.9787447849909463
Epoch 132/200, Loss: 3.9539859294891357
Epoch 133/200, Loss: 3.977624694506327
Epoch 134/200, Loss: 4.058124860127767
Epoch 135/200, Loss: 3.9533782800038657
Epoch 136/200, Loss: 3.9184900522232056
Epoch 137/200, Loss: 4.063675045967102
Epoch 138/200, Loss: 4.138531406720479
Epoch 139/200, Loss: 4.014150222142537
Epoch 140/200, Loss: 3.95342226823171
Epoch 141/200, Loss: 3.942173957824707
Epoch 142/200, Loss: 3.9351824124654136
Epoch 143/200, Loss: 4.02156416575114
Epoch 144/200, Loss: 3.9632875521977744
Epoch 145/200, Loss: 3.9974148273468018
Epoch 146/200, Loss: 3.96260929107666
Epoch 147/200, Loss: 3.977455973625183
Epoch 148/200, Loss: 3.9334038893381753
Epoch 149/200, Loss: 3.960498015085856
Epoch 150/200, Loss: 3.9236753781636557
Epoch 151/200, Loss: 4.011558612187703
Epoch 152/200, Loss: 3.9935919841130576
Epoch 153/200, Loss: 4.049807707468669
Epoch 154/200, Loss: 4.055954217910767
Epoch 155/200, Loss: 3.89608097076416
Epoch 156/200, Loss: 3.9262080987294516
Epoch 157/200, Loss: 3.9295657873153687
Epoch 158/200, Loss: 3.960697650909424
Epoch 159/200, Loss: 3.8430184920628867
Epoch 160/200, Loss: 4.073151548703511
Epoch 161/200, Loss: 4.084207018216451
Epoch 162/200, Loss: 3.9278600215911865
Epoch 163/200, Loss: 3.9242839415868125
Epoch 164/200, Loss: 3.93990949789683
Epoch 165/200, Loss: 3.967386325200399
Epoch 166/200, Loss: 3.943594455718994
Epoch 167/200, Loss: 3.9791065057118735
Epoch 168/200, Loss: 3.8837645053863525
Epoch 169/200, Loss: 3.943443497021993
Epoch 170/200, Loss: 4.048122366269429
Epoch 171/200, Loss: 3.928007205327352
Epoch 172/200, Loss: 4.0864600737889605
Epoch 173/200, Loss: 3.9676141341527305
Epoch 174/200, Loss: 3.9369959831237793
Epoch 175/200, Loss: 3.9443389177322388
Epoch 176/200, Loss: 3.9125045935312905
Epoch 177/200, Loss: 4.011197447776794
Epoch 178/200, Loss: 3.9057980378468833
Epoch 179/200, Loss: 3.978978951772054
Epoch 180/200, Loss: 3.945582071940104
Epoch 181/200, Loss: 3.883482336997986
Epoch 182/200, Loss: 3.91413950920105
Epoch 183/200, Loss: 3.9923574527104697
Epoch 184/200, Loss: 3.8910323778788247
Epoch 185/200, Loss: 3.887175997098287
Epoch 186/200, Loss: 3.9681034485499063
Epoch 187/200, Loss: 3.9755331675211587
Epoch 188/200, Loss: 3.946414669354757
Epoch 189/200, Loss: 3.9318655331929526
Epoch 190/200, Loss: 3.9367840687433877
Epoch 191/200, Loss: 3.9214953184127808
Epoch 192/200, Loss: 3.9224642515182495
Epoch 193/200, Loss: 3.9026792446772256
Epoch 194/200, Loss: 3.9155889749526978
Epoch 195/200, Loss: 3.83877166112264
Epoch 196/200, Loss: 4.081154743830363
Epoch 197/200, Loss: 3.9546942710876465
Epoch 198/200, Loss: 3.948448340098063
Epoch 199/200, Loss: 3.9893747568130493
Epoch 200/200, Loss: 4.06830374399821"""

output_yolo_scorer = output_yolo_scorer.split("\n")
output_yolo_scorer = [float(x.split(": ")[1]) for x in output_yolo_scorer]
output_yolo_scorer = np.array(output_yolo_scorer)

plt.figure(figsize=(10,5))

plt.title("YOLO as Keypoint Detector + Scorer Train Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.plot(output_yolo_scorer)

# %%
output_mmpose_classifier = """Epoch 1/100, Loss: 1.0904159148534138
        Epoch 2/100, Loss: 1.0263748268286388
        Epoch 3/100, Loss: 0.9700267116228739
        Epoch 4/100, Loss: 0.9602437118689219
        Epoch 5/100, Loss: 0.8852782845497131
        Epoch 6/100, Loss: 0.9544138809045156
        Epoch 7/100, Loss: 0.8189499775568644
        Epoch 8/100, Loss: 0.7849861681461334
        Epoch 9/100, Loss: 0.6901061137517294
        Epoch 10/100, Loss: 0.7113344271977743
        Epoch 11/100, Loss: 0.5821369290351868
        Epoch 12/100, Loss: 0.49788687626520794
        Epoch 13/100, Loss: 0.5385311792294184
        Epoch 14/100, Loss: 0.5444477995236715
        Epoch 15/100, Loss: 0.484404335419337
        Epoch 16/100, Loss: 0.456838163236777
        Epoch 17/100, Loss: 0.5165937518080076
        Epoch 18/100, Loss: 0.5228654543558756
        Epoch 19/100, Loss: 0.4657561282316844
        Epoch 20/100, Loss: 0.42176418999830884
        Epoch 21/100, Loss: 0.44027722378571826
        Epoch 22/100, Loss: 0.4304322625199954
        Epoch 23/100, Loss: 0.4002530202269554
        Epoch 24/100, Loss: 0.3104673661291599
        Epoch 25/100, Loss: 0.33835308998823166
        Epoch 26/100, Loss: 0.47130633642276126
        Epoch 27/100, Loss: 0.3550916984677315
        Epoch 28/100, Loss: 0.2403175594906012
        Epoch 29/100, Loss: 0.25686250378688175
        Epoch 30/100, Loss: 0.3577049449086189
        Epoch 31/100, Loss: 0.3656448225180308
        Epoch 32/100, Loss: 0.35027630627155304
        Epoch 33/100, Loss: 0.24785665422677994
        Epoch 34/100, Loss: 0.2284464587767919
        Epoch 35/100, Loss: 0.19577470608055592
        Epoch 36/100, Loss: 0.2155768685042858
        Epoch 37/100, Loss: 0.4096426951388518
        Epoch 38/100, Loss: 0.31627858771632117
        Epoch 39/100, Loss: 0.32026008144021034
        Epoch 40/100, Loss: 0.24738827471931776
        Epoch 41/100, Loss: 0.2888227974375089
        Epoch 42/100, Loss: 0.275791859254241
        Epoch 43/100, Loss: 0.1802385045836369
        Epoch 44/100, Loss: 0.19880102078119913
        Epoch 45/100, Loss: 0.28636079654097557
        Epoch 46/100, Loss: 0.16481071213881174
        Epoch 47/100, Loss: 0.21529757355650267
        Epoch 48/100, Loss: 0.2280221531788508
        Epoch 49/100, Loss: 0.2530965246260166
        Epoch 50/100, Loss: 0.300118509059151
        Epoch 51/100, Loss: 0.28672250794867676
        Epoch 52/100, Loss: 0.3859691818555196
        Epoch 53/100, Loss: 0.24335234984755516
        Epoch 54/100, Loss: 0.43088165173927945
        Epoch 55/100, Loss: 0.26313389216860134
        Epoch 56/100, Loss: 0.22838191439708075
        Epoch 57/100, Loss: 0.190752229342858
        Epoch 58/100, Loss: 0.22159641981124878
        Epoch 59/100, Loss: 0.17416432996590933
        Epoch 60/100, Loss: 0.2120380587875843
        Epoch 61/100, Loss: 0.2458749661842982
        Epoch 62/100, Loss: 0.16797573740283647
        Epoch 63/100, Loss: 0.24380488569537798
        Epoch 64/100, Loss: 0.1934592922528585
        Epoch 65/100, Loss: 0.23307607074578604
        Epoch 66/100, Loss: 0.10499884250263374
        Epoch 67/100, Loss: 0.0858653640995423
        Epoch 68/100, Loss: 0.13536209426820278
        Epoch 69/100, Loss: 0.1422426582624515
        Epoch 70/100, Loss: 0.2202502911289533
        Epoch 71/100, Loss: 0.12214266881346703
        Epoch 72/100, Loss: 0.05982499197125435
        Epoch 73/100, Loss: 0.10201655964677532
        Epoch 74/100, Loss: 0.10927706273893516
        Epoch 75/100, Loss: 0.24664975322472552
        Epoch 76/100, Loss: 0.18544339900836349
        Epoch 77/100, Loss: 0.2343858666718006
        Epoch 78/100, Loss: 0.2523167133331299
        Epoch 79/100, Loss: 0.185143090163668
        Epoch 80/100, Loss: 0.11707822761187951
        Epoch 81/100, Loss: 0.25655406589309376
        Epoch 82/100, Loss: 0.14679782340923944
        Epoch 83/100, Loss: 0.13923510909080505
        Epoch 84/100, Loss: 0.14499783143401146
        Epoch 85/100, Loss: 0.10869455337524414
        Epoch 86/100, Loss: 0.10306977899745107
        Epoch 87/100, Loss: 0.06171748166282972
        Epoch 88/100, Loss: 0.20819436945021152
        Epoch 89/100, Loss: 0.10897447603444259
        Epoch 90/100, Loss: 0.18902075787385306
        Epoch 91/100, Loss: 0.11705432552844286
        Epoch 92/100, Loss: 0.08985494294514258
        Epoch 93/100, Loss: 0.15674381206432977
        Epoch 94/100, Loss: 0.19157080724835396
        Epoch 95/100, Loss: 0.18755649231995145
        Epoch 96/100, Loss: 0.14092566911131144
        Epoch 97/100, Loss: 0.11209243753304084
        Epoch 98/100, Loss: 0.1586087333659331
        Epoch 99/100, Loss: 0.15520702488720417
        Epoch 100/100, Loss: 0.14354327445228895"""
        
output_mmpose_classifier = output_mmpose_classifier.split("\n")
output_mmpose_classifier = [float(x.split(": ")[1]) for x in output_mmpose_classifier]
output_mmpose_classifier = np.array(output_mmpose_classifier)

plt.figure(figsize=(10,5))

plt.title("MMPose as Keypoint Detector + Classifier Train Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.plot(output_mmpose_classifier)

# %%
output_mmpose_scorer = """Epoch 1/200, Loss: 9.697385708491007
Epoch 2/200, Loss: 5.98160424331824
Epoch 3/200, Loss: 4.174108569820722
Epoch 4/200, Loss: 4.1535612642765045
Epoch 5/200, Loss: 4.004811878005664
Epoch 6/200, Loss: 3.9754221737384796
Epoch 7/200, Loss: 3.938331904510657
Epoch 8/200, Loss: 3.9150258153676987
Epoch 9/200, Loss: 3.904639594256878
Epoch 10/200, Loss: 3.8883832891782126
Epoch 11/200, Loss: 3.8736793075998626
Epoch 12/200, Loss: 3.8735623210668564
Epoch 13/200, Loss: 3.783027851333221
Epoch 14/200, Loss: 3.7681902199983597
Epoch 15/200, Loss: 4.009181953966618
Epoch 16/200, Loss: 3.725533276796341
Epoch 17/200, Loss: 3.849259104579687
Epoch 18/200, Loss: 3.834649088482062
Epoch 19/200, Loss: 3.7693318525950112
Epoch 20/200, Loss: 3.9507843777537346
Epoch 21/200, Loss: 3.835052082935969
Epoch 22/200, Loss: 3.8903770397106805
Epoch 23/200, Loss: 3.745260089635849
Epoch 24/200, Loss: 3.9536143441994986
Epoch 25/200, Loss: 3.8243938026328883
Epoch 26/200, Loss: 3.869579960902532
Epoch 27/200, Loss: 3.8405116200447083
Epoch 28/200, Loss: 3.91071375956138
Epoch 29/200, Loss: 3.802628974119822
Epoch 30/200, Loss: 3.8268914421399436
Epoch 31/200, Loss: 3.847941320389509
Epoch 32/200, Loss: 3.705900937318802
Epoch 33/200, Loss: 3.7860861321290336
Epoch 34/200, Loss: 3.892347519596418
Epoch 35/200, Loss: 3.696695019801458
Epoch 36/200, Loss: 3.5760018825531006
Epoch 37/200, Loss: 3.657383839289347
Epoch 38/200, Loss: 3.7446200251579285
Epoch 39/200, Loss: 3.8533444851636887
Epoch 40/200, Loss: 3.7664407789707184
Epoch 41/200, Loss: 3.8215804050366082
Epoch 42/200, Loss: 3.7525157233079276
Epoch 43/200, Loss: 3.719535862406095
Epoch 44/200, Loss: 3.996120348572731
Epoch 45/200, Loss: 3.9172446628411612
Epoch 46/200, Loss: 3.952401985724767
Epoch 47/200, Loss: 3.8275638769070306
Epoch 48/200, Loss: 3.655774936079979
Epoch 49/200, Loss: 3.801891565322876
Epoch 50/200, Loss: 3.751202675203482
Epoch 51/200, Loss: 3.6921234329541526
Epoch 52/200, Loss: 3.732754131158193
Epoch 53/200, Loss: 3.7838194022576013
Epoch 54/200, Loss: 3.6971409767866135
Epoch 55/200, Loss: 3.7439183965325356
Epoch 56/200, Loss: 3.732491930325826
Epoch 57/200, Loss: 3.8334335386753082
Epoch 58/200, Loss: 3.8445382912953696
Epoch 59/200, Loss: 3.81097050011158
Epoch 60/200, Loss: 3.848533014456431
Epoch 61/200, Loss: 3.844920093814532
Epoch 62/200, Loss: 3.696434661746025
Epoch 63/200, Loss: 3.79506786664327
Epoch 64/200, Loss: 3.8442373275756836
Epoch 65/200, Loss: 3.8288978338241577
Epoch 66/200, Loss: 3.702118292450905
Epoch 67/200, Loss: 3.728494564692179
Epoch 68/200, Loss: 3.843949111799399
Epoch 69/200, Loss: 3.6466403802235923
Epoch 70/200, Loss: 3.6948957120378814
Epoch 71/200, Loss: 3.9197344978650412
Epoch 72/200, Loss: 3.543380548556646
Epoch 73/200, Loss: 3.800020399192969
Epoch 74/200, Loss: 3.78278549015522
Epoch 75/200, Loss: 3.824371188879013
Epoch 76/200, Loss: 3.8579418609539666
Epoch 77/200, Loss: 3.7697487572828927
Epoch 78/200, Loss: 3.6712574834624925
Epoch 79/200, Loss: 3.7043092598517737
Epoch 80/200, Loss: 3.6343782618641853
Epoch 81/200, Loss: 3.8331694131096206
Epoch 82/200, Loss: 3.8989078203837075
Epoch 83/200, Loss: 3.6033658211429915
Epoch 84/200, Loss: 3.6768668529887996
Epoch 85/200, Loss: 3.6397482057412467
Epoch 86/200, Loss: 3.7676609456539154
Epoch 87/200, Loss: 3.925348572432995
Epoch 88/200, Loss: 3.8190388629833856
Epoch 89/200, Loss: 3.7914906591176987
Epoch 90/200, Loss: 3.717192274828752
Epoch 91/200, Loss: 3.578066503008207
Epoch 92/200, Loss: 3.7637424071629844
Epoch 93/200, Loss: 3.752609105159839
Epoch 94/200, Loss: 3.606103072563807
Epoch 95/200, Loss: 3.7836815789341927
Epoch 96/200, Loss: 3.842043489217758
Epoch 97/200, Loss: 3.9009680251280465
Epoch 98/200, Loss: 3.7023530105749765
Epoch 99/200, Loss: 3.6871096740166345
Epoch 100/200, Loss: 3.853715126713117
Epoch 101/200, Loss: 3.7633963897824287
Epoch 102/200, Loss: 3.904179369409879
Epoch 103/200, Loss: 3.7492450401186943
Epoch 104/200, Loss: 3.828080251812935
Epoch 105/200, Loss: 3.8528061509132385
Epoch 106/200, Loss: 3.7335760792096457
Epoch 107/200, Loss: 3.664901981751124
Epoch 108/200, Loss: 3.9186589270830154
Epoch 109/200, Loss: 3.6939459244410195
Epoch 110/200, Loss: 3.6301379104455314
Epoch 111/200, Loss: 3.7802379727363586
Epoch 112/200, Loss: 3.764327622950077
Epoch 113/200, Loss: 3.546157032251358
Epoch 114/200, Loss: 3.798966800173124
Epoch 115/200, Loss: 3.7696470618247986
Epoch 116/200, Loss: 3.8398453096548715
Epoch 117/200, Loss: 3.837674861152967
Epoch 118/200, Loss: 3.699394921461741
Epoch 119/200, Loss: 3.7477664885421595
Epoch 120/200, Loss: 3.683404097954432
Epoch 121/200, Loss: 3.689081641534964
Epoch 122/200, Loss: 3.6159476911028228
Epoch 123/200, Loss: 3.6712214474876723
Epoch 124/200, Loss: 3.992764795819918
Epoch 125/200, Loss: 3.8890041609605155
Epoch 126/200, Loss: 3.6691563775142035
Epoch 127/200, Loss: 3.790570373336474
Epoch 128/200, Loss: 3.638387685020765
Epoch 129/200, Loss: 3.663572626809279
Epoch 130/200, Loss: 3.76119435330232
Epoch 131/200, Loss: 3.7200731138388314
Epoch 132/200, Loss: 3.8558426201343536
Epoch 133/200, Loss: 3.7292248557011285
Epoch 134/200, Loss: 3.7608790174126625
Epoch 135/200, Loss: 3.7959017554918923
Epoch 136/200, Loss: 3.7221795693039894
Epoch 137/200, Loss: 3.6454198186596236
Epoch 138/200, Loss: 3.7066587011019387
Epoch 139/200, Loss: 3.811691865324974
Epoch 140/200, Loss: 3.8242906630039215
Epoch 141/200, Loss: 3.628237098455429
Epoch 142/200, Loss: 3.6813224156697593
Epoch 143/200, Loss: 3.739826999604702
Epoch 144/200, Loss: 3.944658343990644
Epoch 145/200, Loss: 3.8888951241970062
Epoch 146/200, Loss: 3.76041687031587
Epoch 147/200, Loss: 3.664410044749578
Epoch 148/200, Loss: 3.776739945014318
Epoch 149/200, Loss: 3.8368625168999038
Epoch 150/200, Loss: 3.8076173265775046
Epoch 151/200, Loss: 3.861127550403277
Epoch 152/200, Loss: 3.620748927195867
Epoch 153/200, Loss: 3.6217458794514337
Epoch 154/200, Loss: 3.8712960879007974
Epoch 155/200, Loss: 3.8435149925450482
Epoch 156/200, Loss: 3.7903509189685187
Epoch 157/200, Loss: 3.614812910556793
Epoch 158/200, Loss: 3.9037620027860007
Epoch 159/200, Loss: 3.744374324878057
Epoch 160/200, Loss: 3.854637950658798
Epoch 161/200, Loss: 3.925039365887642
Epoch 162/200, Loss: 3.5819846242666245
Epoch 163/200, Loss: 3.6677482227484384
Epoch 164/200, Loss: 3.769409735997518
Epoch 165/200, Loss: 3.935660413155953
Epoch 166/200, Loss: 3.6861040542523065
Epoch 167/200, Loss: 3.820864131053289
Epoch 168/200, Loss: 3.850046788652738
Epoch 169/200, Loss: 3.5174774527549744
Epoch 170/200, Loss: 3.663447459538778
Epoch 171/200, Loss: 3.788462037841479
Epoch 172/200, Loss: 3.845995952685674
Epoch 173/200, Loss: 3.7207416171828904
Epoch 174/200, Loss: 3.6885312174757323
Epoch 175/200, Loss: 3.629278505841891
Epoch 176/200, Loss: 3.7549021455148854
Epoch 177/200, Loss: 3.769334894915422
Epoch 178/200, Loss: 3.5964555939038596
Epoch 179/200, Loss: 3.59831290692091
Epoch 180/200, Loss: 3.728322312235832
Epoch 181/200, Loss: 3.778307259082794
Epoch 182/200, Loss: 3.74376971522967
Epoch 183/200, Loss: 3.7518209566672645
Epoch 184/200, Loss: 3.8706512401501336
Epoch 185/200, Loss: 3.5908812483151755
Epoch 186/200, Loss: 3.7876929913957915
Epoch 187/200, Loss: 3.6853786607583365
Epoch 188/200, Loss: 3.7064743439356485
Epoch 189/200, Loss: 3.7866095254818597
Epoch 190/200, Loss: 3.905333325266838
Epoch 191/200, Loss: 3.7174559235572815
Epoch 192/200, Loss: 3.9409583508968353
Epoch 193/200, Loss: 3.6919934252897897
Epoch 194/200, Loss: 3.8826566288868585
Epoch 195/200, Loss: 3.7700380931297937
Epoch 196/200, Loss: 3.7855696777502694
Epoch 197/200, Loss: 3.81689453125
Epoch 198/200, Loss: 3.6981084843476615
Epoch 199/200, Loss: 3.6624110490083694
Epoch 200/200, Loss: 3.879979319870472"""
        
output_mmpose_scorer = output_mmpose_scorer.split("\n")
output_mmpose_scorer = [float(x.split(": ")[1]) for x in output_mmpose_scorer]
output_mmpose_scorer = np.array(output_mmpose_scorer)

plt.figure(figsize=(10,5))

plt.title("MMPose as Keypoint Detector + Scorer Train Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.plot(output_mmpose_scorer)

# %%
output_yolo_kp_angle_classifier = """Epoch 1/300, Loss: 2.666595550636042
        Epoch 2/300, Loss: 2.261162247276623
        Epoch 3/300, Loss: 2.280808792097224
        Epoch 4/300, Loss: 2.122312798681914
        Epoch 5/300, Loss: 1.8357759982347488
        Epoch 6/300, Loss: 1.6539972904248554
        Epoch 7/300, Loss: 1.5618447455565299
        Epoch 8/300, Loss: 1.4598485026704637
        Epoch 9/300, Loss: 1.4889428501801663
        Epoch 10/300, Loss: 1.3543113913681162
        Epoch 11/300, Loss: 1.1113509994882502
        Epoch 12/300, Loss: 1.2979685425366225
        Epoch 13/300, Loss: 1.1491951434235823
        Epoch 14/300, Loss: 1.1532822714824424
        Epoch 15/300, Loss: 1.1580424812181216
        Epoch 16/300, Loss: 1.1691210525600533
        Epoch 17/300, Loss: 1.100414271142922
        Epoch 18/300, Loss: 1.2671097630144734
        Epoch 19/300, Loss: 0.935974913227715
        Epoch 20/300, Loss: 1.0397352521650884
        Epoch 21/300, Loss: 0.8614488095633294
        Epoch 22/300, Loss: 0.9301851650503905
        Epoch 23/300, Loss: 1.0168778121961575
        Epoch 24/300, Loss: 0.7803218460825615
        Epoch 25/300, Loss: 1.031380786933005
        Epoch 26/300, Loss: 0.9325564711501724
        Epoch 27/300, Loss: 0.9975247696434196
        Epoch 28/300, Loss: 0.8725077408347524
        Epoch 29/300, Loss: 0.8781267865658983
        Epoch 30/300, Loss: 0.8933042073389516
        Epoch 31/300, Loss: 0.7498464864782842
        Epoch 32/300, Loss: 0.9610690138100548
        Epoch 33/300, Loss: 0.8822530754792847
        Epoch 34/300, Loss: 0.8478172479099348
        Epoch 35/300, Loss: 0.7581294912942931
        Epoch 36/300, Loss: 0.872146048619853
        Epoch 37/300, Loss: 0.9026451282546316
        Epoch 38/300, Loss: 0.7597802769123135
        Epoch 39/300, Loss: 0.8552874024418232
        Epoch 40/300, Loss: 0.7371216120455708
        Epoch 41/300, Loss: 0.9328863777465334
        Epoch 42/300, Loss: 0.7183874518108113
        Epoch 43/300, Loss: 0.7713663704849559
        Epoch 44/300, Loss: 0.7660953614854646
        Epoch 45/300, Loss: 0.8297756746166238
        Epoch 46/300, Loss: 0.7903564854402487
        Epoch 47/300, Loss: 0.7064229954230158
        Epoch 48/300, Loss: 0.7405624222028755
        Epoch 49/300, Loss: 0.7283500111386131
        Epoch 50/300, Loss: 0.7303229000110725
        Epoch 51/300, Loss: 0.7150925429782977
        Epoch 52/300, Loss: 0.6430812043012243
        Epoch 53/300, Loss: 0.6555996237331113
        Epoch 54/300, Loss: 0.7476637843320053
        Epoch 55/300, Loss: 0.6129054138402352
        Epoch 56/300, Loss: 0.7733801210436324
        Epoch 57/300, Loss: 0.701828201379823
        Epoch 58/300, Loss: 0.6691281623051748
        Epoch 59/300, Loss: 0.5672035706048758
        Epoch 60/300, Loss: 0.6507590083674969
        Epoch 61/300, Loss: 0.7353264753987067
        Epoch 62/300, Loss: 0.602945804987547
        Epoch 63/300, Loss: 0.5794878440638824
        Epoch 64/300, Loss: 0.6558651203874002
        Epoch 65/300, Loss: 0.5834367205017005
        Epoch 66/300, Loss: 0.5210114552455575
        Epoch 67/300, Loss: 0.5778833062657597
        Epoch 68/300, Loss: 0.6441130310933467
        Epoch 69/300, Loss: 0.6223928798023017
        Epoch 70/300, Loss: 0.533129524881401
        Epoch 71/300, Loss: 0.60103709375858
        Epoch 72/300, Loss: 0.6318968890507317
        Epoch 73/300, Loss: 0.5401871312758503
        Epoch 74/300, Loss: 0.5330228570379019
        Epoch 75/300, Loss: 0.5196298845229504
        Epoch 76/300, Loss: 0.5007949758070409
        Epoch 77/300, Loss: 0.4721995482288261
        Epoch 78/300, Loss: 0.4751107735698928
        Epoch 79/300, Loss: 0.5738387886790932
        Epoch 80/300, Loss: 0.525886708224875
        Epoch 81/300, Loss: 0.5193309990298985
        Epoch 82/300, Loss: 0.6055534323289689
        Epoch 83/300, Loss: 0.5267591558248186
        Epoch 84/300, Loss: 0.5818501045487401
        Epoch 85/300, Loss: 0.49896496578429306
        Epoch 86/300, Loss: 0.45200558943458724
        Epoch 87/300, Loss: 0.5075663617348924
        Epoch 88/300, Loss: 0.49686112937461435
        Epoch 89/300, Loss: 0.44095921016444267
        Epoch 90/300, Loss: 0.4821922489176024
        Epoch 91/300, Loss: 0.5411189826957477
        Epoch 92/300, Loss: 0.5028455894118619
        Epoch 93/300, Loss: 0.3468691289656512
        Epoch 94/300, Loss: 0.42627622092496426
        Epoch 95/300, Loss: 0.5444470523584594
        Epoch 96/300, Loss: 0.49526536405470606
        Epoch 97/300, Loss: 0.5287051351394385
        Epoch 98/300, Loss: 0.40157052077975086
        Epoch 99/300, Loss: 0.42873635188377496
        Epoch 100/300, Loss: 0.4722554475278529
        Epoch 101/300, Loss: 0.48607708889275697
        Epoch 102/300, Loss: 0.36657193515047165
        Epoch 103/300, Loss: 0.40523663721558684
        Epoch 104/300, Loss: 0.4508297655503946
        Epoch 105/300, Loss: 0.32447884154062673
        Epoch 106/300, Loss: 0.3405888684401935
        Epoch 107/300, Loss: 0.4161949856416628
        Epoch 108/300, Loss: 0.4187256822442813
        Epoch 109/300, Loss: 0.3871268909268001
        Epoch 110/300, Loss: 0.4059680112028553
        Epoch 111/300, Loss: 0.35078866382358254
        Epoch 112/300, Loss: 0.47628037871983525
        Epoch 113/300, Loss: 0.379600562320047
        Epoch 114/300, Loss: 0.3057695921407757
        Epoch 115/300, Loss: 0.4452915662980005
        Epoch 116/300, Loss: 0.4589705832754206
        Epoch 117/300, Loss: 0.3927056147244845
        Epoch 118/300, Loss: 0.3216922226618096
        Epoch 119/300, Loss: 0.2838850614977715
        Epoch 120/300, Loss: 0.4425116026534253
        Epoch 121/300, Loss: 0.325034755714348
        Epoch 122/300, Loss: 0.31233445361219736
        Epoch 123/300, Loss: 0.4784088063741699
        Epoch 124/300, Loss: 0.2692325242508918
        Epoch 125/300, Loss: 0.23790771467237784
        Epoch 126/300, Loss: 0.3185001842787851
        Epoch 127/300, Loss: 0.36958937210504184
        Epoch 128/300, Loss: 0.30380600426448146
        Epoch 129/300, Loss: 0.3341381459187782
        Epoch 130/300, Loss: 0.3243921684516791
        Epoch 131/300, Loss: 0.35884160574350493
        Epoch 132/300, Loss: 0.2708554563513822
        Epoch 133/300, Loss: 0.36483244056114816
        Epoch 134/300, Loss: 0.18465445553713672
        Epoch 135/300, Loss: 0.27403554010813513
        Epoch 136/300, Loss: 0.18026374882289875
        Epoch 137/300, Loss: 0.32552555473002037
        Epoch 138/300, Loss: 0.4043550933307645
        Epoch 139/300, Loss: 0.3207896901482274
        Epoch 140/300, Loss: 0.20282098190821307
        Epoch 141/300, Loss: 0.23073180193595794
        Epoch 142/300, Loss: 0.39113875779855634
        Epoch 143/300, Loss: 0.24311454062795138
        Epoch 144/300, Loss: 0.3071567477628372
        Epoch 145/300, Loss: 0.13878746512296666
        Epoch 146/300, Loss: 0.2310283930058768
        Epoch 147/300, Loss: 0.3204970406821648
        Epoch 148/300, Loss: 0.18678094929949077
        Epoch 149/300, Loss: 0.23948410035067066
        Epoch 150/300, Loss: 0.19493143392418882
        Epoch 151/300, Loss: 0.1864073640786194
        Epoch 152/300, Loss: 0.3137195034883694
        Epoch 153/300, Loss: 0.3522232787125891
        Epoch 154/300, Loss: 0.28781618128259095
        Epoch 155/300, Loss: 0.19850645940660508
        Epoch 156/300, Loss: 0.17941327517866154
        Epoch 157/300, Loss: 0.2315399638339074
        Epoch 158/300, Loss: 0.33988890627594104
        Epoch 159/300, Loss: 0.28906529751245075
        Epoch 160/300, Loss: 0.20315222572776853
        Epoch 161/300, Loss: 0.20645518720482467
        Epoch 162/300, Loss: 0.1583495938590678
        Epoch 163/300, Loss: 0.1696492824216113
        Epoch 164/300, Loss: 0.2777967000693326
        Epoch 165/300, Loss: 0.26580576370222503
        Epoch 166/300, Loss: 0.26707019344100796
        Epoch 167/300, Loss: 0.1300960913389623
        Epoch 168/300, Loss: 0.2662607622302645
        Epoch 169/300, Loss: 0.21353369717011136
        Epoch 170/300, Loss: 0.20422302675963888
        Epoch 171/300, Loss: 0.31237217003566825
        Epoch 172/300, Loss: 0.15711439053127252
        Epoch 173/300, Loss: 0.2446435520141533
        Epoch 174/300, Loss: 0.11817008383580999
        Epoch 175/300, Loss: 0.2235128621311667
        Epoch 176/300, Loss: 0.24013701447985003
        Epoch 177/300, Loss: 0.16474630542710056
        Epoch 178/300, Loss: 0.16852907240197623
        Epoch 179/300, Loss: 0.16608312815651635
        Epoch 180/300, Loss: 0.12795243803899797
        Epoch 181/300, Loss: 0.1979126184993608
        Epoch 182/300, Loss: 0.2330822432006676
        Epoch 183/300, Loss: 0.23051359703368138
        Epoch 184/300, Loss: 0.12083624852826631
        Epoch 185/300, Loss: 0.13452534402797467
        Epoch 186/300, Loss: 0.22437634674750206
        Epoch 187/300, Loss: 0.17924051419287537
        Epoch 188/300, Loss: 0.13272315557946932
        Epoch 189/300, Loss: 0.3215353226452072
        Epoch 190/300, Loss: 0.14836402076438573
        Epoch 191/300, Loss: 0.06790548833444415
        Epoch 192/300, Loss: 0.12360257061894006
        Epoch 193/300, Loss: 0.1658719533658547
        Epoch 194/300, Loss: 0.09122340909577807
        Epoch 195/300, Loss: 0.11990458274840743
        Epoch 196/300, Loss: 0.09944537156077803
        Epoch 197/300, Loss: 0.17184298577194643
        Epoch 198/300, Loss: 0.15582195519598754
        Epoch 199/300, Loss: 0.28631943596674553
        Epoch 200/300, Loss: 0.06323619986583268
        Epoch 201/300, Loss: 0.18164480041837872
        Epoch 202/300, Loss: 0.21422156067642772
        Epoch 203/300, Loss: 0.15112973207565075
        Epoch 204/300, Loss: 0.19037959863192877
        Epoch 205/300, Loss: 0.1753052679725678
        Epoch 206/300, Loss: 0.11975408225842032
        Epoch 207/300, Loss: 0.12576103025331214
        Epoch 208/300, Loss: 0.1020310641422675
        Epoch 209/300, Loss: 0.12158370949084918
        Epoch 210/300, Loss: 0.13486775085110198
        Epoch 211/300, Loss: 0.1638715819835223
        Epoch 212/300, Loss: 0.06714088100918301
        Epoch 213/300, Loss: 0.06472923173138374
        Epoch 214/300, Loss: 0.10911323461826679
        Epoch 215/300, Loss: 0.11109796669139896
        Epoch 216/300, Loss: 0.0755953449613963
        Epoch 217/300, Loss: 0.10625219830312072
        Epoch 218/300, Loss: 0.22550832116786687
        Epoch 219/300, Loss: 0.049023175985133984
        Epoch 220/300, Loss: 0.05569891871254519
        Epoch 221/300, Loss: 0.07643492060755677
        Epoch 222/300, Loss: 0.08645659944321454
        Epoch 223/300, Loss: 0.1866813227536885
        Epoch 224/300, Loss: 0.08174143605498016
        Epoch 225/300, Loss: 0.14402356934870106
        Epoch 226/300, Loss: 0.050272515313654474
        Epoch 227/300, Loss: 0.18338118816741034
        Epoch 228/300, Loss: 0.1318448104809392
        Epoch 229/300, Loss: 0.09100069187924506
        Epoch 230/300, Loss: 0.10152365553505614
        Epoch 231/300, Loss: 0.08798278089294186
        Epoch 232/300, Loss: 0.10669397963216609
        Epoch 233/300, Loss: 0.16089867855849035
        Epoch 234/300, Loss: 0.07379711084390468
        Epoch 235/300, Loss: 0.0367958309160264
        Epoch 236/300, Loss: 0.12795967661531044
        Epoch 237/300, Loss: 0.041297269788975056
        Epoch 238/300, Loss: 0.14189862687416321
        Epoch 239/300, Loss: 0.10183573188884114
        Epoch 240/300, Loss: 0.0672793398866728
        Epoch 241/300, Loss: 0.0819142578119344
        Epoch 242/300, Loss: 0.1638435636928944
        Epoch 243/300, Loss: 0.03866312410706703
        Epoch 244/300, Loss: 0.08608053620085537
        Epoch 245/300, Loss: 0.12247056034938453
        Epoch 246/300, Loss: 0.16535302521537132
        Epoch 247/300, Loss: 0.14063965725517233
        Epoch 248/300, Loss: 0.04041454147963733
        Epoch 249/300, Loss: 0.07763235942737592
        Epoch 250/300, Loss: 0.10367750998217613
        Epoch 251/300, Loss: 0.036762889652944046
        Epoch 252/300, Loss: 0.034228283033696086
        Epoch 253/300, Loss: 0.0777367389135921
        Epoch 254/300, Loss: 0.06596786891168809
        Epoch 255/300, Loss: 0.1523411339485585
        Epoch 256/300, Loss: 0.08168887082006746
        Epoch 257/300, Loss: 0.2162500384980937
        Epoch 258/300, Loss: 0.023597052882074664
        Epoch 259/300, Loss: 0.15430264039398464
        Epoch 260/300, Loss: 0.07588925077111286
        Epoch 261/300, Loss: 0.08427893266666757
        Epoch 262/300, Loss: 0.06654646281267096
        Epoch 263/300, Loss: 0.03274976757800299
        Epoch 264/300, Loss: 0.14447376182218968
        Epoch 265/300, Loss: 0.05941566443100829
        Epoch 266/300, Loss: 0.09340629990875779
        Epoch 267/300, Loss: 0.023856411798675255
        Epoch 268/300, Loss: 0.06401786559827446
        Epoch 269/300, Loss: 0.020793291930656876
        Epoch 270/300, Loss: 0.014441448938315055
        Epoch 271/300, Loss: 0.12219950043505037
        Epoch 272/300, Loss: 0.0337397329950625
        Epoch 273/300, Loss: 0.0580215036376987
        Epoch 274/300, Loss: 0.020129902853755623
        Epoch 275/300, Loss: 0.055756982652949726
        Epoch 276/300, Loss: 0.08988557742062636
        Epoch 277/300, Loss: 0.15717851613361944
        Epoch 278/300, Loss: 0.07661479888650725
        Epoch 279/300, Loss: 0.14746912159280418
        Epoch 280/300, Loss: 0.09867845815344382
        Epoch 281/300, Loss: 0.27700812206455133
        Epoch 282/300, Loss: 0.08291792121639675
        Epoch 283/300, Loss: 0.021979168001145785
        Epoch 284/300, Loss: 0.07081333884587682
        Epoch 285/300, Loss: 0.09634621669067797
        Epoch 286/300, Loss: 0.0824914608453975
        Epoch 287/300, Loss: 0.05873878131296447
        Epoch 288/300, Loss: 0.028548104897478093
        Epoch 289/300, Loss: 0.017016786352083552
        Epoch 290/300, Loss: 0.09630806218632938
        Epoch 291/300, Loss: 0.024559774915607516
        Epoch 292/300, Loss: 0.05039167806400317
        Epoch 293/300, Loss: 0.048436622103170034
        Epoch 294/300, Loss: 0.0574311404001704
        Epoch 295/300, Loss: 0.026475585501180746
        Epoch 296/300, Loss: 0.022297061767510305
        Epoch 297/300, Loss: 0.035157615586238936
        Epoch 298/300, Loss: 0.011202347935994046
        Epoch 299/300, Loss: 0.014197787060925742
        Epoch 300/300, Loss: 0.05215423311295995"""
        
output_yolo_kp_angle_classifier = output_yolo_kp_angle_classifier.split("\n")
output_yolo_kp_angle_classifier = [float(x.split(": ")[1]) for x in output_yolo_kp_angle_classifier]
output_yolo_kp_angle_classifier = np.array(output_yolo_kp_angle_classifier)

plt.figure(figsize=(10,5))

plt.title("YOLO as Keypoint Detector + Calculated Angles with Keypoints for Classifier Train Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.plot(output_yolo_kp_angle_classifier)

# %%
output_yolo_kp_angle_scorer = """Epoch 1/200, Loss: 13.965652465820312
        Epoch 2/200, Loss: 10.065508047739664
        Epoch 3/200, Loss: 6.30704124768575
        Epoch 4/200, Loss: 5.2732001940409345
        Epoch 5/200, Loss: 6.47416075070699
        Epoch 6/200, Loss: 5.944696982701619
        Epoch 7/200, Loss: 4.617506504058838
        Epoch 8/200, Loss: 4.9408271710077925
        Epoch 9/200, Loss: 4.624274015426636
        Epoch 10/200, Loss: 4.786371231079102
        Epoch 11/200, Loss: 4.585852384567261
        Epoch 12/200, Loss: 4.620980620384216
        Epoch 13/200, Loss: 4.424335718154907
        Epoch 14/200, Loss: 4.526843746503194
        Epoch 15/200, Loss: 4.570213993390401
        Epoch 16/200, Loss: 4.691075404485066
        Epoch 17/200, Loss: 4.688865860303243
        Epoch 18/200, Loss: 4.78091561794281
        Epoch 19/200, Loss: 4.555864016215007
        Epoch 20/200, Loss: 4.365533908208211
        Epoch 21/200, Loss: 4.647191047668457
        Epoch 22/200, Loss: 4.288066943486531
        Epoch 23/200, Loss: 4.2943142255147295
        Epoch 24/200, Loss: 4.3030292590459185
        Epoch 25/200, Loss: 4.381914019584656
        Epoch 26/200, Loss: 4.282106916109721
        Epoch 27/200, Loss: 4.376422484715779
        Epoch 28/200, Loss: 4.344910621643066
        Epoch 29/200, Loss: 4.265461126963298
        Epoch 30/200, Loss: 4.314467231432597
        Epoch 31/200, Loss: 4.249988953272502
        Epoch 32/200, Loss: 4.266725619633992
        Epoch 33/200, Loss: 4.287265499432881
        Epoch 34/200, Loss: 4.111559311548869
        Epoch 35/200, Loss: 4.2947918971379595
        Epoch 36/200, Loss: 4.284677624702454
        Epoch 37/200, Loss: 4.331118901570638
        Epoch 38/200, Loss: 4.0426121552785235
        Epoch 39/200, Loss: 4.181256373723348
        Epoch 40/200, Loss: 4.169976234436035
        Epoch 41/200, Loss: 4.092102448145549
        Epoch 42/200, Loss: 4.319251378377278
        Epoch 43/200, Loss: 4.279190580050151
        Epoch 44/200, Loss: 4.144685943921407
        Epoch 45/200, Loss: 4.236538847287496
        Epoch 46/200, Loss: 4.312493721644084
        Epoch 47/200, Loss: 4.177637259165446
        Epoch 48/200, Loss: 4.298592209815979
        Epoch 49/200, Loss: 4.232661088307698
        Epoch 50/200, Loss: 4.2783390283584595
        Epoch 51/200, Loss: 4.223585486412048
        Epoch 52/200, Loss: 4.082143982251485
        Epoch 53/200, Loss: 4.073165376981099
        Epoch 54/200, Loss: 4.075128197669983
        Epoch 55/200, Loss: 4.1013955275217695
        Epoch 56/200, Loss: 4.347072958946228
        Epoch 57/200, Loss: 4.41696564356486
        Epoch 58/200, Loss: 4.307175954182942
        Epoch 59/200, Loss: 4.068896611531575
        Epoch 60/200, Loss: 4.0528413852055865
        Epoch 61/200, Loss: 4.0774480899175005
        Epoch 62/200, Loss: 4.049176136652629
        Epoch 63/200, Loss: 4.079734921455383
        Epoch 64/200, Loss: 4.046607295672099
        Epoch 65/200, Loss: 4.054139773050944
        Epoch 66/200, Loss: 4.072306156158447
        Epoch 67/200, Loss: 4.053762873013814
        Epoch 68/200, Loss: 4.113138993581136
        Epoch 69/200, Loss: 4.0768963098526
        Epoch 70/200, Loss: 4.078779220581055
        Epoch 71/200, Loss: 4.131678064664205
        Epoch 72/200, Loss: 4.248202681541443
        Epoch 73/200, Loss: 3.9417854944864907
        Epoch 74/200, Loss: 4.1316618124643965
        Epoch 75/200, Loss: 4.1624711354573565
        Epoch 76/200, Loss: 4.148043235143025
        Epoch 77/200, Loss: 4.173760334650676
        Epoch 78/200, Loss: 4.142855087916057
        Epoch 79/200, Loss: 4.08995779355367
        Epoch 80/200, Loss: 4.12923526763916
        Epoch 81/200, Loss: 3.983938733736674
        Epoch 82/200, Loss: 4.075032989184062
        Epoch 83/200, Loss: 4.18440842628479
        Epoch 84/200, Loss: 4.187731862068176
        Epoch 85/200, Loss: 4.143205483754476
        Epoch 86/200, Loss: 4.030185143152873
        Epoch 87/200, Loss: 4.101572672526042
        Epoch 88/200, Loss: 4.114009102185567
        Epoch 89/200, Loss: 4.049352169036865
        Epoch 90/200, Loss: 3.937568426132202
        Epoch 91/200, Loss: 3.99498184521993
        Epoch 92/200, Loss: 4.067257483800252
        Epoch 93/200, Loss: 4.063111186027527
        Epoch 94/200, Loss: 4.093313415845235
        Epoch 95/200, Loss: 4.050028483072917
        Epoch 96/200, Loss: 4.141132950782776
        Epoch 97/200, Loss: 4.082056383291881
        Epoch 98/200, Loss: 3.973668177922567
        Epoch 99/200, Loss: 4.180312871932983
        Epoch 100/200, Loss: 3.927355170249939
        Epoch 101/200, Loss: 4.074342608451843
        Epoch 102/200, Loss: 4.02795930703481
        Epoch 103/200, Loss: 4.073274294535319
        Epoch 104/200, Loss: 4.332905928293864
        Epoch 105/200, Loss: 4.1936153173446655
        Epoch 106/200, Loss: 4.1179689566294355
        Epoch 107/200, Loss: 4.030840675036113
        Epoch 108/200, Loss: 3.9844248294830322
        Epoch 109/200, Loss: 3.978192170461019
        Epoch 110/200, Loss: 3.9742801586786904
        Epoch 111/200, Loss: 3.9597926139831543
        Epoch 112/200, Loss: 4.071004470189412
        Epoch 113/200, Loss: 4.105818708737691
        Epoch 114/200, Loss: 3.9389962355295816
        Epoch 115/200, Loss: 4.064128478368123
        Epoch 116/200, Loss: 4.366935610771179
        Epoch 117/200, Loss: 4.083345055580139
        Epoch 118/200, Loss: 4.174172004063924
        Epoch 119/200, Loss: 4.14020053545634
        Epoch 120/200, Loss: 4.158989906311035
        Epoch 121/200, Loss: 4.019261479377747
        Epoch 122/200, Loss: 4.024649779001872
        Epoch 123/200, Loss: 4.041554888089498
        Epoch 124/200, Loss: 4.073580185572307
        Epoch 125/200, Loss: 4.155201156934102
        Epoch 126/200, Loss: 4.092670718828837
        Epoch 127/200, Loss: 4.126075228055318
        Epoch 128/200, Loss: 3.9372846682866416
        Epoch 129/200, Loss: 4.006311893463135
        Epoch 130/200, Loss: 3.97225828965505
        Epoch 131/200, Loss: 4.043377121289571
        Epoch 132/200, Loss: 3.963453729947408
        Epoch 133/200, Loss: 4.0426625808080034
        Epoch 134/200, Loss: 4.106358130772908
        Epoch 135/200, Loss: 3.9813795487085977
        Epoch 136/200, Loss: 4.067284067471822
        Epoch 137/200, Loss: 4.043168147404988
        Epoch 138/200, Loss: 4.097525874773662
        Epoch 139/200, Loss: 4.050883928934733
        Epoch 140/200, Loss: 3.9369770685831704
        Epoch 141/200, Loss: 4.224425673484802
        Epoch 142/200, Loss: 4.015242218971252
        Epoch 143/200, Loss: 4.041372021039327
        Epoch 144/200, Loss: 4.017487049102783
        Epoch 145/200, Loss: 3.980065027872721
        Epoch 146/200, Loss: 4.056914567947388
        Epoch 147/200, Loss: 4.079793691635132
        Epoch 148/200, Loss: 3.979617436726888
        Epoch 149/200, Loss: 4.1749982436498
        Epoch 150/200, Loss: 3.9954327742258706
        Epoch 151/200, Loss: 4.022652904192607
        Epoch 152/200, Loss: 3.9408562580744424
        Epoch 153/200, Loss: 4.037669062614441
        Epoch 154/200, Loss: 4.047243634859721
        Epoch 155/200, Loss: 3.980173707008362
        Epoch 156/200, Loss: 4.063587745030721
        Epoch 157/200, Loss: 4.06894322236379
        Epoch 158/200, Loss: 4.015638550122579
        Epoch 159/200, Loss: 4.108832081158956
        Epoch 160/200, Loss: 4.0309997002283735
        Epoch 161/200, Loss: 3.958363135655721
        Epoch 162/200, Loss: 4.123100161552429
        Epoch 163/200, Loss: 3.975089430809021
        Epoch 164/200, Loss: 3.9837025006612143
        Epoch 165/200, Loss: 3.9930237929026284
        Epoch 166/200, Loss: 3.996652682622274
        Epoch 167/200, Loss: 4.074909329414368
        Epoch 168/200, Loss: 4.063650488853455
        Epoch 169/200, Loss: 4.0290287733078
        Epoch 170/200, Loss: 3.9503660599390664
        Epoch 171/200, Loss: 4.045772711435954
        Epoch 172/200, Loss: 4.0188307762146
        Epoch 173/200, Loss: 3.957195202509562
        Epoch 174/200, Loss: 3.9027921756108603
        Epoch 175/200, Loss: 4.0114660660425825
        Epoch 176/200, Loss: 4.036511381467183
        Epoch 177/200, Loss: 3.9942683378855386
        Epoch 178/200, Loss: 4.098995606104533
        Epoch 179/200, Loss: 4.001423319180806
        Epoch 180/200, Loss: 4.006581862767537
        Epoch 181/200, Loss: 4.043489535649617
        Epoch 182/200, Loss: 3.961249510447184
        Epoch 183/200, Loss: 4.109455664952596
        Epoch 184/200, Loss: 3.9898978074391684
        Epoch 185/200, Loss: 3.92715060710907
        Epoch 186/200, Loss: 3.972953756650289
        Epoch 187/200, Loss: 3.981200019518534
        Epoch 188/200, Loss: 3.9655960400899253
        Epoch 189/200, Loss: 4.015636165936788
        Epoch 190/200, Loss: 3.9372419118881226
        Epoch 191/200, Loss: 4.073638478914897
        Epoch 192/200, Loss: 4.013903776804606
        Epoch 193/200, Loss: 4.215739568074544
        Epoch 194/200, Loss: 4.082699139912923
        Epoch 195/200, Loss: 4.167884826660156
        Epoch 196/200, Loss: 4.049333214759827
        Epoch 197/200, Loss: 3.894223690032959
        Epoch 198/200, Loss: 3.920265475908915
        Epoch 199/200, Loss: 4.0980643431345625
        Epoch 200/200, Loss: 3.950065771738688"""
        
output_yolo_kp_angle_scorer = output_yolo_kp_angle_scorer.split("\n")
output_yolo_kp_angle_scorer = [float(x.split(": ")[1]) for x in output_yolo_kp_angle_scorer]
output_yolo_kp_angle_scorer = np.array(output_yolo_kp_angle_scorer)

plt.figure(figsize=(10,5))

plt.title("YOLO as Keypoint Detector + Calculated Angles with Keypoints for Scorer Train Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.plot(output_yolo_kp_angle_scorer)

# %%
output_yolo_finetuning_classifier = """Epoch 1/100, Loss: 596.3466152758975
        Epoch 2/100, Loss: 413.26326055903183
        Epoch 3/100, Loss: 291.17308353305253
        Epoch 4/100, Loss: 210.93619030996373
        Epoch 5/100, Loss: 108.99830118081935
        Epoch 6/100, Loss: 32.79658967213463
        Epoch 7/100, Loss: 1.1482165157794952
        Epoch 8/100, Loss: 1.0954126031775224
        Epoch 9/100, Loss: 1.0951145347795987
        Epoch 10/100, Loss: 1.0945170364881818
        Epoch 11/100, Loss: 1.0938329106882998
        Epoch 12/100, Loss: 2.3863540304776842
        Epoch 13/100, Loss: 1.0935362953888743
        Epoch 14/100, Loss: 1.093220325520164
        Epoch 15/100, Loss: 1.092881841408579
        Epoch 16/100, Loss: 1.0925839348843223
        Epoch 17/100, Loss: 1.0924056266483508
        Epoch 18/100, Loss: 1.0923102265910098
        Epoch 19/100, Loss: 1.0922410839482357
        Epoch 20/100, Loss: 1.0924587965011596
        Epoch 21/100, Loss: 1.091531249096519
        Epoch 22/100, Loss: 1.091374875369825
        Epoch 23/100, Loss: 1.0911536605734573
        Epoch 24/100, Loss: 1.0913041478709171
        Epoch 25/100, Loss: 1.0909645419371756
        Epoch 26/100, Loss: 1.0906797020058883
        Epoch 27/100, Loss: 1.0904540770932247
        Epoch 28/100, Loss: 1.0905370574248465
        Epoch 29/100, Loss: 1.0907651449504652
        Epoch 30/100, Loss: 1.0900208812010916
        Epoch 31/100, Loss: 1.0900680378863685
        Epoch 32/100, Loss: 1.0900025581058703
        Epoch 33/100, Loss: 1.0900650626734683
        Epoch 34/100, Loss: 1.0898285250914723
        Epoch 35/100, Loss: 1.0896445117498699
        Epoch 36/100, Loss: 1.0897471139305517
        Epoch 37/100, Loss: 1.089700094022249
        Epoch 38/100, Loss: 1.089618578710054
        Epoch 39/100, Loss: 1.0893570642722281
        Epoch 40/100, Loss: 1.0897135420849449
        Epoch 41/100, Loss: 1.0894870243574444
        Epoch 42/100, Loss: 1.089385567840777
        Epoch 43/100, Loss: 1.0891775833932977
        Epoch 44/100, Loss: 1.0894088337295933
        Epoch 45/100, Loss: 1.0896284442198905
        Epoch 46/100, Loss: 1.0895136500659741
        Epoch 47/100, Loss: 1.0889637896889135
        Epoch 48/100, Loss: 1.0886209205577249
        Epoch 49/100, Loss: 1.089280058208265
        Epoch 50/100, Loss: 1.0887356174619574
        Epoch 51/100, Loss: 1.0886149663674205
        Epoch 52/100, Loss: 1.0888869781243173
        Epoch 53/100, Loss: 1.0889366777319658
        Epoch 54/100, Loss: 1.0892220396744579
        Epoch 55/100, Loss: 1.0887015530937596
        Epoch 56/100, Loss: 1.0884976462314004
        Epoch 57/100, Loss: 1.0886601059060348
        Epoch 58/100, Loss: 1.089114056762896
        Epoch 59/100, Loss: 1.0883119382356343
        Epoch 60/100, Loss: 1.0889366927899813
        Epoch 61/100, Loss: 1.0889121607730263
        Epoch 62/100, Loss: 1.0886799304108872
        Epoch 63/100, Loss: 1.0888768070622494
        Epoch 64/100, Loss: 1.0885006754021895
        Epoch 65/100, Loss: 1.0886737014117993
        Epoch 66/100, Loss: 1.0885996768349095
        Epoch 67/100, Loss: 1.08832585811615
        Epoch 68/100, Loss: 1.0889891630724857
        Epoch 69/100, Loss: 1.08819828096189
        Epoch 70/100, Loss: 1.0888070213167291
        Epoch 71/100, Loss: 1.0885787581142625
        Epoch 72/100, Loss: 1.0881005851845993
        Epoch 73/100, Loss: 1.088556856858103
        Epoch 74/100, Loss: 1.0886931827193813
        Epoch 75/100, Loss: 1.0891240270514237
        Epoch 76/100, Loss: 1.0881185136343303
        Epoch 77/100, Loss: 1.0881752754512586
        Epoch 78/100, Loss: 1.0886400856469807
        Epoch 79/100, Loss: 1.0885550749929327
        Epoch 80/100, Loss: 1.088283360004425
        Epoch 81/100, Loss: 1.0882359385490417
        Epoch 82/100, Loss: 1.0882998460217526
        Epoch 83/100, Loss: 1.0886448922910188
        Epoch 84/100, Loss: 1.0887338625757317
        Epoch 85/100, Loss: 1.088698207077227
        Epoch 86/100, Loss: 1.0883437972319754
        Epoch 87/100, Loss: 1.0886069573854145
        Epoch 88/100, Loss: 1.088475975864812
        Epoch 89/100, Loss: 1.0878600961283633
        Epoch 90/100, Loss: 1.0883057148833024
        Epoch 91/100, Loss: 1.0883820395720631
        Epoch 92/100, Loss: 1.0882131036959197
        Epoch 93/100, Loss: 1.0881353052038896
        Epoch 94/100, Loss: 1.0881876230239869
        Epoch 95/100, Loss: 1.088344062629499
        Epoch 96/100, Loss: 1.0884518278272528
        Epoch 97/100, Loss: 1.0884414302675347
        Epoch 98/100, Loss: 1.0886765705911736
        Epoch 99/100, Loss: 1.08864279483494
        Epoch 100/100, Loss: 1.0882219107527482"""
        
output_yolo_finetuning_classifier = output_yolo_finetuning_classifier.split("\n")
output_yolo_finetuning_classifier = [float(x.split(": ")[1]) for x in output_yolo_finetuning_classifier]
output_yolo_finetuning_classifier = np.array(output_yolo_finetuning_classifier)

plt.figure(figsize=(10,5))

plt.title("YOLO Finetuning for Classifier Train Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.plot(output_yolo_finetuning_classifier)
