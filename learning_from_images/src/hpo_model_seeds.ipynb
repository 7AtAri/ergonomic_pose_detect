# %% [markdown]
# # Ergonomic pose fine-tuning:

# %% [markdown]
# ## Seed Hyperparameter Optimization

# %%
from mmpose.apis import MMPoseInferencer
from ultralytics import YOLO
import numpy as np
from PIL import Image
import torch
from functools import partial
from torch.utils.data import random_split, DataLoader, Subset, TensorDataset
from torchvision import datasets, transforms
import cv2
import time

data_path_scores = 'E:/Users/Vipin/Documents/BHT/3. Semester/Learning from images/Pose Dataset Complete'
data_path_grouped = 'E:/Users/Vipin/Documents/BHT/3. Semester/Learning from images/Pose Dataset_binned'

yolo_kp_params_classifier = {'lr': 0.0001, 'h1': 512, 'h2': 1024, 'batch_size': 4, 'num_epochs': 300}
yolo_kp_params_scorer = {'lr': 0.001, 'h1': 256, 'h2': 256, 'batch_size': 16, 'num_epochs': 200}
mmpose_kp_params_classifier = {'lr': 0.001, 'h1': 1024, 'h2': 512, 'batch_size': 16, 'num_epochs': 100}
mmpose_kp_params_scorer = {'lr': 5e-05, 'h1': 512, 'h2': 1024, 'batch_size': 4, 'num_epochs': 200}

def set_seed(seed):
    torch.manual_seed(seed) 
    np.random.seed(seed)
    torch.use_deterministic_algorithms(True)
    torch.backends.cudnn.benchmark = True
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.enabled = True

# %%
def get_device():
    if torch.cuda.is_available():
        return torch.device("cuda")
    elif torch.backends.mps.is_available():
        return torch.device("mps")
    else:
        return torch.device("cpu")
    
get_device()
# Out:
# device(type='cuda')

# %%
class PILToNumpyTransform:
    def __call__(self, pil_img):
        """
        Convert a PIL Image to an OpenCV Image / Numpy Array.

        Parameters:
            pil_img (PIL.Image): The PIL Image to be converted.

        Returns:
            np.ndarray: The converted OpenCV Image in RGB format.
        """
        # Convert PIL Image to NumPy array (RGB)
        img_array = np.array(pil_img)
        img_array = cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB)

        return img_array

data_transforms = transforms.Compose([
    transforms.Resize((480, 640)), # Resize images to (480, 640)
    transforms.ToTensor(), # Convert images to PyTorch tensors
])

own_dataset_scores = datasets.ImageFolder(root=data_path_scores, transform=data_transforms)
display(own_dataset_scores)
own_dataset_grouped = datasets.ImageFolder(root=data_path_grouped, transform=data_transforms)
display(own_dataset_grouped)
# Out:
# Dataset ImageFolder
#     Number of datapoints: 118
#     Root location: E:/Users/Vipin/Documents/BHT/3. Semester/Learning from images/Pose Dataset Complete
#     StandardTransform
# Transform: Compose(
#                Resize(size=(480, 640), interpolation=bilinear, max_size=None, antialias=True)
#                ToTensor()
#            )
# Dataset ImageFolder
#     Number of datapoints: 118
#     Root location: E:/Users/Vipin/Documents/BHT/3. Semester/Learning from images/Pose Dataset_binned
#     StandardTransform
# Transform: Compose(
#                Resize(size=(480, 640), interpolation=bilinear, max_size=None, antialias=True)
#                ToTensor()
#            )

# %%
generator1 = torch.Generator().manual_seed(13)  # set seed for reproducibility of the split
train_and_val_dataset_scores, test_dataset_scores = random_split(own_dataset_scores, [0.8, 0.2], generator=generator1)  # 80% training and evaluation, 20% testing

train_and_val_dataset_grouped, test_dataset_grouped = random_split(own_dataset_grouped, [0.8, 0.2], generator=generator1)  # 80% training and evaluation, 20% testing

# %% [markdown]
# ### Define the models

# %%
import torch
import torch.nn as nn

class KeypointClassifier(nn.Module):
    def __init__(self, num_keypoints, num_classes, h1, h2):
        super(KeypointClassifier, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Linear(num_keypoints*2, h1),
            nn.ReLU(),
            nn.Dropout(0.5)
        )
        self.layer2 = nn.Sequential(
            nn.Linear(h1, h2),
            nn.ReLU(),
            nn.Dropout(0.5)
        )
        self.layer3 = nn.Sequential(
            nn.Linear(h2, h2 // 2),
            nn.ReLU()
        )
        self.dense = nn.Sequential(
            nn.Linear(h2 // 2, num_classes)
        )
    
    def forward(self, keypoints_flattened):
        x = self.layer1(keypoints_flattened)
        x = self.layer2(x)
        x = self.layer3(x)
        output = self.dense(x)
        
        return output

class KeypointScorer(nn.Module):
    def __init__(self, num_keypoints, h1, h2):
        super(KeypointScorer, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Linear(num_keypoints*2, h1),
            nn.ReLU(),
            nn.Dropout(0.5)
        )
        self.layer2 = nn.Sequential(
            nn.Linear(h1, h2),
            nn.ReLU(),
            nn.Dropout(0.5)
        )
        self.layer3 = nn.Sequential(
            nn.Linear(h2, h2 // 2),
            nn.ReLU()
        )
        self.dense = nn.Sequential(
            nn.Linear(h2 // 2, 1)
        )
    
    def forward(self, keypoints_flattened):
        x = self.layer1(keypoints_flattened)
        x = self.layer2(x)
        x = self.layer3(x)
        output = self.dense(x)
        
        return output

# %%
def tensor_to_cv2_image(tensor):
    """
    Converts a PyTorch tensor to an OpenCV image.
    
    Parameters:
    - tensor: A PyTorch tensor, in the format CxHxW with values normalized to [0, 1].
    
    Returns:
    - An OpenCV image, in BGR format.
    """
    
    # Denormalize the tensor and convert it to a numpy array
    image = tensor.mul(255).byte().permute(2, 1, 0).cpu().numpy()
    image = np.fliplr(image)
    
    # Convert the color space from RGB to BGR
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    
    return image


def get_keypoints_from_mmpose(model, inputs):
    with torch.no_grad(): # gradients are not computed for the frozen model
        results = []
        for input in inputs:
            start_time = time.perf_counter()
            
            cv2_img = tensor_to_cv2_image(input)
            result = list(next(model(cv2_img, show=False)).values())
            keypoints = result[1][0][0]['keypoints']
            
            ellapsed_time_ms = (time.perf_counter() - start_time) * 1000
            print(f"Image processed in {ellapsed_time_ms:.2f} ms")
            results.append(torch.tensor(keypoints))
    return torch.stack(results)

def get_keypoints_from_yolo(yolo_model, inputs):
    with torch.no_grad():
        results = []
        for input in inputs:
            result = yolo_model(input.unsqueeze(0))[0].keypoints.xy[0].to(input.device)
            if result.shape[0] < 17:
                result = torch.cat([result, torch.zeros(17 - result.shape[0], 2).to(input.device)], dim = 0)
            
            results.append(result)
    return torch.stack(results)

# %% [markdown]
# processing keypoints:

# %%
# z-Value
def process_keypoints_for_model(keypoints):
    # Calculate mean and standard deviation with keepdim=True to preserve broadcasting compatibility
    mean_vals = keypoints.mean(dim=1, keepdim=True)
    std_vals = keypoints.std(dim=1, keepdim=True) + 1e-6  # Adding a small epsilon to prevent division by zero

    # Perform standardization
    kp_tensor_standardized = (keypoints - mean_vals) / std_vals
    
    # Flatten the last two dimensions while keeping the batch dimension
    batch_flattened = kp_tensor_standardized.view(keypoints.size(0), -1)
    
    return batch_flattened

# %% [markdown]
# #### training the model:
#
# - with cross-entropy loss function (fits our classification task)
# - Adam optimizer

# %% [markdown]
# HPO:

# %%
import optuna
from sklearn.metrics import f1_score, confusion_matrix
import numpy as np

# %%
def preprocess_dataset(kp_detection_model, kp_detection_func, dataset, device):
    processed_keypoints_list = []
    labels_list = []
    
    dataloader = DataLoader(dataset, batch_size=1, shuffle=False)
    
    # Assuming `dataset` is an iterable of (input, label) pairs
    for inputs, labels in dataloader:
        inputs = inputs.to(device)
        keypoints = kp_detection_func(kp_detection_model, inputs)  # Extract keypoints        
        processed_kps = process_keypoints_for_model(keypoints)  # Process keypoints        
        processed_keypoints_list.append(processed_kps)
        labels_list.append(labels)

    # Convert lists to tensors
    processed_keypoints_tensor = torch.cat(processed_keypoints_list, dim=0)
    labels_tensor = torch.cat(labels_list, dim=0)
    
    # Create a new TensorDataset and DataLoader
    preprocessed_dataset = TensorDataset(processed_keypoints_tensor, labels_tensor)
    
    return preprocessed_dataset
    
def train_and_eval_model(kp_model, optimizer, loss_fn, num_epochs, train_loader, val_loader, device):
    
    kp_model = kp_model.to(device)  # move model to device
    kp_model.train()  # set model to training mode
    
    print("type of train_loader", type(train_loader))

    for epoch in range(num_epochs):
        for batch in train_loader:
            # access images and labels
            inputs = batch[0].to(device)
            labels = batch[1].to(device)
            
            optimizer.zero_grad()  # Zero the parameter gradients
            classification_output = kp_model(inputs) # get results for the classification
            
            # Use this for classification
            # loss = loss_fn(classification_output, labels)
            
            # Use this for scoring
            loss = loss_fn(classification_output.float(), labels.float())
            
            loss.backward()  # Backpropagate the loss
            optimizer.step()  # Update weights

            # todo: further processing, such as calculating accuracy or loss, goes here

        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')
            
        
        kp_model.eval()  # model to evaluation mode

        total_loss = 0
        all_predictions = []
        all_labels = []

        with torch.no_grad():  # no need to compute gradients, because we are in evaluation mode
            for inputs, labels in val_loader:  # iterate over validation dataset
                inputs, labels = inputs.to(device), labels.to(device)  # move data to device
                
                # Not necessary because already preprocessed
                # keypoints = get_keypoints_from_yolo(yolo_model, inputs) # get keypoints from the YOLO model
                # processed_kps = process_keypoints_for_classifier(keypoints) # prepare the keypoints for the classifier
                
                classification_output = kp_model(inputs) # get results for the classification 
                
                # Use this for classification
                # loss = loss_fn(classification_output, labels)
                
                # Use this for scoring
                loss = loss_fn(classification_output.float(), labels.float())
                
                total_loss += loss.item()  # accumulate the loss
                # get predictions for output
                _, predicted = torch.max(classification_output.data, 1)
                # collect the predictions and labels
                all_predictions.extend(predicted.cpu().numpy())
                all_labels.extend(labels.cpu().numpy())
            # calculate the validation metrics:
            avg_loss = total_loss / len(val_loader)  # get the average loss
            # accuracy = (np.array(all_predictions) == np.array(all_labels)).mean()
            # f1 = f1_score(all_labels, all_predictions, average='weighted')  
            # conf_matrix = confusion_matrix(all_labels, all_predictions)
            
            print(f"Validation Loss: {avg_loss:.4f}")
            # print(f"Validation Accuracy: {accuracy:.4f}")
            # print(f"Validation F1 Score: {f1:.4f}")
            # print("Confusion Matrix:")
            # print(conf_matrix)
            
            # here: F1 score chosen as the metric to optimize
            # other options: - combining metrics like accuracy and F1 score to maximize on both
            #                        - or multi-objective optimization on F1 score and accuracy
    return avg_loss

# %%
# this function was generated by gpt-4

def get_k_fold_indices(n, k=5, random_seed=None):
    """
    Generate indices for k-fold cross-validation.

    Parameters:
    - n: Total number of samples in the dataset.
    - k: Number of folds.
    - random_seed: Optional seed for reproducibility.

    Returns:
    - A list of tuples, each containing (train_indices, val_indices) for a fold.
    """
    # Initialize the random generator
    g = torch.Generator()
    if random_seed is not None:
        g.manual_seed(random_seed)
    
    # Generate a random permutation of indices
    indices = torch.randperm(n, generator=g).tolist()
    
    # Calculate fold sizes
    fold_sizes = [n // k for _ in range(k)]
    for i in range(n % k):
        fold_sizes[i] += 1
    
    # Generate train and validation indices for each fold
    current = 0
    folds_indices = []
    for fold_size in fold_sizes:
        start, end = current, current + fold_size
        val_indices = indices[start:end]
        train_indices = indices[:start] + indices[end:]
        folds_indices.append((train_indices, val_indices))
        current = end
    
    return folds_indices

# %%
def objective(trial, params, dataset, num_keypoints, num_classes):
    # Define hyperparameters to optimize
    lr = params["lr"]
    h1 = params["h1"]
    h2 = params["h2"]
    batch_size = params["batch_size"]
    num_epochs = params["num_epochs"]
    seed = trial.suggest_categorical("seed", [13, 23, 42, 2000, 1986])

    validation_scores = []

    n = len(dataset)
    k = 5
    folds_indices = get_k_fold_indices(n, k, random_seed=13)
    device = get_device()
    
    set_seed(seed)
    
    for fold, (train_idx, val_idx) in enumerate(folds_indices, start=1):
        print(f"Trial {trial.number}, Fold {fold}/{k}")
        train_subset = Subset(dataset, train_idx)
        val_subset = Subset(dataset, val_idx)
        
        # Create data loaders for training and validation
        train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
        val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False)
        
        # Initializing the model and optimizer with the chosen hyperparameters
        kp_model = KeypointScorer(num_keypoints, h1, h2).to(device)
        # kp_model = KeypointClassifier(num_keypoints=num_keypoints, num_classes=num_classes, h1=h1, h2=h2).to(device)
        optimizer = torch.optim.Adam(kp_model.parameters(), lr=lr, weight_decay=1e-5)
    
        # training and evaluating the model - Watch out for the Loss - CrossEntropyLoss for classification and MSELoss for scoring
        validation_score = train_and_eval_model(kp_model, optimizer, nn.MSELoss(), num_epochs, train_loader, val_loader, device)
        validation_scores.append(validation_score)

    return np.mean(validation_scores)

# %%
print(yolo_kp_params_classifier)
print(yolo_kp_params_scorer)
print(mmpose_kp_params_classifier)
print(mmpose_kp_params_scorer)
# Out:
# {'lr': 0.0001, 'h1': 512, 'h2': 1024, 'batch_size': 4, 'num_epochs': 300}
# {'lr': 0.001, 'h1': 256, 'h2': 256, 'batch_size': 16, 'num_epochs': 200}
# {'lr': 0.001, 'h1': 1024, 'h2': 512, 'batch_size': 16, 'num_epochs': 100}
# {'lr': 5e-05, 'h1': 512, 'h2': 1024, 'batch_size': 4, 'num_epochs': 200}

# %%
mmpose_model = MMPoseInferencer('rtmw-m_8xb1024-270e_cocktail14-256x192')
yolo_model = YOLO('yolov8n-pose.pt')
preprocessed_dataset = preprocess_dataset(mmpose_model, get_keypoints_from_mmpose, train_and_val_dataset_grouped, get_device())
optimize = partial(objective, params = mmpose_kp_params_scorer, dataset = preprocessed_dataset, num_keypoints = 133, num_classes = 3)
search_space = {
    "seed" : [13, 23, 42, 2000, 1986]
}

study = optuna.create_study(sampler=optuna.samplers.GridSampler(search_space), direction='minimize')
study.optimize(optimize, n_trials=5)

# Best hyperparameters
print("Best hyperparameters:", study.best_params)
# Out:
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmpose/v1/projects/rtmw/rtmw-dw-l-m_simcc-cocktail14_270e-256x192-20231122.pth
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmpose/v1/projects/rtmposev1/rtmdet_m_8xb32-100e_coco-obj365-person-235e8209.pth
# Image processed in 57.21 ms
# Image processed in 52.74 ms
# Image processed in 58.17 ms
# Image processed in 58.81 ms
# Image processed in 57.61 ms
# Image processed in 56.05 ms
# Image processed in 56.89 ms
# Image processed in 54.54 ms
# Image processed in 56.29 ms
# Image processed in 57.44 ms
# Image processed in 58.57 ms
# Image processed in 58.83 ms
# Image processed in 61.39 ms
# Image processed in 58.46 ms
# Image processed in 58.16 ms
# Image processed in 58.24 ms
# Image processed in 59.02 ms
# Image processed in 54.46 ms
# Image processed in 59.20 ms
# Image processed in 58.30 ms
# Image processed in 55.78 ms
# Image processed in 54.65 ms
# Image processed in 54.29 ms
# Image processed in 55.82 ms
# Image processed in 63.05 ms
# Image processed in 56.82 ms
# Image processed in 59.20 ms
# Image processed in 57.62 ms
# Image processed in 56.20 ms
# Image processed in 54.70 ms
# Image processed in 57.40 ms
# Image processed in 60.37 ms
# Image processed in 58.23 ms
# Image processed in 60.10 ms
# Image processed in 57.69 ms
# Image processed in 55.01 ms
# Image processed in 57.60 ms
# Image processed in 59.03 ms
# Image processed in 57.90 ms
# Image processed in 52.06 ms
# Image processed in 56.70 ms
# Image processed in 58.73 ms
# Image processed in 55.48 ms
# Image processed in 58.21 ms
# Image processed in 54.75 ms
# Image processed in 57.72 ms
# Image processed in 54.76 ms
# Image processed in 58.32 ms
# Image processed in 54.46 ms
# Image processed in 56.96 ms
# Image processed in 58.32 ms
# Image processed in 59.55 ms
# Image processed in 59.71 ms
# Image processed in 54.02 ms
# Image processed in 57.42 ms
# Image processed in 56.05 ms
# Image processed in 60.04 ms
# Image processed in 58.53 ms
# Image processed in 54.36 ms
# Image processed in 56.18 ms
# Image processed in 53.27 ms
# Image processed in 54.56 ms
# Image processed in 60.18 ms
# Image processed in 57.38 ms
# Image processed in 56.92 ms
# Image processed in 56.09 ms
# Image processed in 56.63 ms
# Image processed in 57.76 ms
# Image processed in 55.79 ms
# Image processed in 58.88 ms
# Image processed in 57.38 ms
# Image processed in 58.16 ms
# Image processed in 56.02 ms
# Image processed in 60.02 ms
# Image processed in 59.53 ms
# Image processed in 57.93 ms
# Image processed in 61.01 ms
# Image processed in 57.07 ms
# Image processed in 58.93 ms
# Image processed in 60.29 ms
# Image processed in 53.89 ms
# Image processed in 53.91 ms
# Image processed in 53.23 ms
# Image processed in 54.97 ms
# Image processed in 56.80 ms
# Image processed in 55.02 ms
# Image processed in 58.30 ms
# Image processed in 57.37 ms
# Image processed in 57.90 ms
# Image processed in 61.98 ms
# Image processed in 64.48 ms
# Image processed in 59.41 ms
# Image processed in 65.68 ms
# Image processed in 57.25 ms
# [I 2024-03-24 14:56:04,509] A new study created in memory with name: no-name-24fc9785-f352-4752-a81b-f2a52f3ad604
# e:\Users\Vipin\Documents\BHT\3. Semester\Learning from images\ergonomic_pose_detect\.venv\lib\site-packages\torch\nn\modules\loss.py:535: UserWarning: Using a target size (torch.Size([4])) that is different to the input size (torch.Size([4, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# e:\Users\Vipin\Documents\BHT\3. Semester\Learning from images\ergonomic_pose_detect\.venv\lib\site-packages\torch\nn\modules\loss.py:535: UserWarning: Using a target size (torch.Size([3])) that is different to the input size (torch.Size([3, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Image processed in 60.59 ms
# Trial 0, Fold 1/5
# type of train_loader <class 'torch.utils.data.dataloader.DataLoader'>
# Epoch [1/200], Loss: 0.2181
# Validation Loss: 1.1818
# Epoch [2/200], Loss: 1.0941
# Validation Loss: 0.5936
# Epoch [3/200], Loss: 0.7305
# Validation Loss: 0.5773
# Epoch [4/200], Loss: 0.9800
# Validation Loss: 0.6427
# Epoch [5/200], Loss: 0.8264
# Validation Loss: 0.5756
# Epoch [6/200], Loss: 1.1656
# Validation Loss: 0.5655
# Epoch [7/200], Loss: 0.5080
# Validation Loss: 0.6152
# Epoch [8/200], Loss: 0.7013
# Validation Loss: 0.5827
# Epoch [9/200], Loss: 0.6209
# Validation Loss: 0.6121
# Epoch [10/200], Loss: 0.4793
# Validation Loss: 0.5794
# Epoch [11/200], Loss: 0.2412
# Validation Loss: 0.5849
# Epoch [12/200], Loss: 1.0139
# Validation Loss: 0.6128
# Epoch [13/200], Loss: 0.3620
# Validation Loss: 0.5961
# Epoch [14/200], Loss: 0.2910
# Validation Loss: 0.5842
# Epoch [15/200], Loss: 1.0111
# Validation Loss: 0.5994
# Epoch [16/200], Loss: 0.7277
# Validation Loss: 0.6241
# Epoch [17/200], Loss: 0.8474
# Validation Loss: 0.5631
# Epoch [18/200], Loss: 1.0268
# Validation Loss: 0.6604
# Epoch [19/200], Loss: 0.7365
# Validation Loss: 0.5732
# Epoch [20/200], Loss: 0.7232
# Validation Loss: 0.6072
# Epoch [21/200], Loss: 0.4192
# Validation Loss: 0.6056
# Epoch [22/200], Loss: 1.0128
# Validation Loss: 0.5991
# Epoch [23/200], Loss: 0.5274
# Validation Loss: 0.5764
# Epoch [24/200], Loss: 0.5205
# Validation Loss: 0.5889
# Epoch [25/200], Loss: 1.0171
# Validation Loss: 0.5813
# Epoch [26/200], Loss: 0.5933
# Validation Loss: 0.5522
# Epoch [27/200], Loss: 0.3013
# Validation Loss: 0.5948
# Epoch [28/200], Loss: 0.9654
# Validation Loss: 0.5891
# Epoch [29/200], Loss: 0.8132
# Validation Loss: 0.5826
# Epoch [30/200], Loss: 0.7419
# Validation Loss: 0.5668
# Epoch [31/200], Loss: 0.3773
# Validation Loss: 0.5672
# Epoch [32/200], Loss: 0.7864
# Validation Loss: 0.5902
# Epoch [33/200], Loss: 0.3723
# Validation Loss: 0.5903
# Epoch [34/200], Loss: 0.2376
# Validation Loss: 0.5785
# Epoch [35/200], Loss: 0.4340
# Validation Loss: 0.6135
# Epoch [36/200], Loss: 0.7575
# Validation Loss: 0.5776
# Epoch [37/200], Loss: 0.9102
# Validation Loss: 0.5822
# Epoch [38/200], Loss: 0.1997
# Validation Loss: 0.5854
# Epoch [39/200], Loss: 1.0327
# Validation Loss: 0.6157
# Epoch [40/200], Loss: 0.6983
# Validation Loss: 0.6293
# Epoch [41/200], Loss: 0.9035
# Validation Loss: 0.5839
# Epoch [42/200], Loss: 0.5077
# Validation Loss: 0.5875
# Epoch [43/200], Loss: 0.7989
# Validation Loss: 0.5891
# Epoch [44/200], Loss: 0.7793
# Validation Loss: 0.6042
# Epoch [45/200], Loss: 0.7435
# Validation Loss: 0.6217
# Epoch [46/200], Loss: 0.4397
# Validation Loss: 0.5823
# Epoch [47/200], Loss: 0.2239
# Validation Loss: 0.5995
# Epoch [48/200], Loss: 0.4419
# Validation Loss: 0.6034
# Epoch [49/200], Loss: 0.7097
# Validation Loss: 0.5545
# Epoch [50/200], Loss: 0.9322
# Validation Loss: 0.5758
# Epoch [51/200], Loss: 1.0301
# Validation Loss: 0.6098
# Epoch [52/200], Loss: 0.4734
# Validation Loss: 0.5872
# Epoch [53/200], Loss: 0.8702
# Validation Loss: 0.6211
# Epoch [54/200], Loss: 0.7382
# Validation Loss: 0.5977
# Epoch [55/200], Loss: 0.4252
# Validation Loss: 0.6010
# Epoch [56/200], Loss: 0.2347
# Validation Loss: 0.5830
# Epoch [57/200], Loss: 0.7329
# Validation Loss: 0.6081
# Epoch [58/200], Loss: 0.4194
# Validation Loss: 0.5792
# Epoch [59/200], Loss: 0.3248
# Validation Loss: 0.5578
# Epoch [60/200], Loss: 0.7404
# Validation Loss: 0.5948
# Epoch [61/200], Loss: 0.3926
# Validation Loss: 0.6034
# Epoch [62/200], Loss: 0.3867
# Validation Loss: 0.5847
# Epoch [63/200], Loss: 1.0393
# Validation Loss: 0.5491
# Epoch [64/200], Loss: 0.9177
# Validation Loss: 0.5951
# Epoch [65/200], Loss: 0.5329
# Validation Loss: 0.5431
# Epoch [66/200], Loss: 0.7598
# Validation Loss: 0.6000
# Epoch [67/200], Loss: 0.2124
# Validation Loss: 0.5926
# Epoch [68/200], Loss: 1.0878
# Validation Loss: 0.5857
# Epoch [69/200], Loss: 0.5259
# Validation Loss: 0.5816
# Epoch [70/200], Loss: 0.2568
# Validation Loss: 0.6148
# Epoch [71/200], Loss: 0.7836
# Validation Loss: 0.5792
# Epoch [72/200], Loss: 0.9222
# Validation Loss: 0.5996
# Epoch [73/200], Loss: 0.7578
# Validation Loss: 0.6010
# Epoch [74/200], Loss: 1.0708
# Validation Loss: 0.5574
# Epoch [75/200], Loss: 0.5131
# Validation Loss: 0.5908
# Epoch [76/200], Loss: 0.7817
# Validation Loss: 0.6122
# Epoch [77/200], Loss: 0.8372
# Validation Loss: 0.5788
# Epoch [78/200], Loss: 0.5512
# Validation Loss: 0.6048
# Epoch [79/200], Loss: 0.5173
# Validation Loss: 0.5901
# Epoch [80/200], Loss: 0.4665
# Validation Loss: 0.5933
# Epoch [81/200], Loss: 0.3110
# Validation Loss: 0.5490
# Epoch [82/200], Loss: 0.5283
# Validation Loss: 0.5888
# Epoch [83/200], Loss: 0.7298
# Validation Loss: 0.5943
# Epoch [84/200], Loss: 0.5276
# Validation Loss: 0.6315
# Epoch [85/200], Loss: 0.5582
# Validation Loss: 0.6101
# Epoch [86/200], Loss: 0.5127
# Validation Loss: 0.6259
# Epoch [87/200], Loss: 1.0731
# Validation Loss: 0.5651
# Epoch [88/200], Loss: 0.3542
# Validation Loss: 0.5958
# Epoch [89/200], Loss: 0.5258
# Validation Loss: 0.5823
# Epoch [90/200], Loss: 0.6895
# Validation Loss: 0.6164
# Epoch [91/200], Loss: 0.8479
# Validation Loss: 0.5527
# Epoch [92/200], Loss: 1.0062
# Validation Loss: 0.5991
# Epoch [93/200], Loss: 0.2530
# Validation Loss: 0.5925
# Epoch [94/200], Loss: 0.6194
# Validation Loss: 0.5522
# Epoch [95/200], Loss: 0.4395
# Validation Loss: 0.5929
# Epoch [96/200], Loss: 0.7380
# Validation Loss: 0.5500
# Epoch [97/200], Loss: 0.2409
# Validation Loss: 0.5950
# Epoch [98/200], Loss: 0.7602
# Validation Loss: 0.5635
# Epoch [99/200], Loss: 0.3012
# Validation Loss: 0.5390
# Epoch [100/200], Loss: 0.0111
# Validation Loss: 0.5472
# Epoch [101/200], Loss: 0.2283
# Validation Loss: 0.5743
# Epoch [102/200], Loss: 0.7570
# Validation Loss: 0.5820
# Epoch [103/200], Loss: 0.5750
# Validation Loss: 0.5603
# Epoch [104/200], Loss: 0.2487
# Validation Loss: 0.6002
# Epoch [105/200], Loss: 0.9191
# Validation Loss: 0.6073
# Epoch [106/200], Loss: 0.5950
# Validation Loss: 0.5888
# Epoch [107/200], Loss: 0.7673
# Validation Loss: 0.6081
# Epoch [108/200], Loss: 0.6905
# Validation Loss: 0.5581
# Epoch [109/200], Loss: 0.2243
# Validation Loss: 0.6121
# Epoch [110/200], Loss: 0.5172
# Validation Loss: 0.6128
# Epoch [111/200], Loss: 0.7700
# Validation Loss: 0.5978
# Epoch [112/200], Loss: 1.0609
# Validation Loss: 0.5672
# Epoch [113/200], Loss: 0.9067
# Validation Loss: 0.6098
# Epoch [114/200], Loss: 0.4591
# Validation Loss: 0.5721
# Epoch [115/200], Loss: 1.0481
# Validation Loss: 0.5832
# Epoch [116/200], Loss: 0.9081
# Validation Loss: 0.6201
# Epoch [117/200], Loss: 0.5159
# Validation Loss: 0.6097
# Epoch [118/200], Loss: 0.7741
# Validation Loss: 0.5807
# Epoch [119/200], Loss: 0.0087
# Validation Loss: 0.5653
# Epoch [120/200], Loss: 0.5706
# Validation Loss: 0.5448
# Epoch [121/200], Loss: 0.2678
# Validation Loss: 0.6052
# Epoch [122/200], Loss: 0.2120
# Validation Loss: 0.5735
# Epoch [123/200], Loss: 0.8649
# Validation Loss: 0.5383
# Epoch [124/200], Loss: 0.7922
# Validation Loss: 0.5672
# Epoch [125/200], Loss: 0.2207
# Validation Loss: 0.5835
# Epoch [126/200], Loss: 0.4635
# Validation Loss: 0.5750
# Epoch [127/200], Loss: 0.7654
# Validation Loss: 0.6084
# Epoch [128/200], Loss: 0.9323
# Validation Loss: 0.5760
# Epoch [129/200], Loss: 1.0521
# Validation Loss: 0.5581
# Epoch [130/200], Loss: 0.5677
# Validation Loss: 0.5968
# Epoch [131/200], Loss: 0.5135
# Validation Loss: 0.5583
# Epoch [132/200], Loss: 0.5463
# Validation Loss: 0.6044
# Epoch [133/200], Loss: 0.7579
# Validation Loss: 0.5968
# Epoch [134/200], Loss: 0.2346
# Validation Loss: 0.5883
# Epoch [135/200], Loss: 0.9045
# Validation Loss: 0.5880
# Epoch [136/200], Loss: 0.5249
# Validation Loss: 0.5662
# Epoch [137/200], Loss: 0.7399
# Validation Loss: 0.5502
# Epoch [138/200], Loss: 1.0205
# Validation Loss: 0.6042
# Epoch [139/200], Loss: 0.7384
# Validation Loss: 0.5666
# Epoch [140/200], Loss: 0.7192
# Validation Loss: 0.5498
# Epoch [141/200], Loss: 0.7905
# Validation Loss: 0.5689
# Epoch [142/200], Loss: 0.5171
# Validation Loss: 0.5763
# Epoch [143/200], Loss: 0.2811
# Validation Loss: 0.5680
# Epoch [144/200], Loss: 0.2367
# Validation Loss: 0.5755
# Epoch [145/200], Loss: 0.3997
# Validation Loss: 0.5679
# Epoch [146/200], Loss: 0.6636
# Validation Loss: 0.5500
# Epoch [147/200], Loss: 0.9080
# Validation Loss: 0.6032
# Epoch [148/200], Loss: 0.7622
# Validation Loss: 0.5738
# Epoch [149/200], Loss: 0.5370
# Validation Loss: 0.5401
# Epoch [150/200], Loss: 0.2421
# Validation Loss: 0.5593
# Epoch [151/200], Loss: 0.5313
# Validation Loss: 0.5844
# Epoch [152/200], Loss: 0.7462
# Validation Loss: 0.5953
# Epoch [153/200], Loss: 0.9885
# Validation Loss: 0.6012
# Epoch [154/200], Loss: 0.0090
# Validation Loss: 0.5532
# Epoch [155/200], Loss: 0.7756
# Validation Loss: 0.5988
# Epoch [156/200], Loss: 0.4293
# Validation Loss: 0.5654
# Epoch [157/200], Loss: 0.7697
# Validation Loss: 0.5585
# Epoch [158/200], Loss: 0.7499
# Validation Loss: 0.5592
# Epoch [159/200], Loss: 0.7335
# Validation Loss: 0.6047
# Epoch [160/200], Loss: 1.0418
# Validation Loss: 0.5520
# Epoch [161/200], Loss: 0.7611
# Validation Loss: 0.5673
# Epoch [162/200], Loss: 0.5349
# Validation Loss: 0.5843
# Epoch [163/200], Loss: 0.6808
# Validation Loss: 0.5431
# Epoch [164/200], Loss: 0.2709
# Validation Loss: 0.6236
# Epoch [165/200], Loss: 0.5425
# Validation Loss: 0.5456
# Epoch [166/200], Loss: 0.7945
# Validation Loss: 0.5586
# Epoch [167/200], Loss: 0.6337
# Validation Loss: 0.5571
# Epoch [168/200], Loss: 0.2232
# Validation Loss: 0.5932
# Epoch [169/200], Loss: 0.5899
# Validation Loss: 0.6119
# Epoch [170/200], Loss: 0.3238
# Validation Loss: 0.5500
# Epoch [171/200], Loss: 0.4827
# Validation Loss: 0.5581
# Epoch [172/200], Loss: 0.5213
# Validation Loss: 0.5905
# Epoch [173/200], Loss: 0.7969
# Validation Loss: 0.5538
# Epoch [174/200], Loss: 0.5475
# Validation Loss: 0.5815
# Epoch [175/200], Loss: 0.5313
# Validation Loss: 0.5789
# Epoch [176/200], Loss: 0.4647
# Validation Loss: 0.6004
# Epoch [177/200], Loss: 0.7156
# Validation Loss: 0.5344
# Epoch [178/200], Loss: 0.7394
# Validation Loss: 0.5660
# Epoch [179/200], Loss: 1.0271
# Validation Loss: 0.5806
# Epoch [180/200], Loss: 0.5500
# Validation Loss: 0.5669
# Epoch [181/200], Loss: 0.3461
# Validation Loss: 0.5844
# Epoch [182/200], Loss: 0.3539
# Validation Loss: 0.5909
# Epoch [183/200], Loss: 0.8106
# Validation Loss: 0.5756
# Epoch [184/200], Loss: 0.5485
# Validation Loss: 0.5871
# Epoch [185/200], Loss: 0.9786
# Validation Loss: 0.5533
# Epoch [186/200], Loss: 0.5200
# Validation Loss: 0.6057
# Epoch [187/200], Loss: 0.9169
# Validation Loss: 0.5648
# Epoch [188/200], Loss: 1.0002
# Validation Loss: 0.5424
# Epoch [189/200], Loss: 0.7536
# Validation Loss: 0.5766
# Epoch [190/200], Loss: 1.0767
# Validation Loss: 0.5547
# Epoch [191/200], Loss: 0.0264
# Validation Loss: 0.5674
# Epoch [192/200], Loss: 0.9158
# Validation Loss: 0.5710
# Epoch [193/200], Loss: 0.7278
# Validation Loss: 0.5490
# Epoch [194/200], Loss: 0.4340
# Validation Loss: 0.5706
# Epoch [195/200], Loss: 0.7722
# Validation Loss: 0.5789
# Epoch [196/200], Loss: 0.7525
# Validation Loss: 0.5711
# Epoch [197/200], Loss: 0.5390
# Validation Loss: 0.5816
# Epoch [198/200], Loss: 0.4348
# Validation Loss: 0.5664
# Epoch [199/200], Loss: 1.0561
# Validation Loss: 0.5576
# Epoch [200/200], Loss: 1.0700
# Validation Loss: 0.5808
# Trial 0, Fold 2/5
# type of train_loader <class 'torch.utils.data.dataloader.DataLoader'>
# Epoch [1/200], Loss: 1.3128
# Validation Loss: 1.1992
# Epoch [2/200], Loss: 0.7094
# Validation Loss: 0.6075
# Epoch [3/200], Loss: 0.3989
# Validation Loss: 0.5539
# Epoch [4/200], Loss: 0.4185
# Validation Loss: 0.5770
# Epoch [5/200], Loss: 1.1003
# Validation Loss: 0.6165
# Epoch [6/200], Loss: 0.4958
# Validation Loss: 0.5506
# Epoch [7/200], Loss: 0.0112
# Validation Loss: 0.5790
# Epoch [8/200], Loss: 0.6998
# Validation Loss: 0.5767
# Epoch [9/200], Loss: 0.6304
# Validation Loss: 0.5623
# Epoch [10/200], Loss: 0.5030
# Validation Loss: 0.5759
# Epoch [11/200], Loss: 0.7023
# Validation Loss: 0.5595
# Epoch [12/200], Loss: 0.6421
# Validation Loss: 0.5709
# Epoch [13/200], Loss: 1.0348
# Validation Loss: 0.5481
# Epoch [14/200], Loss: 0.2956
# Validation Loss: 0.5756
# Epoch [15/200], Loss: 0.5338
# Validation Loss: 0.5787
# Epoch [16/200], Loss: 0.2400
# Validation Loss: 0.5712
# Epoch [17/200], Loss: 0.5854
# Validation Loss: 0.5615
# Epoch [18/200], Loss: 0.5220
# Validation Loss: 0.5920
# Epoch [19/200], Loss: 0.7379
# Validation Loss: 0.5982
# Epoch [20/200], Loss: 0.7938
# Validation Loss: 0.5623
# Epoch [21/200], Loss: 0.3000
# Validation Loss: 0.5657
# Epoch [22/200], Loss: 0.5112
# Validation Loss: 0.5821
# Epoch [23/200], Loss: 0.7172
# Validation Loss: 0.5649
# Epoch [24/200], Loss: 0.7442
# Validation Loss: 0.5674
# Epoch [25/200], Loss: 0.8098
# Validation Loss: 0.5908
# Epoch [26/200], Loss: 1.0083
# Validation Loss: 0.5953
# Epoch [27/200], Loss: 0.7366
# Validation Loss: 0.5991
# Epoch [28/200], Loss: 0.7431
# Validation Loss: 0.5873
# Epoch [29/200], Loss: 0.4234
# Validation Loss: 0.5679
# Epoch [30/200], Loss: 0.7354
# Validation Loss: 0.5803
# Epoch [31/200], Loss: 0.7015
# Validation Loss: 0.5624
# Epoch [32/200], Loss: 0.5159
# Validation Loss: 0.5593
# Epoch [33/200], Loss: 0.5839
# Validation Loss: 0.5538
# Epoch [34/200], Loss: 1.0237
# Validation Loss: 0.5500
# Epoch [35/200], Loss: 0.7549
# Validation Loss: 0.5548
# Epoch [36/200], Loss: 0.5235
# Validation Loss: 0.5883
# Epoch [37/200], Loss: 0.7199
# Validation Loss: 0.5730
# Epoch [38/200], Loss: 0.4611
# Validation Loss: 0.5726
# Epoch [39/200], Loss: 1.0375
# Validation Loss: 0.5542
# Epoch [40/200], Loss: 0.7389
# Validation Loss: 0.5621
# Epoch [41/200], Loss: 0.5075
# Validation Loss: 0.5637
# Epoch [42/200], Loss: 0.7381
# Validation Loss: 0.5385
# Epoch [43/200], Loss: 0.2354
# Validation Loss: 0.5791
# Epoch [44/200], Loss: 0.3250
# Validation Loss: 0.5651
# Epoch [45/200], Loss: 0.8135
# Validation Loss: 0.5590
# Epoch [46/200], Loss: 0.2283
# Validation Loss: 0.5710
# Epoch [47/200], Loss: 0.5089
# Validation Loss: 0.5530
# Epoch [48/200], Loss: 0.5078
# Validation Loss: 0.5578
# Epoch [49/200], Loss: 0.5748
# Validation Loss: 0.5640
# Epoch [50/200], Loss: 0.5419
# Validation Loss: 0.5551
# Epoch [51/200], Loss: 0.6188
# Validation Loss: 0.5601
# Epoch [52/200], Loss: 0.7350
# Validation Loss: 0.5591
# Epoch [53/200], Loss: 0.3556
# Validation Loss: 0.5583
# Epoch [54/200], Loss: 0.2172
# Validation Loss: 0.5667
# Epoch [55/200], Loss: 0.5235
# Validation Loss: 0.5602
# Epoch [56/200], Loss: 0.2038
# Validation Loss: 0.5598
# Epoch [57/200], Loss: 1.0164
# Validation Loss: 0.5672
# Epoch [58/200], Loss: 0.4753
# Validation Loss: 0.5733
# Epoch [59/200], Loss: 1.0585
# Validation Loss: 0.5622
# Epoch [60/200], Loss: 0.7001
# Validation Loss: 0.5656
# Epoch [61/200], Loss: 0.7881
# Validation Loss: 0.5703
# Epoch [62/200], Loss: 0.0116
# Validation Loss: 0.5477
# Epoch [63/200], Loss: 0.7628
# Validation Loss: 0.5663
# Epoch [64/200], Loss: 0.9021
# Validation Loss: 0.5640
# Epoch [65/200], Loss: 0.9865
# Validation Loss: 0.5631
# Epoch [66/200], Loss: 0.7758
# Validation Loss: 0.5707
# Epoch [67/200], Loss: 0.8268
# Validation Loss: 0.5538
# Epoch [68/200], Loss: 0.7825
# Validation Loss: 0.5710
# Epoch [69/200], Loss: 0.7756
# Validation Loss: 0.5692
# Epoch [70/200], Loss: 0.3051
# Validation Loss: 0.5573
# Epoch [71/200], Loss: 1.0237
# Validation Loss: 0.5789
# Epoch [72/200], Loss: 0.5267
# Validation Loss: 0.5746
# Epoch [73/200], Loss: 0.5445
# Validation Loss: 0.5596
# Epoch [74/200], Loss: 0.5206
# Validation Loss: 0.5510
# Epoch [75/200], Loss: 0.1990
# Validation Loss: 0.5448
# Epoch [76/200], Loss: 0.4900
# Validation Loss: 0.5578
# Epoch [77/200], Loss: 0.3101
# Validation Loss: 0.5544
# Epoch [78/200], Loss: 0.4499
# Validation Loss: 0.5720
# Epoch [79/200], Loss: 0.7529
# Validation Loss: 0.5841
# Epoch [80/200], Loss: 0.1956
# Validation Loss: 0.5662
# Epoch [81/200], Loss: 1.0591
# Validation Loss: 0.5736
# Epoch [82/200], Loss: 0.4915
# Validation Loss: 0.5648
# Epoch [83/200], Loss: 0.8009
# Validation Loss: 0.5945
# Epoch [84/200], Loss: 1.0136
# Validation Loss: 0.5537
# Epoch [85/200], Loss: 0.7824
# Validation Loss: 0.5588
# Epoch [86/200], Loss: 0.8895
# Validation Loss: 0.5535
# Epoch [87/200], Loss: 0.8023
# Validation Loss: 0.5736
# Epoch [88/200], Loss: 0.3634
# Validation Loss: 0.5906
# Epoch [89/200], Loss: 0.7657
# Validation Loss: 0.5843
# Epoch [90/200], Loss: 0.7892
# Validation Loss: 0.5646
# Epoch [91/200], Loss: 0.7452
# Validation Loss: 0.5642
# Epoch [92/200], Loss: 0.5414
# Validation Loss: 0.5602
# Epoch [93/200], Loss: 0.4174
# Validation Loss: 0.5762
# Epoch [94/200], Loss: 0.4543
# Validation Loss: 0.5689
# Epoch [95/200], Loss: 0.2941
# Validation Loss: 0.5808
# Epoch [96/200], Loss: 1.0271
# Validation Loss: 0.5999
# Epoch [97/200], Loss: 0.8555
# Validation Loss: 0.5905
# Epoch [98/200], Loss: 0.5187
# Validation Loss: 0.5855
# Epoch [99/200], Loss: 0.4839
# Validation Loss: 0.5788
# Epoch [100/200], Loss: 0.0032
# Validation Loss: 0.5709
# Epoch [101/200], Loss: 0.4373
# Validation Loss: 0.6062
# Epoch [102/200], Loss: 0.8145
# Validation Loss: 0.5873
# Epoch [103/200], Loss: 1.0405
# Validation Loss: 0.5721
# Epoch [104/200], Loss: 0.7502
# Validation Loss: 0.5633
# Epoch [105/200], Loss: 0.7298
# Validation Loss: 0.5814
# Epoch [106/200], Loss: 0.5261
# Validation Loss: 0.5783
# Epoch [107/200], Loss: 0.7574
# Validation Loss: 0.5794
# Epoch [108/200], Loss: 0.8789
# Validation Loss: 0.5676
# Epoch [109/200], Loss: 0.3971
# Validation Loss: 0.5761
# Epoch [110/200], Loss: 0.5149
# Validation Loss: 0.5670
# Epoch [111/200], Loss: 0.8477
# Validation Loss: 0.5587
# Epoch [112/200], Loss: 0.2143
# Validation Loss: 0.5940
# Epoch [113/200], Loss: 0.7107
# Validation Loss: 0.6003
# Epoch [114/200], Loss: 0.7880
# Validation Loss: 0.5855
# Epoch [115/200], Loss: 0.7721
# Validation Loss: 0.5726
# Epoch [116/200], Loss: 0.5471
# Validation Loss: 0.5552
# Epoch [117/200], Loss: 0.3814
# Validation Loss: 0.5845
# Epoch [118/200], Loss: 0.3514
# Validation Loss: 0.5659
# Epoch [119/200], Loss: 0.5410
# Validation Loss: 0.5645
# Epoch [120/200], Loss: 0.4145
# Validation Loss: 0.5607
# Epoch [121/200], Loss: 1.0521
# Validation Loss: 0.5526
# Epoch [122/200], Loss: 0.7061
# Validation Loss: 0.5693
# Epoch [123/200], Loss: 0.7345
# Validation Loss: 0.5829
# Epoch [124/200], Loss: 0.8122
# Validation Loss: 0.5933
# Epoch [125/200], Loss: 0.7634
# Validation Loss: 0.5896
# Epoch [126/200], Loss: 0.6543
# Validation Loss: 0.5899
# Epoch [127/200], Loss: 0.2400
# Validation Loss: 0.5902
# Epoch [128/200], Loss: 0.8304
# Validation Loss: 0.5623
# Epoch [129/200], Loss: 0.7303
# Validation Loss: 0.5765
# Epoch [130/200], Loss: 0.5307
# Validation Loss: 0.5712
# Epoch [131/200], Loss: 0.7412
# Validation Loss: 0.5872
# Epoch [132/200], Loss: 0.2603
# Validation Loss: 0.5781
# Epoch [133/200], Loss: 0.7636
# Validation Loss: 0.5836
# Epoch [134/200], Loss: 1.0726
# Validation Loss: 0.5839
# Epoch [135/200], Loss: 0.2911
# Validation Loss: 0.5868
# Epoch [136/200], Loss: 0.7530
# Validation Loss: 0.5891
# Epoch [137/200], Loss: 0.7847
# Validation Loss: 0.5841
# Epoch [138/200], Loss: 0.7514
# Validation Loss: 0.5741
# Epoch [139/200], Loss: 0.2457
# Validation Loss: 0.5800
# Epoch [140/200], Loss: 0.4008
# Validation Loss: 0.5798
# Epoch [141/200], Loss: 1.0753
# Validation Loss: 0.5577
# Epoch [142/200], Loss: 0.5218
# Validation Loss: 0.5732
# Epoch [143/200], Loss: 0.8085
# Validation Loss: 0.5706
# Epoch [144/200], Loss: 0.7868
# Validation Loss: 0.5844
# Epoch [145/200], Loss: 0.5545
# Validation Loss: 0.5806
# Epoch [146/200], Loss: 0.7757
# Validation Loss: 0.5768
# Epoch [147/200], Loss: 0.5462
# Validation Loss: 0.5658
# Epoch [148/200], Loss: 0.8379
# Validation Loss: 0.5527
# Epoch [149/200], Loss: 1.0237
# Validation Loss: 0.5755
# Epoch [150/200], Loss: 0.5025
# Validation Loss: 0.5791
# Epoch [151/200], Loss: 0.5306
# Validation Loss: 0.5928
# Epoch [152/200], Loss: 0.3723
# Validation Loss: 0.6160
# Epoch [153/200], Loss: 0.3858
# Validation Loss: 0.5939
# Epoch [154/200], Loss: 0.7647
# Validation Loss: 0.5928
# Epoch [155/200], Loss: 0.7352
# Validation Loss: 0.6020
# Epoch [156/200], Loss: 0.2499
# Validation Loss: 0.5777
# Epoch [157/200], Loss: 1.0764
# Validation Loss: 0.5738
# Epoch [158/200], Loss: 0.2142
# Validation Loss: 0.5767
# Epoch [159/200], Loss: 0.2786
# Validation Loss: 0.5711
# Epoch [160/200], Loss: 0.7939
# Validation Loss: 0.5638
# Epoch [161/200], Loss: 0.5303
# Validation Loss: 0.5503
# Epoch [162/200], Loss: 0.2661
# Validation Loss: 0.5554
# Epoch [163/200], Loss: 0.4959
# Validation Loss: 0.5685
# Epoch [164/200], Loss: 0.7332
# Validation Loss: 0.5786
# Epoch [165/200], Loss: 0.4052
# Validation Loss: 0.5842
# Epoch [166/200], Loss: 0.4542
# Validation Loss: 0.6027
# Epoch [167/200], Loss: 0.7312
# Validation Loss: 0.6119
# Epoch [168/200], Loss: 0.7332
# Validation Loss: 0.5917
# Epoch [169/200], Loss: 0.7703
# Validation Loss: 0.5976
# Epoch [170/200], Loss: 0.3762
# Validation Loss: 0.5864
# Epoch [171/200], Loss: 0.7534
# Validation Loss: 0.6120
# Epoch [172/200], Loss: 0.7523
# Validation Loss: 0.6092
# Epoch [173/200], Loss: 0.9227
# Validation Loss: 0.5833
# Epoch [174/200], Loss: 0.5319
# Validation Loss: 0.5885
# Epoch [175/200], Loss: 0.8135
# Validation Loss: 0.6068
# Epoch [176/200], Loss: 0.7634
# Validation Loss: 0.6118
# Epoch [177/200], Loss: 0.2163
# Validation Loss: 0.6094
# Epoch [178/200], Loss: 0.8124
# Validation Loss: 0.5990
# Epoch [179/200], Loss: 0.4156
# Validation Loss: 0.5869
# Epoch [180/200], Loss: 0.7617
# Validation Loss: 0.5742
# Epoch [181/200], Loss: 1.0757
# Validation Loss: 0.5661
# Epoch [182/200], Loss: 0.5693
# Validation Loss: 0.5783
# Epoch [183/200], Loss: 0.4180
# Validation Loss: 0.5896
# Epoch [184/200], Loss: 0.3475
# Validation Loss: 0.5852
# Epoch [185/200], Loss: 0.4371
# Validation Loss: 0.6190
# Epoch [186/200], Loss: 0.7796
# Validation Loss: 0.6156
# Epoch [187/200], Loss: 0.2358
# Validation Loss: 0.5985
# Epoch [188/200], Loss: 0.7559
# Validation Loss: 0.5918
# Epoch [189/200], Loss: 0.4117
# Validation Loss: 0.5974
# Epoch [190/200], Loss: 0.7427
# Validation Loss: 0.5794
# Epoch [191/200], Loss: 0.5546
# Validation Loss: 0.5743
# Epoch [192/200], Loss: 0.3491
# Validation Loss: 0.5710
# Epoch [193/200], Loss: 0.8114
# Validation Loss: 0.5705
# Epoch [194/200], Loss: 0.9559
# Validation Loss: 0.5821
# Epoch [195/200], Loss: 0.2037
# Validation Loss: 0.5614
# Epoch [196/200], Loss: 1.0644
# Validation Loss: 0.5650
# Epoch [197/200], Loss: 0.5158
# Validation Loss: 0.5751
# Epoch [198/200], Loss: 0.6628
# Validation Loss: 0.5767
# Epoch [199/200], Loss: 0.4500
# Validation Loss: 0.5987
# Epoch [200/200], Loss: 0.7400
# Validation Loss: 0.5778
# Trial 0, Fold 3/5
# type of train_loader <class 'torch.utils.data.dataloader.DataLoader'>
# Epoch [1/200], Loss: 1.7675
# Validation Loss: 0.9150
# Epoch [2/200], Loss: 0.3097
# Validation Loss: 0.7632
# Epoch [3/200], Loss: 0.6886
# Validation Loss: 0.8003
# Epoch [4/200], Loss: 0.7071
# Validation Loss: 0.7232
# Epoch [5/200], Loss: 0.7080
# Validation Loss: 0.7230
# Epoch [6/200], Loss: 0.7182
# Validation Loss: 0.7715
# Epoch [7/200], Loss: 0.5592
# Validation Loss: 0.7232
# Epoch [8/200], Loss: 0.4233
# Validation Loss: 0.6965
# Epoch [9/200], Loss: 0.5100
# Validation Loss: 0.7173
# Epoch [10/200], Loss: 0.5395
# Validation Loss: 0.7469
# Epoch [11/200], Loss: 0.6982
# Validation Loss: 0.6846
# Epoch [12/200], Loss: 0.3246
# Validation Loss: 0.7271
# Epoch [13/200], Loss: 0.5005
# Validation Loss: 0.6828
# Epoch [14/200], Loss: 0.7160
# Validation Loss: 0.7045
# Epoch [15/200], Loss: 0.7951
# Validation Loss: 0.7125
# Epoch [16/200], Loss: 1.0220
# Validation Loss: 0.6911
# Epoch [17/200], Loss: 0.4628
# Validation Loss: 0.6741
# Epoch [18/200], Loss: 0.5651
# Validation Loss: 0.6688
# Epoch [19/200], Loss: 0.8445
# Validation Loss: 0.6704
# Epoch [20/200], Loss: 0.5281
# Validation Loss: 0.6671
# Epoch [21/200], Loss: 0.5417
# Validation Loss: 0.7203
# Epoch [22/200], Loss: 0.3530
# Validation Loss: 0.6740
# Epoch [23/200], Loss: 0.8240
# Validation Loss: 0.6820
# Epoch [24/200], Loss: 0.5659
# Validation Loss: 0.6654
# Epoch [25/200], Loss: 0.7176
# Validation Loss: 0.6689
# Epoch [26/200], Loss: 0.3211
# Validation Loss: 0.6952
# Epoch [27/200], Loss: 0.1925
# Validation Loss: 0.6811
# Epoch [28/200], Loss: 0.5201
# Validation Loss: 0.7056
# Epoch [29/200], Loss: 0.4143
# Validation Loss: 0.6885
# Epoch [30/200], Loss: 0.5452
# Validation Loss: 0.6974
# Epoch [31/200], Loss: 0.7072
# Validation Loss: 0.6933
# Epoch [32/200], Loss: 0.8467
# Validation Loss: 0.7050
# Epoch [33/200], Loss: 0.4279
# Validation Loss: 0.6632
# Epoch [34/200], Loss: 0.9927
# Validation Loss: 0.7295
# Epoch [35/200], Loss: 1.0371
# Validation Loss: 0.6952
# Epoch [36/200], Loss: 0.5114
# Validation Loss: 0.6789
# Epoch [37/200], Loss: 0.7000
# Validation Loss: 0.7064
# Epoch [38/200], Loss: 0.2542
# Validation Loss: 0.6538
# Epoch [39/200], Loss: 0.5499
# Validation Loss: 0.6878
# Epoch [40/200], Loss: 0.7201
# Validation Loss: 0.6712
# Epoch [41/200], Loss: 0.5506
# Validation Loss: 0.6693
# Epoch [42/200], Loss: 0.2226
# Validation Loss: 0.6478
# Epoch [43/200], Loss: 0.9621
# Validation Loss: 0.6938
# Epoch [44/200], Loss: 0.5549
# Validation Loss: 0.6943
# Epoch [45/200], Loss: 0.8731
# Validation Loss: 0.6538
# Epoch [46/200], Loss: 0.7824
# Validation Loss: 0.6919
# Epoch [47/200], Loss: 1.0389
# Validation Loss: 0.6646
# Epoch [48/200], Loss: 0.3550
# Validation Loss: 0.6761
# Epoch [49/200], Loss: 0.3001
# Validation Loss: 0.7085
# Epoch [50/200], Loss: 0.8346
# Validation Loss: 0.7014
# Epoch [51/200], Loss: 0.5186
# Validation Loss: 0.6839
# Epoch [52/200], Loss: 0.9153
# Validation Loss: 0.6908
# Epoch [53/200], Loss: 0.9181
# Validation Loss: 0.6656
# Epoch [54/200], Loss: 0.4096
# Validation Loss: 0.6976
# Epoch [55/200], Loss: 1.1215
# Validation Loss: 0.7314
# Epoch [56/200], Loss: 0.5177
# Validation Loss: 0.6745
# Epoch [57/200], Loss: 0.3375
# Validation Loss: 0.7099
# Epoch [58/200], Loss: 0.4993
# Validation Loss: 0.6629
# Epoch [59/200], Loss: 0.7144
# Validation Loss: 0.6799
# Epoch [60/200], Loss: 0.3276
# Validation Loss: 0.6636
# Epoch [61/200], Loss: 0.7179
# Validation Loss: 0.6550
# Epoch [62/200], Loss: 0.8253
# Validation Loss: 0.6884
# Epoch [63/200], Loss: 0.4494
# Validation Loss: 0.6892
# Epoch [64/200], Loss: 0.8827
# Validation Loss: 0.6956
# Epoch [65/200], Loss: 0.5408
# Validation Loss: 0.6676
# Epoch [66/200], Loss: 1.0746
# Validation Loss: 0.6774
# Epoch [67/200], Loss: 0.3466
# Validation Loss: 0.6643
# Epoch [68/200], Loss: 0.8961
# Validation Loss: 0.6675
# Epoch [69/200], Loss: 0.3419
# Validation Loss: 0.6678
# Epoch [70/200], Loss: 0.7194
# Validation Loss: 0.6535
# Epoch [71/200], Loss: 0.5185
# Validation Loss: 0.6712
# Epoch [72/200], Loss: 0.5065
# Validation Loss: 0.6721
# Epoch [73/200], Loss: 0.8169
# Validation Loss: 0.6906
# Epoch [74/200], Loss: 0.8524
# Validation Loss: 0.6433
# Epoch [75/200], Loss: 0.7216
# Validation Loss: 0.6439
# Epoch [76/200], Loss: 0.5213
# Validation Loss: 0.6742
# Epoch [77/200], Loss: 0.7365
# Validation Loss: 0.6876
# Epoch [78/200], Loss: 0.8380
# Validation Loss: 0.6757
# Epoch [79/200], Loss: 0.5955
# Validation Loss: 0.6320
# Epoch [80/200], Loss: 0.3846
# Validation Loss: 0.6610
# Epoch [81/200], Loss: 0.2751
# Validation Loss: 0.6374
# Epoch [82/200], Loss: 0.2020
# Validation Loss: 0.6598
# Epoch [83/200], Loss: 0.9027
# Validation Loss: 0.6688
# Epoch [84/200], Loss: 0.3514
# Validation Loss: 0.6437
# Epoch [85/200], Loss: 0.6961
# Validation Loss: 0.6852
# Epoch [86/200], Loss: 0.8441
# Validation Loss: 0.6600
# Epoch [87/200], Loss: 0.2069
# Validation Loss: 0.6359
# Epoch [88/200], Loss: 0.5518
# Validation Loss: 0.6642
# Epoch [89/200], Loss: 0.6047
# Validation Loss: 0.6832
# Epoch [90/200], Loss: 0.4621
# Validation Loss: 0.6217
# Epoch [91/200], Loss: 0.7271
# Validation Loss: 0.6719
# Epoch [92/200], Loss: 0.5270
# Validation Loss: 0.6491
# Epoch [93/200], Loss: 0.8534
# Validation Loss: 0.6658
# Epoch [94/200], Loss: 1.0697
# Validation Loss: 0.6873
# Epoch [95/200], Loss: 0.2046
# Validation Loss: 0.6703
# Epoch [96/200], Loss: 0.5450
# Validation Loss: 0.6607
# Epoch [97/200], Loss: 0.8358
# Validation Loss: 0.6880
# Epoch [98/200], Loss: 0.3510
# Validation Loss: 0.6731
# Epoch [99/200], Loss: 0.3795
# Validation Loss: 0.6684
# Epoch [100/200], Loss: 0.7064
# Validation Loss: 0.6825
# Epoch [101/200], Loss: 0.5293
# Validation Loss: 0.6717
# Epoch [102/200], Loss: 0.6081
# Validation Loss: 0.6816
# Epoch [103/200], Loss: 0.5273
# Validation Loss: 0.6671
# Epoch [104/200], Loss: 0.7143
# Validation Loss: 0.6643
# Epoch [105/200], Loss: 0.3647
# Validation Loss: 0.6576
# Epoch [106/200], Loss: 0.6177
# Validation Loss: 0.6658
# Epoch [107/200], Loss: 0.7905
# Validation Loss: 0.6413
# Epoch [108/200], Loss: 0.5451
# Validation Loss: 0.6716
# Epoch [109/200], Loss: 0.3328
# Validation Loss: 0.6762
# Epoch [110/200], Loss: 0.5186
# Validation Loss: 0.6742
# Epoch [111/200], Loss: 0.7927
# Validation Loss: 0.6832
# Epoch [112/200], Loss: 0.3488
# Validation Loss: 0.6737
# Epoch [113/200], Loss: 0.4004
# Validation Loss: 0.6811
# Epoch [114/200], Loss: 0.8249
# Validation Loss: 0.6523
# Epoch [115/200], Loss: 0.5847
# Validation Loss: 0.6805
# Epoch [116/200], Loss: 1.0696
# Validation Loss: 0.6587
# Epoch [117/200], Loss: 0.8955
# Validation Loss: 0.6459
# Epoch [118/200], Loss: 0.2905
# Validation Loss: 0.6703
# Epoch [119/200], Loss: 1.0266
# Validation Loss: 0.6410
# Epoch [120/200], Loss: 1.0698
# Validation Loss: 0.6627
# Epoch [121/200], Loss: 0.3331
# Validation Loss: 0.6605
# Epoch [122/200], Loss: 0.2105
# Validation Loss: 0.6380
# Epoch [123/200], Loss: 0.2060
# Validation Loss: 0.6623
# Epoch [124/200], Loss: 1.0455
# Validation Loss: 0.6435
# Epoch [125/200], Loss: 0.2046
# Validation Loss: 0.6416
# Epoch [126/200], Loss: 0.8512
# Validation Loss: 0.6346
# Epoch [127/200], Loss: 0.8260
# Validation Loss: 0.6508
# Epoch [128/200], Loss: 0.5412
# Validation Loss: 0.6604
# Epoch [129/200], Loss: 0.7253
# Validation Loss: 0.6339
# Epoch [130/200], Loss: 0.7274
# Validation Loss: 0.6637
# Epoch [131/200], Loss: 0.5538
# Validation Loss: 0.6364
# Epoch [132/200], Loss: 0.5475
# Validation Loss: 0.6339
# Epoch [133/200], Loss: 0.6953
# Validation Loss: 0.6550
# Epoch [134/200], Loss: 0.5663
# Validation Loss: 0.6513
# Epoch [135/200], Loss: 0.7235
# Validation Loss: 0.6689
# Epoch [136/200], Loss: 0.5204
# Validation Loss: 0.6511
# Epoch [137/200], Loss: 0.8556
# Validation Loss: 0.6671
# Epoch [138/200], Loss: 1.0310
# Validation Loss: 0.6640
# Epoch [139/200], Loss: 0.5344
# Validation Loss: 0.6629
# Epoch [140/200], Loss: 0.7265
# Validation Loss: 0.6436
# Epoch [141/200], Loss: 0.5474
# Validation Loss: 0.6744
# Epoch [142/200], Loss: 0.7366
# Validation Loss: 0.6750
# Epoch [143/200], Loss: 0.8207
# Validation Loss: 0.6628
# Epoch [144/200], Loss: 0.7036
# Validation Loss: 0.6539
# Epoch [145/200], Loss: 0.5201
# Validation Loss: 0.6114
# Epoch [146/200], Loss: 0.5524
# Validation Loss: 0.6351
# Epoch [147/200], Loss: 0.9084
# Validation Loss: 0.6629
# Epoch [148/200], Loss: 0.7993
# Validation Loss: 0.6468
# Epoch [149/200], Loss: 0.9149
# Validation Loss: 0.6418
# Epoch [150/200], Loss: 0.5363
# Validation Loss: 0.6360
# Epoch [151/200], Loss: 0.8957
# Validation Loss: 0.6666
# Epoch [152/200], Loss: 0.7584
# Validation Loss: 0.6356
# Epoch [153/200], Loss: 0.5773
# Validation Loss: 0.6415
# Epoch [154/200], Loss: 0.3256
# Validation Loss: 0.6411
# Epoch [155/200], Loss: 0.5408
# Validation Loss: 0.6709
# Epoch [156/200], Loss: 0.0180
# Validation Loss: 0.6393
# Epoch [157/200], Loss: 0.3419
# Validation Loss: 0.6274
# Epoch [158/200], Loss: 0.2169
# Validation Loss: 0.6106
# Epoch [159/200], Loss: 0.2033
# Validation Loss: 0.6313
# Epoch [160/200], Loss: 0.8483
# Validation Loss: 0.6518
# Epoch [161/200], Loss: 0.8197
# Validation Loss: 0.6454
# Epoch [162/200], Loss: 0.7970
# Validation Loss: 0.6428
# Epoch [163/200], Loss: 0.7198
# Validation Loss: 0.6565
# Epoch [164/200], Loss: 0.3882
# Validation Loss: 0.6455
# Epoch [165/200], Loss: 0.2857
# Validation Loss: 0.6540
# Epoch [166/200], Loss: 0.1980
# Validation Loss: 0.6302
# Epoch [167/200], Loss: 0.8822
# Validation Loss: 0.6272
# Epoch [168/200], Loss: 0.7154
# Validation Loss: 0.6290
# Epoch [169/200], Loss: 0.5506
# Validation Loss: 0.6255
# Epoch [170/200], Loss: 0.2683
# Validation Loss: 0.6226
# Epoch [171/200], Loss: 0.2166
# Validation Loss: 0.6355
# Epoch [172/200], Loss: 0.8894
# Validation Loss: 0.6365
# Epoch [173/200], Loss: 0.5499
# Validation Loss: 0.6610
# Epoch [174/200], Loss: 0.6198
# Validation Loss: 0.6693
# Epoch [175/200], Loss: 0.6905
# Validation Loss: 0.6247
# Epoch [176/200], Loss: 0.5812
# Validation Loss: 0.6840
# Epoch [177/200], Loss: 0.2092
# Validation Loss: 0.6539
# Epoch [178/200], Loss: 0.8400
# Validation Loss: 0.6496
# Epoch [179/200], Loss: 0.5367
# Validation Loss: 0.6447
# Epoch [180/200], Loss: 0.8920
# Validation Loss: 0.6394
# Epoch [181/200], Loss: 0.8107
# Validation Loss: 0.6389
# Epoch [182/200], Loss: 0.5282
# Validation Loss: 0.6286
# Epoch [183/200], Loss: 0.4884
# Validation Loss: 0.6226
# Epoch [184/200], Loss: 0.8377
# Validation Loss: 0.6505
# Epoch [185/200], Loss: 0.7164
# Validation Loss: 0.6407
# Epoch [186/200], Loss: 0.3471
# Validation Loss: 0.6504
# Epoch [187/200], Loss: 0.8830
# Validation Loss: 0.6556
# Epoch [188/200], Loss: 0.5472
# Validation Loss: 0.6317
# Epoch [189/200], Loss: 0.3183
# Validation Loss: 0.6449
# Epoch [190/200], Loss: 0.4782
# Validation Loss: 0.6557
# Epoch [191/200], Loss: 0.7582
# Validation Loss: 0.6622
# Epoch [192/200], Loss: 0.3769
# Validation Loss: 0.6573
# Epoch [193/200], Loss: 0.5081
# Validation Loss: 0.6616
# Epoch [194/200], Loss: 0.3831
# Validation Loss: 0.6321
# Epoch [195/200], Loss: 0.7560
# Validation Loss: 0.6758
# Epoch [196/200], Loss: 0.3650
# Validation Loss: 0.6651
# Epoch [197/200], Loss: 0.8569
# Validation Loss: 0.6705
# Epoch [198/200], Loss: 0.8233
# Validation Loss: 0.6493
# Epoch [199/200], Loss: 0.5002
# Validation Loss: 0.6490
# Epoch [200/200], Loss: 0.8465
# Validation Loss: 0.6596
# Trial 0, Fold 4/5
# type of train_loader <class 'torch.utils.data.dataloader.DataLoader'>
# Epoch [1/200], Loss: 0.9718
# Validation Loss: 0.9105
# Epoch [2/200], Loss: 0.0158
# Validation Loss: 0.6269
# Epoch [3/200], Loss: 0.5527
# Validation Loss: 0.6360
# Epoch [4/200], Loss: 0.7115
# Validation Loss: 0.6346
# Epoch [5/200], Loss: 0.7082
# Validation Loss: 0.6259
# Epoch [6/200], Loss: 0.7139
# Validation Loss: 0.6283
# Epoch [7/200], Loss: 1.0665
# Validation Loss: 0.6334
# Epoch [8/200], Loss: 0.5209
# Validation Loss: 0.6323
# Epoch [9/200], Loss: 0.5086
# Validation Loss: 0.6456
# Epoch [10/200], Loss: 0.8880
# Validation Loss: 0.6448
# Epoch [11/200], Loss: 1.0228
# Validation Loss: 0.6420
# Epoch [12/200], Loss: 0.5174
# Validation Loss: 0.6471
# Epoch [13/200], Loss: 0.7707
# Validation Loss: 0.6467
# Epoch [14/200], Loss: 0.7088
# Validation Loss: 0.6458
# Epoch [15/200], Loss: 0.5344
# Validation Loss: 0.6485
# Epoch [16/200], Loss: 0.1924
# Validation Loss: 0.6413
# Epoch [17/200], Loss: 0.5088
# Validation Loss: 0.6423
# Epoch [18/200], Loss: 0.2100
# Validation Loss: 0.6502
# Epoch [19/200], Loss: 0.2950
# Validation Loss: 0.6505
# Epoch [20/200], Loss: 0.9233
# Validation Loss: 0.6534
# Epoch [21/200], Loss: 0.7095
# Validation Loss: 0.6420
# Epoch [22/200], Loss: 0.5184
# Validation Loss: 0.6468
# Epoch [23/200], Loss: 0.3945
# Validation Loss: 0.6360
# Epoch [24/200], Loss: 0.5606
# Validation Loss: 0.6454
# Epoch [25/200], Loss: 0.7818
# Validation Loss: 0.6452
# Epoch [26/200], Loss: 0.8043
# Validation Loss: 0.6472
# Epoch [27/200], Loss: 0.9037
# Validation Loss: 0.6426
# Epoch [28/200], Loss: 0.5164
# Validation Loss: 0.6472
# Epoch [29/200], Loss: 0.7349
# Validation Loss: 0.6474
# Epoch [30/200], Loss: 0.5244
# Validation Loss: 0.6515
# Epoch [31/200], Loss: 0.4003
# Validation Loss: 0.6658
# Epoch [32/200], Loss: 0.2325
# Validation Loss: 0.6529
# Epoch [33/200], Loss: 0.3681
# Validation Loss: 0.6837
# Epoch [34/200], Loss: 0.5214
# Validation Loss: 0.6718
# Epoch [35/200], Loss: 0.3621
# Validation Loss: 0.6483
# Epoch [36/200], Loss: 0.7720
# Validation Loss: 0.6643
# Epoch [37/200], Loss: 0.5389
# Validation Loss: 0.6757
# Epoch [38/200], Loss: 0.5277
# Validation Loss: 0.6767
# Epoch [39/200], Loss: 0.4869
# Validation Loss: 0.6670
# Epoch [40/200], Loss: 0.9125
# Validation Loss: 0.6611
# Epoch [41/200], Loss: 0.2056
# Validation Loss: 0.6647
# Epoch [42/200], Loss: 0.2352
# Validation Loss: 0.6709
# Epoch [43/200], Loss: 0.3603
# Validation Loss: 0.6769
# Epoch [44/200], Loss: 1.1591
# Validation Loss: 0.6652
# Epoch [45/200], Loss: 0.3947
# Validation Loss: 0.6545
# Epoch [46/200], Loss: 0.7150
# Validation Loss: 0.6579
# Epoch [47/200], Loss: 0.2777
# Validation Loss: 0.6562
# Epoch [48/200], Loss: 0.7814
# Validation Loss: 0.6620
# Epoch [49/200], Loss: 0.7663
# Validation Loss: 0.6539
# Epoch [50/200], Loss: 0.7504
# Validation Loss: 0.6453
# Epoch [51/200], Loss: 0.8745
# Validation Loss: 0.6410
# Epoch [52/200], Loss: 0.3860
# Validation Loss: 0.6606
# Epoch [53/200], Loss: 0.7403
# Validation Loss: 0.6764
# Epoch [54/200], Loss: 0.5384
# Validation Loss: 0.6672
# Epoch [55/200], Loss: 0.4748
# Validation Loss: 0.6657
# Epoch [56/200], Loss: 0.9083
# Validation Loss: 0.6782
# Epoch [57/200], Loss: 0.2120
# Validation Loss: 0.6782
# Epoch [58/200], Loss: 0.3572
# Validation Loss: 0.6881
# Epoch [59/200], Loss: 0.5655
# Validation Loss: 0.6834
# Epoch [60/200], Loss: 0.5393
# Validation Loss: 0.6985
# Epoch [61/200], Loss: 0.5440
# Validation Loss: 0.6770
# Epoch [62/200], Loss: 0.5323
# Validation Loss: 0.6642
# Epoch [63/200], Loss: 0.5181
# Validation Loss: 0.6857
# Epoch [64/200], Loss: 0.7839
# Validation Loss: 0.6921
# Epoch [65/200], Loss: 0.5303
# Validation Loss: 0.7193
# Epoch [66/200], Loss: 0.4563
# Validation Loss: 0.6755
# Epoch [67/200], Loss: 0.6229
# Validation Loss: 0.6883
# Epoch [68/200], Loss: 0.7591
# Validation Loss: 0.6598
# Epoch [69/200], Loss: 0.7041
# Validation Loss: 0.6774
# Epoch [70/200], Loss: 0.8836
# Validation Loss: 0.6769
# Epoch [71/200], Loss: 0.7683
# Validation Loss: 0.6600
# Epoch [72/200], Loss: 0.7254
# Validation Loss: 0.6547
# Epoch [73/200], Loss: 0.7145
# Validation Loss: 0.6609
# Epoch [74/200], Loss: 0.5360
# Validation Loss: 0.6746
# Epoch [75/200], Loss: 0.8032
# Validation Loss: 0.6756
# Epoch [76/200], Loss: 0.5498
# Validation Loss: 0.6765
# Epoch [77/200], Loss: 0.7460
# Validation Loss: 0.6602
# Epoch [78/200], Loss: 0.6143
# Validation Loss: 0.6602
# Epoch [79/200], Loss: 0.4009
# Validation Loss: 0.6653
# Epoch [80/200], Loss: 0.5186
# Validation Loss: 0.6675
# Epoch [81/200], Loss: 0.7464
# Validation Loss: 0.6962
# Epoch [82/200], Loss: 0.4033
# Validation Loss: 0.6729
# Epoch [83/200], Loss: 0.5343
# Validation Loss: 0.6681
# Epoch [84/200], Loss: 0.5093
# Validation Loss: 0.6662
# Epoch [85/200], Loss: 0.4951
# Validation Loss: 0.6893
# Epoch [86/200], Loss: 0.7434
# Validation Loss: 0.6745
# Epoch [87/200], Loss: 0.8337
# Validation Loss: 0.6723
# Epoch [88/200], Loss: 0.4340
# Validation Loss: 0.6700
# Epoch [89/200], Loss: 0.2212
# Validation Loss: 0.6924
# Epoch [90/200], Loss: 0.4178
# Validation Loss: 0.6732
# Epoch [91/200], Loss: 0.7881
# Validation Loss: 0.6568
# Epoch [92/200], Loss: 0.7083
# Validation Loss: 0.6547
# Epoch [93/200], Loss: 0.2684
# Validation Loss: 0.6695
# Epoch [94/200], Loss: 0.8652
# Validation Loss: 0.6870
# Epoch [95/200], Loss: 0.5369
# Validation Loss: 0.6645
# Epoch [96/200], Loss: 0.7472
# Validation Loss: 0.6626
# Epoch [97/200], Loss: 0.7645
# Validation Loss: 0.6634
# Epoch [98/200], Loss: 0.3414
# Validation Loss: 0.6757
# Epoch [99/200], Loss: 0.7105
# Validation Loss: 0.6824
# Epoch [100/200], Loss: 0.4905
# Validation Loss: 0.6726
# Epoch [101/200], Loss: 0.4314
# Validation Loss: 0.6755
# Epoch [102/200], Loss: 0.7736
# Validation Loss: 0.6883
# Epoch [103/200], Loss: 0.6965
# Validation Loss: 0.7191
# Epoch [104/200], Loss: 0.7873
# Validation Loss: 0.6956
# Epoch [105/200], Loss: 0.7319
# Validation Loss: 0.6732
# Epoch [106/200], Loss: 0.3558
# Validation Loss: 0.6757
# Epoch [107/200], Loss: 0.8386
# Validation Loss: 0.6838
# Epoch [108/200], Loss: 0.4122
# Validation Loss: 0.6730
# Epoch [109/200], Loss: 0.7366
# Validation Loss: 0.6747
# Epoch [110/200], Loss: 0.4611
# Validation Loss: 0.6981
# Epoch [111/200], Loss: 0.2297
# Validation Loss: 0.7000
# Epoch [112/200], Loss: 0.1910
# Validation Loss: 0.6955
# Epoch [113/200], Loss: 0.7975
# Validation Loss: 0.6772
# Epoch [114/200], Loss: 0.9279
# Validation Loss: 0.6950
# Epoch [115/200], Loss: 0.5180
# Validation Loss: 0.6854
# Epoch [116/200], Loss: 0.8030
# Validation Loss: 0.6915
# Epoch [117/200], Loss: 0.7902
# Validation Loss: 0.6774
# Epoch [118/200], Loss: 0.7367
# Validation Loss: 0.6720
# Epoch [119/200], Loss: 0.5710
# Validation Loss: 0.6664
# Epoch [120/200], Loss: 0.1970
# Validation Loss: 0.6698
# Epoch [121/200], Loss: 0.8034
# Validation Loss: 0.6780
# Epoch [122/200], Loss: 0.9552
# Validation Loss: 0.6717
# Epoch [123/200], Loss: 0.9819
# Validation Loss: 0.6612
# Epoch [124/200], Loss: 0.7939
# Validation Loss: 0.6645
# Epoch [125/200], Loss: 0.7067
# Validation Loss: 0.6674
# Epoch [126/200], Loss: 0.7308
# Validation Loss: 0.6665
# Epoch [127/200], Loss: 0.7306
# Validation Loss: 0.6680
# Epoch [128/200], Loss: 0.7328
# Validation Loss: 0.6569
# Epoch [129/200], Loss: 0.5224
# Validation Loss: 0.6548
# Epoch [130/200], Loss: 0.5438
# Validation Loss: 0.6568
# Epoch [131/200], Loss: 0.2008
# Validation Loss: 0.6553
# Epoch [132/200], Loss: 0.2009
# Validation Loss: 0.6657
# Epoch [133/200], Loss: 0.8070
# Validation Loss: 0.6716
# Epoch [134/200], Loss: 0.3506
# Validation Loss: 0.6649
# Epoch [135/200], Loss: 0.2910
# Validation Loss: 0.6588
# Epoch [136/200], Loss: 0.5203
# Validation Loss: 0.6609
# Epoch [137/200], Loss: 0.8305
# Validation Loss: 0.6593
# Epoch [138/200], Loss: 0.8031
# Validation Loss: 0.6598
# Epoch [139/200], Loss: 0.3445
# Validation Loss: 0.6492
# Epoch [140/200], Loss: 0.4985
# Validation Loss: 0.6487
# Epoch [141/200], Loss: 0.5199
# Validation Loss: 0.6628
# Epoch [142/200], Loss: 0.8436
# Validation Loss: 0.6698
# Epoch [143/200], Loss: 0.7585
# Validation Loss: 0.6588
# Epoch [144/200], Loss: 0.5264
# Validation Loss: 0.6757
# Epoch [145/200], Loss: 0.8327
# Validation Loss: 0.6928
# Epoch [146/200], Loss: 0.7331
# Validation Loss: 0.6879
# Epoch [147/200], Loss: 0.7857
# Validation Loss: 0.6802
# Epoch [148/200], Loss: 0.7861
# Validation Loss: 0.6699
# Epoch [149/200], Loss: 0.7509
# Validation Loss: 0.6598
# Epoch [150/200], Loss: 0.2922
# Validation Loss: 0.6605
# Epoch [151/200], Loss: 0.2137
# Validation Loss: 0.6727
# Epoch [152/200], Loss: 0.5300
# Validation Loss: 0.6842
# Epoch [153/200], Loss: 0.6591
# Validation Loss: 0.6965
# Epoch [154/200], Loss: 0.0300
# Validation Loss: 0.6920
# Epoch [155/200], Loss: 0.3332
# Validation Loss: 0.6881
# Epoch [156/200], Loss: 0.8348
# Validation Loss: 0.6806
# Epoch [157/200], Loss: 1.0890
# Validation Loss: 0.6971
# Epoch [158/200], Loss: 0.1951
# Validation Loss: 0.6777
# Epoch [159/200], Loss: 0.1919
# Validation Loss: 0.6671
# Epoch [160/200], Loss: 0.7542
# Validation Loss: 0.6874
# Epoch [161/200], Loss: 0.7333
# Validation Loss: 0.7104
# Epoch [162/200], Loss: 0.2098
# Validation Loss: 0.7213
# Epoch [163/200], Loss: 0.4513
# Validation Loss: 0.7060
# Epoch [164/200], Loss: 0.7578
# Validation Loss: 0.6802
# Epoch [165/200], Loss: 0.5692
# Validation Loss: 0.7330
# Epoch [166/200], Loss: 0.5133
# Validation Loss: 0.6703
# Epoch [167/200], Loss: 0.5271
# Validation Loss: 0.6722
# Epoch [168/200], Loss: 0.0049
# Validation Loss: 0.6589
# Epoch [169/200], Loss: 0.7387
# Validation Loss: 0.6715
# Epoch [170/200], Loss: 0.3499
# Validation Loss: 0.6665
# Epoch [171/200], Loss: 0.3304
# Validation Loss: 0.6704
# Epoch [172/200], Loss: 0.4962
# Validation Loss: 0.6646
# Epoch [173/200], Loss: 0.0321
# Validation Loss: 0.6657
# Epoch [174/200], Loss: 0.7134
# Validation Loss: 0.6770
# Epoch [175/200], Loss: 1.0572
# Validation Loss: 0.6714
# Epoch [176/200], Loss: 0.3092
# Validation Loss: 0.6696
# Epoch [177/200], Loss: 0.5427
# Validation Loss: 0.6806
# Epoch [178/200], Loss: 0.3158
# Validation Loss: 0.6790
# Epoch [179/200], Loss: 0.7264
# Validation Loss: 0.6732
# Epoch [180/200], Loss: 0.7039
# Validation Loss: 0.6690
# Epoch [181/200], Loss: 0.9313
# Validation Loss: 0.6775
# Epoch [182/200], Loss: 0.7243
# Validation Loss: 0.6754
# Epoch [183/200], Loss: 1.0374
# Validation Loss: 0.6623
# Epoch [184/200], Loss: 0.5369
# Validation Loss: 0.6677
# Epoch [185/200], Loss: 0.7955
# Validation Loss: 0.6771
# Epoch [186/200], Loss: 0.7528
# Validation Loss: 0.6867
# Epoch [187/200], Loss: 0.2047
# Validation Loss: 0.6973
# Epoch [188/200], Loss: 0.0136
# Validation Loss: 0.7001
# Epoch [189/200], Loss: 0.5802
# Validation Loss: 0.6941
# Epoch [190/200], Loss: 0.4787
# Validation Loss: 0.7247
# Epoch [191/200], Loss: 0.3398
# Validation Loss: 0.7161
# Epoch [192/200], Loss: 0.7905
# Validation Loss: 0.6802
# Epoch [193/200], Loss: 0.7585
# Validation Loss: 0.6913
# Epoch [194/200], Loss: 0.3837
# Validation Loss: 0.6894
# Epoch [195/200], Loss: 0.3851
# Validation Loss: 0.7043
# Epoch [196/200], Loss: 0.5065
# Validation Loss: 0.6857
# Epoch [197/200], Loss: 0.7344
# Validation Loss: 0.6857
# Epoch [198/200], Loss: 0.4691
# Validation Loss: 0.6817
# Epoch [199/200], Loss: 0.3519
# Validation Loss: 0.6711
# Epoch [200/200], Loss: 0.5499
# Validation Loss: 0.6772
# Trial 0, Fold 5/5
# type of train_loader <class 'torch.utils.data.dataloader.DataLoader'>
# Epoch [1/200], Loss: 0.2613
# Validation Loss: 0.9033
# Epoch [2/200], Loss: 0.9217
# Validation Loss: 0.7187
# Epoch [3/200], Loss: 0.3057
# Validation Loss: 0.7665
# Epoch [4/200], Loss: 0.5295
# Validation Loss: 0.7204
# Epoch [5/200], Loss: 0.6951
# Validation Loss: 0.7140
# Epoch [6/200], Loss: 0.3055
# Validation Loss: 0.7222
# Epoch [7/200], Loss: 0.7983
# Validation Loss: 0.7132
# Epoch [8/200], Loss: 0.7342
# Validation Loss: 0.6971
# Epoch [9/200], Loss: 0.8576
# Validation Loss: 0.7133
# Epoch [10/200], Loss: 0.2030
# Validation Loss: 0.6944
# Epoch [11/200], Loss: 0.5291
# Validation Loss: 0.7134
# Epoch [12/200], Loss: 1.0202
# Validation Loss: 0.7062
# Epoch [13/200], Loss: 0.1935
# Validation Loss: 0.7158
# Epoch [14/200], Loss: 0.5171
# Validation Loss: 0.7023
# Epoch [15/200], Loss: 0.2026
# Validation Loss: 0.7034
# Epoch [16/200], Loss: 0.5374
# Validation Loss: 0.7029
# Epoch [17/200], Loss: 0.7218
# ...
# Epoch [108/200], Loss: 0.2199
# Validation Loss: 0.6948
# Epoch [109/200], Loss: 0.5333
# Validation Loss: 0.7310
# Epoch [110/200], Loss: 0.2063
# Validation Loss: 0.6684
# Epoch [111/200], Loss: 0.4978
# Validation Loss: 0.6768
# Epoch [112/200], Loss: 0.4012
# Validation Loss: 0.7138
# Epoch [113/200], Loss: 0.7820
# Validation Loss: 0.7025
# Epoch [114/200], Loss: 0.2315
# Validation Loss: 0.6963
# Epoch [115/200], Loss: 0.3706
# Validation Loss: 0.7057
# Epoch [116/200], Loss: 0.9052
# Validation Loss: 0.7319
# Epoch [117/200], Loss: 0.5197
# Validation Loss: 0.6865
# Epoch [118/200], Loss: 0.7479
# Validation Loss: 0.6813
# Epoch [119/200], Loss: 0.7212
# Validation Loss: 0.6837
# Epoch [120/200], Loss: 0.5361
# Validation Loss: 0.6710
# Epoch [121/200], Loss: 0.2333
# Validation Loss: 0.6663
# Epoch [122/200], Loss: 0.3199
# Validation Loss: 0.6806
# Epoch [123/200], Loss: 0.7201
# Validation Loss: 0.6781
# Epoch [124/200], Loss: 0.4994
# Validation Loss: 0.6828
# Epoch [125/200], Loss: 0.8801
# Validation Loss: 0.6830
# Epoch [126/200], Loss: 0.4679
# Validation Loss: 0.6679
# Epoch [127/200], Loss: 0.5314
# Validation Loss: 0.6666
# Epoch [128/200], Loss: 0.3703
# Validation Loss: 0.6678
# Epoch [129/200], Loss: 0.8291
# Validation Loss: 0.6953
# Epoch [130/200], Loss: 0.2094
# Validation Loss: 0.7015
# Epoch [131/200], Loss: 0.9201
# Validation Loss: 0.6918
# Epoch [132/200], Loss: 0.4862
# Validation Loss: 0.6824
# Epoch [133/200], Loss: 0.3274
# Validation Loss: 0.6744
# Epoch [134/200], Loss: 0.5164
# Validation Loss: 0.6619
# Epoch [135/200], Loss: 0.2020
# Validation Loss: 0.6712
# Epoch [136/200], Loss: 0.8222
# Validation Loss: 0.7002
# Epoch [137/200], Loss: 0.7429
# Validation Loss: 0.6739
# Epoch [138/200], Loss: 0.8901
# Validation Loss: 0.7050
# Epoch [139/200], Loss: 0.5632
# Validation Loss: 0.7122
# Epoch [140/200], Loss: 0.5484
# Validation Loss: 0.6816
# Epoch [141/200], Loss: 0.5546
# Validation Loss: 0.6802
# Epoch [142/200], Loss: 1.0827
# Validation Loss: 0.7096
# Epoch [143/200], Loss: 0.7921
# Validation Loss: 0.7026
# Epoch [144/200], Loss: 0.4087
# Validation Loss: 0.7297
# Epoch [145/200], Loss: 0.3745
# Validation Loss: 0.7006
# Epoch [146/200], Loss: 0.6086
# Validation Loss: 0.6735
# Epoch [147/200], Loss: 0.5645
# Validation Loss: 0.7051
# Epoch [148/200], Loss: 0.7238
# Validation Loss: 0.6928
# Epoch [149/200], Loss: 0.4054
# Validation Loss: 0.6940
# Epoch [150/200], Loss: 0.7379
# Validation Loss: 0.6853
# Epoch [151/200], Loss: 0.5223
# Validation Loss: 0.6626
# Epoch [152/200], Loss: 0.5240
# Validation Loss: 0.6649
# Epoch [153/200], Loss: 0.6095
# Validation Loss: 0.6625
# Epoch [154/200], Loss: 0.4652
# Validation Loss: 0.7106
# Epoch [155/200], Loss: 0.5764
# Validation Loss: 0.7100
# Epoch [156/200], Loss: 0.5307
# Validation Loss: 0.6944
# Epoch [157/200], Loss: 1.0633
# Validation Loss: 0.6948
# Epoch [158/200], Loss: 0.7252
# Validation Loss: 0.6937
# Epoch [159/200], Loss: 0.2401
# Validation Loss: 0.6870
# Epoch [160/200], Loss: 0.5561
# Validation Loss: 0.6927
# Epoch [161/200], Loss: 0.5391
# Validation Loss: 0.6710
# Epoch [162/200], Loss: 0.4982
# Validation Loss: 0.6825
# Epoch [163/200], Loss: 0.7055
# Validation Loss: 0.6738
# Epoch [164/200], Loss: 0.4980
# Validation Loss: 0.6618
# Epoch [165/200], Loss: 0.7899
# Validation Loss: 0.6635
# Epoch [166/200], Loss: 0.3283
# Validation Loss: 0.6807
# Epoch [167/200], Loss: 0.3661
# Validation Loss: 0.6768
# Epoch [168/200], Loss: 0.7199
# Validation Loss: 0.6976
# Epoch [169/200], Loss: 0.5355
# Validation Loss: 0.6855
# Epoch [170/200], Loss: 0.8011
# Validation Loss: 0.6813
# Epoch [171/200], Loss: 0.8158
# Validation Loss: 0.6847
# Epoch [172/200], Loss: 0.5338
# Validation Loss: 0.7107
# Epoch [173/200], Loss: 0.4098
# Validation Loss: 0.7363
# Epoch [174/200], Loss: 0.4465
# Validation Loss: 0.7453
# Epoch [175/200], Loss: 0.3898
# Validation Loss: 0.7044
# Epoch [176/200], Loss: 0.5298
# Validation Loss: 0.6985
# Epoch [177/200], Loss: 0.7445
# Validation Loss: 0.7017
# Epoch [178/200], Loss: 0.5389
# Validation Loss: 0.6827
# Epoch [179/200], Loss: 0.9781
# Validation Loss: 0.6881
# Epoch [180/200], Loss: 1.1332
# Validation Loss: 0.6877
# Epoch [181/200], Loss: 0.4950
# Validation Loss: 0.6865
# Epoch [182/200], Loss: 0.5141
# Validation Loss: 0.7003
# Epoch [183/200], Loss: 0.8180
# Validation Loss: 0.6946
# Epoch [184/200], Loss: 0.9197
# Validation Loss: 0.6933
# Epoch [185/200], Loss: 0.3501
# Validation Loss: 0.7108
# Epoch [186/200], Loss: 0.2300
# Validation Loss: 0.7165
# Epoch [187/200], Loss: 0.5330
# Validation Loss: 0.7223
# Epoch [188/200], Loss: 0.7302
# Validation Loss: 0.6918
# Epoch [189/200], Loss: 0.5729
# Validation Loss: 0.6663
# Epoch [190/200], Loss: 0.5711
# Validation Loss: 0.6767
# Epoch [191/200], Loss: 0.2929
# Validation Loss: 0.6966
# Epoch [192/200], Loss: 0.7342
# Validation Loss: 0.6927
# Epoch [193/200], Loss: 1.0822
# Validation Loss: 0.6882
# Epoch [194/200], Loss: 0.5310
# Validation Loss: 0.6937
# Epoch [195/200], Loss: 0.5382
# Validation Loss: 0.6853
# Epoch [196/200], Loss: 1.0561
# Validation Loss: 0.6828
# Epoch [197/200], Loss: 0.4112
# Validation Loss: 0.6892
# Epoch [198/200], Loss: 0.5348
# Validation Loss: 0.6957
# Epoch [199/200], Loss: 0.3657
# Validation Loss: 0.6891
# Epoch [200/200], Loss: 0.4388
# Validation Loss: 0.7208
# Trial 4, Fold 5/5
# type of train_loader <class 'torch.utils.data.dataloader.DataLoader'>
# Epoch [1/200], Loss: 0.6797
# Validation Loss: 0.8278
# Epoch [2/200], Loss: 0.8875
# Validation Loss: 0.7541
# Epoch [3/200], Loss: 0.5335
# Validation Loss: 0.7680
# Epoch [4/200], Loss: 0.6919
# Validation Loss: 0.7295
# Epoch [5/200], Loss: 0.3744
# Validation Loss: 0.7003
# Epoch [6/200], Loss: 0.3363
# Validation Loss: 0.7139
# Epoch [7/200], Loss: 0.6951
# Validation Loss: 0.7410
# Epoch [8/200], Loss: 0.0174
# Validation Loss: 0.7004
# Epoch [9/200], Loss: 1.0181
# Validation Loss: 0.6942
# Epoch [10/200], Loss: 0.3367
# Validation Loss: 0.7348
# Epoch [11/200], Loss: 0.7384
# Validation Loss: 0.7044
# Epoch [12/200], Loss: 0.5232
# Validation Loss: 0.6971
# Epoch [13/200], Loss: 0.6163
# Validation Loss: 0.7068
# Epoch [14/200], Loss: 0.8487
# Validation Loss: 0.7203
# Epoch [15/200], Loss: 1.0338
# Validation Loss: 0.6967
# Epoch [16/200], Loss: 0.3074
# Validation Loss: 0.7104
# Epoch [17/200], Loss: 0.5520
# Validation Loss: 0.7177
# Epoch [18/200], Loss: 0.2279
# Validation Loss: 0.6823
# Epoch [19/200], Loss: 0.5456
# Validation Loss: 0.6916
# Epoch [20/200], Loss: 0.3647
# Validation Loss: 0.7270
# Epoch [21/200], Loss: 0.2118
# Validation Loss: 0.7028
# Epoch [22/200], Loss: 0.0510
# Validation Loss: 0.7246
# Epoch [23/200], Loss: 0.2040
# Validation Loss: 0.6774
# Epoch [24/200], Loss: 0.7114
# Validation Loss: 0.7203
# Epoch [25/200], Loss: 0.5692
# Validation Loss: 0.7009
# Epoch [26/200], Loss: 0.5085
# Validation Loss: 0.7047
# Epoch [27/200], Loss: 0.6999
# Validation Loss: 0.6990
# Epoch [28/200], Loss: 0.8536
# Validation Loss: 0.6962
# Epoch [29/200], Loss: 0.7173
# Validation Loss: 0.7027
# Epoch [30/200], Loss: 0.7386
# Validation Loss: 0.6978
# Epoch [31/200], Loss: 0.3715
# Validation Loss: 0.7148
# Epoch [32/200], Loss: 0.5424
# Validation Loss: 0.7147
# Epoch [33/200], Loss: 0.7209
# Validation Loss: 0.7055
# Epoch [34/200], Loss: 0.5620
# Validation Loss: 0.7259
# Epoch [35/200], Loss: 0.7129
# Validation Loss: 0.6972
# Epoch [36/200], Loss: 0.3903
# Validation Loss: 0.7044
# Epoch [37/200], Loss: 0.8623
# Validation Loss: 0.7052
# Epoch [38/200], Loss: 0.3845
# Validation Loss: 0.6933
# Epoch [39/200], Loss: 0.4101
# Validation Loss: 0.7069
# Epoch [40/200], Loss: 0.4568
# Validation Loss: 0.6921
# Epoch [41/200], Loss: 0.5255
# Validation Loss: 0.6979
# Epoch [42/200], Loss: 0.3714
# Validation Loss: 0.7091
# Epoch [43/200], Loss: 0.7495
# Validation Loss: 0.7022
# Epoch [44/200], Loss: 0.9151
# Validation Loss: 0.7267
# Epoch [45/200], Loss: 0.3890
# Validation Loss: 0.6911
# Epoch [46/200], Loss: 0.5406
# Validation Loss: 0.7219
# Epoch [47/200], Loss: 0.5376
# Validation Loss: 0.7143
# Epoch [48/200], Loss: 0.8243
# Validation Loss: 0.6973
# Epoch [49/200], Loss: 0.7327
# Validation Loss: 0.6943
# Epoch [50/200], Loss: 0.4653
# Validation Loss: 0.7094
# Epoch [51/200], Loss: 0.8496
# Validation Loss: 0.6995
# Epoch [52/200], Loss: 1.0390
# Validation Loss: 0.7071
# Epoch [53/200], Loss: 0.5157
# Validation Loss: 0.7201
# Epoch [54/200], Loss: 0.2095
# Validation Loss: 0.7116
# Epoch [55/200], Loss: 0.9193
# Validation Loss: 0.7020
# Epoch [56/200], Loss: 0.6098
# Validation Loss: 0.7311
# Epoch [57/200], Loss: 0.5343
# Validation Loss: 0.7008
# Epoch [58/200], Loss: 0.4617
# Validation Loss: 0.6875
# Epoch [59/200], Loss: 0.7923
# Validation Loss: 0.6953
# Epoch [60/200], Loss: 0.3189
# Validation Loss: 0.7046
# Epoch [61/200], Loss: 0.6739
# Validation Loss: 0.7376
# Epoch [62/200], Loss: 0.6576
# Validation Loss: 0.6967
# Epoch [63/200], Loss: 0.4598
# Validation Loss: 0.7177
# Epoch [64/200], Loss: 0.5042
# Validation Loss: 0.7017
# Epoch [65/200], Loss: 0.4737
# Validation Loss: 0.7118
# Epoch [66/200], Loss: 0.4089
# Validation Loss: 0.7103
# Epoch [67/200], Loss: 0.9027
# Validation Loss: 0.7044
# Epoch [68/200], Loss: 0.6649
# Validation Loss: 0.6909
# Epoch [69/200], Loss: 0.1956
# Validation Loss: 0.7040
# Epoch [70/200], Loss: 0.4224
# Validation Loss: 0.7022
# Epoch [71/200], Loss: 0.5479
# Validation Loss: 0.7240
# Epoch [72/200], Loss: 0.8565
# Validation Loss: 0.7138
# Epoch [73/200], Loss: 0.4941
# Validation Loss: 0.7084
# Epoch [74/200], Loss: 0.6957
# Validation Loss: 0.7543
# Epoch [75/200], Loss: 0.5361
# Validation Loss: 0.7095
# Epoch [76/200], Loss: 0.5336
# Validation Loss: 0.7076
# Epoch [77/200], Loss: 0.5184
# Validation Loss: 0.7129
# Epoch [78/200], Loss: 0.7196
# Validation Loss: 0.7144
# Epoch [79/200], Loss: 0.3612
# Validation Loss: 0.7106
# Epoch [80/200], Loss: 0.7230
# Validation Loss: 0.7472
# Epoch [81/200], Loss: 0.5293
# Validation Loss: 0.7278
# Epoch [82/200], Loss: 0.8861
# Validation Loss: 0.7310
# Epoch [83/200], Loss: 0.5444
# Validation Loss: 0.7038
# Epoch [84/200], Loss: 0.3842
# Validation Loss: 0.7262
# Epoch [85/200], Loss: 0.1967
# Validation Loss: 0.7297
# Epoch [86/200], Loss: 0.3639
# Validation Loss: 0.7189
# Epoch [87/200], Loss: 0.5602
# Validation Loss: 0.7312
# Epoch [88/200], Loss: 0.7221
# Validation Loss: 0.7124
# Epoch [89/200], Loss: 0.8765
# Validation Loss: 0.7146
# Epoch [90/200], Loss: 0.6027
# Validation Loss: 0.7322
# Epoch [91/200], Loss: 0.5160
# Validation Loss: 0.7179
# Epoch [92/200], Loss: 0.5438
# Validation Loss: 0.7294
# Epoch [93/200], Loss: 0.5241
# Validation Loss: 0.7015
# Epoch [94/200], Loss: 0.7137
# Validation Loss: 0.7115
# Epoch [95/200], Loss: 0.2151
# Validation Loss: 0.6996
# Epoch [96/200], Loss: 0.5347
# Validation Loss: 0.7293
# Epoch [97/200], Loss: 0.2247
# Validation Loss: 0.7137
# Epoch [98/200], Loss: 0.5250
# Validation Loss: 0.7131
# Epoch [99/200], Loss: 0.5449
# Validation Loss: 0.7091
# Epoch [100/200], Loss: 0.2114
# Validation Loss: 0.7067
# Epoch [101/200], Loss: 0.7655
# Validation Loss: 0.6837
# Epoch [102/200], Loss: 0.3031
# Validation Loss: 0.7057
# Epoch [103/200], Loss: 0.5226
# Validation Loss: 0.6812
# Epoch [104/200], Loss: 0.9145
# Validation Loss: 0.7084
# Epoch [105/200], Loss: 0.5219
# Validation Loss: 0.7095
# Epoch [106/200], Loss: 0.3815
# Validation Loss: 0.7239
# Epoch [107/200], Loss: 0.5724
# Validation Loss: 0.7048
# Epoch [108/200], Loss: 0.3141
# Validation Loss: 0.7102
# Epoch [109/200], Loss: 0.4004
# Validation Loss: 0.6936
# Epoch [110/200], Loss: 0.3453
# Validation Loss: 0.7005
# Epoch [111/200], Loss: 1.1876
# Validation Loss: 0.7366
# Epoch [112/200], Loss: 0.9260
# Validation Loss: 0.6841
# Epoch [113/200], Loss: 0.8816
# Validation Loss: 0.7085
# Epoch [114/200], Loss: 0.5247
# Validation Loss: 0.7053
# Epoch [115/200], Loss: 0.7124
# Validation Loss: 0.7008
# Epoch [116/200], Loss: 0.7355
# Validation Loss: 0.7112
# Epoch [117/200], Loss: 1.1659
# Validation Loss: 0.7161
# Epoch [118/200], Loss: 0.7306
# Validation Loss: 0.6956
# Epoch [119/200], Loss: 0.7143
# Validation Loss: 0.7030
# Epoch [120/200], Loss: 0.5048
# Validation Loss: 0.6982
# Epoch [121/200], Loss: 0.5247
# Validation Loss: 0.7199
# Epoch [122/200], Loss: 0.8103
# Validation Loss: 0.6947
# Epoch [123/200], Loss: 0.3389
# Validation Loss: 0.6955
# Epoch [124/200], Loss: 0.3036
# Validation Loss: 0.7136
# Epoch [125/200], Loss: 0.7207
# Validation Loss: 0.7119
# Epoch [126/200], Loss: 0.4218
# Validation Loss: 0.7221
# Epoch [127/200], Loss: 0.8432
# Validation Loss: 0.7057
# Epoch [128/200], Loss: 0.3668
# Validation Loss: 0.7175
# Epoch [129/200], Loss: 0.5711
# Validation Loss: 0.7181
# Epoch [130/200], Loss: 0.5336
# Validation Loss: 0.7023
# Epoch [131/200], Loss: 0.4485
# Validation Loss: 0.6944
# Epoch [132/200], Loss: 0.7245
# Validation Loss: 0.7263
# Epoch [133/200], Loss: 1.1067
# Validation Loss: 0.7283
# Epoch [134/200], Loss: 0.5506
# Validation Loss: 0.7174
# Epoch [135/200], Loss: 0.9172
# Validation Loss: 0.7029
# Epoch [136/200], Loss: 0.3178
# Validation Loss: 0.7251
# Epoch [137/200], Loss: 0.3685
# Validation Loss: 0.6995
# Epoch [138/200], Loss: 0.0199
# Validation Loss: 0.7227
# Epoch [139/200], Loss: 0.9188
# Validation Loss: 0.7181
# Epoch [140/200], Loss: 0.8720
# Validation Loss: 0.7336
# Epoch [141/200], Loss: 0.7269
# Validation Loss: 0.7140
# Epoch [142/200], Loss: 0.3788
# Validation Loss: 0.7083
# Epoch [143/200], Loss: 1.0678
# Validation Loss: 0.7042
# Epoch [144/200], Loss: 0.4198
# Validation Loss: 0.7000
# Epoch [145/200], Loss: 0.8561
# Validation Loss: 0.7151
# Epoch [146/200], Loss: 0.4699
# Validation Loss: 0.7040
# Epoch [147/200], Loss: 0.3720
# Validation Loss: 0.7362
# Epoch [148/200], Loss: 0.2901
# Validation Loss: 0.7022
# Epoch [149/200], Loss: 1.2084
# Validation Loss: 0.7245
# Epoch [150/200], Loss: 0.7562
# Validation Loss: 0.6985
# Epoch [151/200], Loss: 0.5823
# Validation Loss: 0.7356
# Epoch [152/200], Loss: 0.7228
# Validation Loss: 0.6971
# Epoch [153/200], Loss: 0.6039
# Validation Loss: 0.7213
# Epoch [154/200], Loss: 0.5926
# Validation Loss: 0.6997
# Epoch [155/200], Loss: 0.7088
# Validation Loss: 0.7217
# Epoch [156/200], Loss: 0.5284
# Validation Loss: 0.7016
# Epoch [157/200], Loss: 0.8659
# Validation Loss: 0.7093
# Epoch [158/200], Loss: 1.0641
# Validation Loss: 0.7089
# Epoch [159/200], Loss: 0.0190
# Validation Loss: 0.7192
# Epoch [160/200], Loss: 0.8134
# Validation Loss: 0.7001
# Epoch [161/200], Loss: 0.4261
# Validation Loss: 0.7125
# Epoch [162/200], Loss: 0.7424
# Validation Loss: 0.7096
# Epoch [163/200], Loss: 1.0366
# Validation Loss: 0.6951
# Epoch [164/200], Loss: 0.5366
# Validation Loss: 0.7022
# Epoch [165/200], Loss: 0.3084
# Validation Loss: 0.7162
# Epoch [166/200], Loss: 0.0194
# Validation Loss: 0.7054
# Epoch [167/200], Loss: 0.3202
# Validation Loss: 0.7165
# Epoch [168/200], Loss: 0.7311
# Validation Loss: 0.7288
# Epoch [169/200], Loss: 0.8615
# Validation Loss: 0.7198
# Epoch [170/200], Loss: 0.5298
# Validation Loss: 0.7231
# Epoch [171/200], Loss: 0.3281
# Validation Loss: 0.7318
# Epoch [172/200], Loss: 0.3025
# Validation Loss: 0.7334
# Epoch [173/200], Loss: 0.3070
# Validation Loss: 0.7162
# Epoch [174/200], Loss: 0.3117
# Validation Loss: 0.7207
# Epoch [175/200], Loss: 0.5185
# Validation Loss: 0.7032
# Epoch [176/200], Loss: 0.0494
# Validation Loss: 0.7470
# Epoch [177/200], Loss: 0.7500
# Validation Loss: 0.7262
# Epoch [178/200], Loss: 0.5272
# Validation Loss: 0.7173
# Epoch [179/200], Loss: 0.3293
# Validation Loss: 0.7172
# Epoch [180/200], Loss: 0.8359
# Validation Loss: 0.7249
# Epoch [181/200], Loss: 0.2005
# Validation Loss: 0.7119
# Epoch [182/200], Loss: 0.5606
# Validation Loss: 0.7353
# Epoch [183/200], Loss: 0.3731
# Validation Loss: 0.7215
# Epoch [184/200], Loss: 0.8417
# Validation Loss: 0.7055
# Epoch [185/200], Loss: 0.4173
# Validation Loss: 0.7069
# Epoch [186/200], Loss: 0.8646
# Validation Loss: 0.7354
# Epoch [187/200], Loss: 0.7330
# Validation Loss: 0.7119
# Epoch [188/200], Loss: 0.2267
# Validation Loss: 0.6991
# Epoch [189/200], Loss: 0.3605
# Validation Loss: 0.6960
# Epoch [190/200], Loss: 0.5510
# Validation Loss: 0.7042
# Epoch [191/200], Loss: 0.7095
# Validation Loss: 0.7136
# Epoch [192/200], Loss: 0.8413
# Validation Loss: 0.7020
# Epoch [193/200], Loss: 0.7911
# Validation Loss: 0.7127
# Epoch [194/200], Loss: 0.8450
# Validation Loss: 0.7194
# Epoch [195/200], Loss: 0.5339
# Validation Loss: 0.7020
# Epoch [196/200], Loss: 0.4770
# Validation Loss: 0.6911
# Epoch [197/200], Loss: 0.8419
# Validation Loss: 0.7245
# Epoch [198/200], Loss: 0.4840
# Validation Loss: 0.6989
# [I 2024-03-24 14:59:06,352] Trial 4 finished with value: 0.6461048281192779 and parameters: {'seed': 13}. Best is trial 3 with value: 0.6268693971633912.
# Epoch [199/200], Loss: 1.0794
# Validation Loss: 0.7282
# Epoch [200/200], Loss: 0.2101
# Validation Loss: 0.6955
# Best hyperparameters: {'seed': 1986}

# %%
best_params = study.best_params
best_params
# Out:
# {'seed': 1986}

# %%
best_params = study.best_params
# extract best_parameters
batch_size = best_params['batch_size']
lr = best_params['lr']
h1 = best_params['h1']
h2 = best_params['h2']
num_epochs = best_params['num_epochs']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[156], line 3
#       1 best_params = study.best_params
#       2 # extract best_parameters
# ----> 3 batch_size = best_params['batch_size']
#       4 lr = best_params['lr']
#       5 h1 = best_params['h1']
#
# KeyError: 'batch_size'

# %% [markdown]
# #### train and evaluate final model on test set:
#
# Unfortunately Optuna cannot output the best model, so we train again on the combined train and validation set with the best parameters found.

# %% [markdown]
# dataloader for final evaluation:

# %%
train_and_eval_loader = preprocess_dataset(mmpose_model, train_and_val_dataset, get_device())
test_loader = preprocess_dataset(mmpose_model, test_dataset, get_device())
# Out:
# Image processed in 112.85 ms
# Image processed in 62.68 ms
# Image processed in 61.85 ms
# Image processed in 58.51 ms
# Image processed in 62.82 ms
# Image processed in 63.22 ms
# Image processed in 60.42 ms
# Image processed in 60.82 ms
# Image processed in 54.75 ms
# Image processed in 57.09 ms
# Image processed in 58.36 ms
# Image processed in 58.68 ms
# Image processed in 63.09 ms
# Image processed in 62.29 ms
# Image processed in 63.19 ms
# Image processed in 60.65 ms
# Image processed in 58.50 ms
# Image processed in 64.25 ms
# Image processed in 66.18 ms
# Image processed in 63.61 ms
# Image processed in 60.31 ms
# Image processed in 61.46 ms
# Image processed in 61.57 ms
# Image processed in 61.95 ms
# Image processed in 61.38 ms
# Image processed in 62.43 ms
# Image processed in 58.98 ms
# Image processed in 57.29 ms
# Image processed in 58.04 ms
# Image processed in 53.93 ms
# Image processed in 61.89 ms
# Image processed in 60.12 ms
# Image processed in 60.72 ms
# Image processed in 52.80 ms
# Image processed in 62.11 ms
# Image processed in 55.29 ms
# Image processed in 62.00 ms
# Image processed in 63.99 ms
# Image processed in 59.59 ms
# Image processed in 56.56 ms
# Image processed in 59.74 ms
# Image processed in 60.20 ms
# Image processed in 63.17 ms
# Image processed in 60.48 ms
# Image processed in 58.63 ms
# Image processed in 59.92 ms
# Image processed in 59.83 ms
# Image processed in 60.28 ms
# Image processed in 63.03 ms
# Image processed in 58.90 ms
# Image processed in 59.99 ms
# Image processed in 64.76 ms
# Image processed in 58.77 ms
# Image processed in 59.95 ms
# Image processed in 58.66 ms
# Image processed in 57.05 ms
# Image processed in 64.45 ms
# Image processed in 64.33 ms
# Image processed in 71.74 ms
# Image processed in 70.45 ms
# Image processed in 66.13 ms
# Image processed in 61.14 ms
# Image processed in 66.61 ms
# Image processed in 59.90 ms
# Image processed in 62.69 ms
# Image processed in 63.23 ms
# Image processed in 57.47 ms
# Image processed in 64.52 ms
# Image processed in 61.26 ms
# Image processed in 62.96 ms
# Image processed in 60.36 ms
# Image processed in 62.01 ms
# Image processed in 61.71 ms
# Image processed in 60.20 ms
# Image processed in 59.44 ms
# Image processed in 60.08 ms
# Image processed in 59.53 ms
# Image processed in 59.18 ms
# Image processed in 57.76 ms
# Image processed in 62.03 ms
# Image processed in 62.79 ms
# Image processed in 64.09 ms
# Image processed in 70.57 ms
# Image processed in 58.72 ms
# Image processed in 58.07 ms
# Image processed in 60.04 ms
# Image processed in 60.31 ms
# Image processed in 63.02 ms
# Image processed in 60.95 ms
# Image processed in 61.30 ms
# Image processed in 56.98 ms
# Image processed in 61.16 ms
# Image processed in 61.40 ms
# Image processed in 60.13 ms
# Image processed in 60.46 ms
# Image processed in 65.39 ms
# Image processed in 61.99 ms
# Image processed in 55.63 ms
# Image processed in 63.04 ms
# Image processed in 57.77 ms
# Image processed in 60.47 ms
# Image processed in 63.19 ms
# Image processed in 60.29 ms
# Image processed in 60.87 ms
# Image processed in 53.70 ms
# Image processed in 62.16 ms
# Image processed in 60.76 ms
# Image processed in 61.60 ms
# Image processed in 61.84 ms
# Image processed in 59.06 ms
# Image processed in 59.57 ms
# Image processed in 57.04 ms
# Image processed in 55.49 ms
# Image processed in 60.27 ms
# Image processed in 59.84 ms
# Image processed in 60.88 ms
# Image processed in 62.36 ms
# Image processed in 60.20 ms

# %% [markdown]
# final evaluation on test set:

# %%
# new instance of the model:
kp_model = KeypointScorer(num_keypoints, h1, h2)
# kp_model = KeypointClassifier(num_keypoints, num_classes, h1, h2)
kp_model = kp_model.to(get_device())  # move model to device
kp_model.train()  # set model to training mode

# loss function and optimizer
criterion = nn.MSELoss() # nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(kp_model.parameters(), lr=lr, weight_decay=1e-5)

for epoch in range(num_epochs):
    for inputs, labels in train_and_eval_loader:  # Assuming data_loader is your DataLoader instance for the dataset
        inputs, labels = inputs.to(get_device()), labels.to(get_device())  # move data to device
        optimizer.zero_grad()  # Zero the parameter gradients
        classification_output = kp_model(inputs) # get results for the classification 
        
        # Use this for classification
        # loss = criterion(classification_output, labels)
        
        # Use this for scoring
        loss = criterion(classification_output.float(), labels.float())
        
        loss.backward()  # Backpropagate the loss
        optimizer.step()  # Update weights

        # todo: further processing, such as calculating accuracy or loss, goes here

    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')
        
    
kp_model.eval()  # model to evaluation mode

total_loss = 0
all_predictions = []
all_labels = []
with torch.no_grad():  # no need to compute gradients, because we are in evaluation mode
    for inputs, labels in test_loader:  # iterate over validation dataset
        inputs, labels = inputs.to(get_device()), labels.to(get_device())  # move data to device
        classification_output = kp_model(inputs) # get results for the classification 
        
        # Use this for classification
        loss = criterion(classification_output, labels)
        
        # Use this for scoring
        # loss = criterion(classification_output.float(), labels.float())
        
        total_loss += loss.item()  # accumulate the loss
        
        if classification_output.data.dim() == 1:
            classification_output.data = classification_output.data.unsqueeze(0)
        
        _, predicted = torch.max(classification_output.data, 1)
        # collect the predictions and labels
        all_predictions.extend(predicted.cpu().numpy())
        
        if labels.dim() == 0:
            labels = labels.unsqueeze(0)  # Add a dimension to make it iterable
        all_labels.extend(labels.cpu().numpy())
    # calculate the validation metrics:
    avg_loss = total_loss / len(test_loader)  # get the average loss
    # accuracy = (np.array(all_predictions) == np.array(all_labels)).mean()
    # f1 = f1_score(all_labels, all_predictions, average='weighted')  
    # conf_matrix = confusion_matrix(all_labels, all_predictions)
    
    print(f"Test Loss: {avg_loss:.4f}")
    # print(f"Test Accuracy: {accuracy:.4f}")
    # print(f"Test F1 Score: {f1:.4f}")
    # print("Confusion Matrix:")
    # print(conf_matrix)
# Out:
# e:\Users\Vipin\Documents\BHT\3. Semester\Learning from images\ergonomic_pose_detect\.venv\lib\site-packages\torch\nn\modules\loss.py:535: UserWarning: Using a target size (torch.Size([])) that is different to the input size (torch.Size([1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch [1/200], Loss: 11.8278
# Epoch [2/200], Loss: 3.8881
# Epoch [3/200], Loss: 3.2793
# Epoch [4/200], Loss: 3.0183
# Epoch [5/200], Loss: 0.8485
# Epoch [6/200], Loss: 2.2129
# Epoch [7/200], Loss: 3.3966
# Epoch [8/200], Loss: 0.5521
# Epoch [9/200], Loss: 3.3730
# Epoch [10/200], Loss: 1.7887
# Epoch [11/200], Loss: 0.3325
# Epoch [12/200], Loss: 0.4270
# Epoch [13/200], Loss: 0.4965
# Epoch [14/200], Loss: 0.6571
# Epoch [15/200], Loss: 0.5159
# Epoch [16/200], Loss: 0.5595
# Epoch [17/200], Loss: 0.4413
# Epoch [18/200], Loss: 0.6999
# Epoch [19/200], Loss: 1.2832
# Epoch [20/200], Loss: 0.2218
# Epoch [21/200], Loss: 0.2286
# Epoch [22/200], Loss: 0.0025
# Epoch [23/200], Loss: 0.1119
# Epoch [24/200], Loss: 0.0659
# Epoch [25/200], Loss: 0.4963
# Epoch [26/200], Loss: 0.0802
# Epoch [27/200], Loss: 0.0000
# Epoch [28/200], Loss: 1.3841
# Epoch [29/200], Loss: 0.6992
# Epoch [30/200], Loss: 0.3252
# Epoch [31/200], Loss: 0.0203
# Epoch [32/200], Loss: 1.6401
# Epoch [33/200], Loss: 1.0623
# Epoch [34/200], Loss: 1.3181
# Epoch [35/200], Loss: 0.4768
# Epoch [36/200], Loss: 0.0009
# Epoch [37/200], Loss: 0.1246
# Epoch [38/200], Loss: 0.5090
# Epoch [39/200], Loss: 0.3852
# Epoch [40/200], Loss: 0.0000
# Epoch [41/200], Loss: 0.8756
# Epoch [42/200], Loss: 0.8698
# Epoch [43/200], Loss: 0.6933
# Epoch [44/200], Loss: 0.0237
# Epoch [45/200], Loss: 0.0430
# Epoch [46/200], Loss: 0.0881
# Epoch [47/200], Loss: 1.2374
# Epoch [48/200], Loss: 0.5841
# Epoch [49/200], Loss: 0.0334
# Epoch [50/200], Loss: 0.2100
# Epoch [51/200], Loss: 0.0017
# Epoch [52/200], Loss: 0.0857
# Epoch [53/200], Loss: 0.0370
# Epoch [54/200], Loss: 0.0199
# Epoch [55/200], Loss: 0.0413
# Epoch [56/200], Loss: 0.3937
# Epoch [57/200], Loss: 0.0007
# Epoch [58/200], Loss: 0.0021
# Epoch [59/200], Loss: 1.6384
# Epoch [60/200], Loss: 0.0287
# Epoch [61/200], Loss: 0.0007
# Epoch [62/200], Loss: 0.2141
# Epoch [63/200], Loss: 2.9981
# Epoch [64/200], Loss: 1.0921
# Epoch [65/200], Loss: 5.7795
# Epoch [66/200], Loss: 0.0838
# Epoch [67/200], Loss: 0.0014
# Epoch [68/200], Loss: 1.4669
# Epoch [69/200], Loss: 0.2359
# Epoch [70/200], Loss: 0.0248
# Epoch [71/200], Loss: 0.0340
# Epoch [72/200], Loss: 0.5573
# Epoch [73/200], Loss: 0.0003
# Epoch [74/200], Loss: 0.2825
# Epoch [75/200], Loss: 2.6987
# Epoch [76/200], Loss: 0.1626
# Epoch [77/200], Loss: 0.3376
# Epoch [78/200], Loss: 0.2524
# Epoch [79/200], Loss: 0.5633
# Epoch [80/200], Loss: 0.0199
# Epoch [81/200], Loss: 0.7521
# Epoch [82/200], Loss: 0.0124
# Epoch [83/200], Loss: 1.4164
# Epoch [84/200], Loss: 0.3026
# Epoch [85/200], Loss: 0.1334
# Epoch [86/200], Loss: 0.1023
# Epoch [87/200], Loss: 0.0317
# Epoch [88/200], Loss: 0.0077
# Epoch [89/200], Loss: 0.4000
# Epoch [90/200], Loss: 1.6077
# Epoch [91/200], Loss: 1.1682
# Epoch [92/200], Loss: 0.5106
# Epoch [93/200], Loss: 0.5006
# Epoch [94/200], Loss: 0.4237
# Epoch [95/200], Loss: 0.9212
# Epoch [96/200], Loss: 0.2157
# Epoch [97/200], Loss: 1.1866
# Epoch [98/200], Loss: 0.4230
# Epoch [99/200], Loss: 0.1007
# Epoch [100/200], Loss: 1.3611
# Epoch [101/200], Loss: 0.7630
# Epoch [102/200], Loss: 0.1533
# Epoch [103/200], Loss: 0.5955
# Epoch [104/200], Loss: 0.1531
# Epoch [105/200], Loss: 0.0020
# Epoch [106/200], Loss: 0.6348
# Epoch [107/200], Loss: 0.0378
# Epoch [108/200], Loss: 0.1269
# Epoch [109/200], Loss: 0.9640
# Epoch [110/200], Loss: 0.4191
# Epoch [111/200], Loss: 1.6758
# Epoch [112/200], Loss: 0.1921
# Epoch [113/200], Loss: 0.0043
# Epoch [114/200], Loss: 0.0648
# Epoch [115/200], Loss: 0.0642
# Epoch [116/200], Loss: 0.3752
# Epoch [117/200], Loss: 0.0005
# Epoch [118/200], Loss: 0.0455
# Epoch [119/200], Loss: 0.0013
# Epoch [120/200], Loss: 0.0952
# Epoch [121/200], Loss: 0.2437
# Epoch [122/200], Loss: 0.0559
# Epoch [123/200], Loss: 0.0092
# Epoch [124/200], Loss: 0.4642
# Epoch [125/200], Loss: 1.3089
# Epoch [126/200], Loss: 0.1790
# Epoch [127/200], Loss: 0.2532
# Epoch [128/200], Loss: 0.1143
# Epoch [129/200], Loss: 0.4437
# Epoch [130/200], Loss: 0.6719
# Epoch [131/200], Loss: 0.9064
# Epoch [132/200], Loss: 0.8678
# Epoch [133/200], Loss: 0.6007
# Epoch [134/200], Loss: 0.0390
# Epoch [135/200], Loss: 0.0782
# Epoch [136/200], Loss: 0.1423
# Epoch [137/200], Loss: 0.1766
# Epoch [138/200], Loss: 0.1656
# Epoch [139/200], Loss: 0.0325
# Epoch [140/200], Loss: 0.0326
# Epoch [141/200], Loss: 0.0808
# Epoch [142/200], Loss: 4.4236
# Epoch [143/200], Loss: 0.6750
# Epoch [144/200], Loss: 0.5000
# Epoch [145/200], Loss: 1.9839
# Epoch [146/200], Loss: 0.0215
# Epoch [147/200], Loss: 0.0001
# Epoch [148/200], Loss: 0.0108
# Epoch [149/200], Loss: 0.3192
# Epoch [150/200], Loss: 0.0070
# Epoch [151/200], Loss: 0.1104
# Epoch [152/200], Loss: 0.2419
# Epoch [153/200], Loss: 0.0147
# Epoch [154/200], Loss: 0.7141
# Epoch [155/200], Loss: 0.0185
# Epoch [156/200], Loss: 0.0483
# Epoch [157/200], Loss: 0.0376
# Epoch [158/200], Loss: 0.5892
# Epoch [159/200], Loss: 0.1552
# Epoch [160/200], Loss: 0.0426
# Epoch [161/200], Loss: 0.2444
# Epoch [162/200], Loss: 0.5519
# Epoch [163/200], Loss: 0.3496
# Epoch [164/200], Loss: 1.5387
# Epoch [165/200], Loss: 0.2654
# Epoch [166/200], Loss: 0.0292
# Epoch [167/200], Loss: 0.7294
# Epoch [168/200], Loss: 0.9498
# Epoch [169/200], Loss: 0.2714
# Epoch [170/200], Loss: 0.0742
# Epoch [171/200], Loss: 0.0012
# Epoch [172/200], Loss: 0.1912
# Epoch [173/200], Loss: 0.0714
# Epoch [174/200], Loss: 0.2351
# Epoch [175/200], Loss: 0.0112
# Epoch [176/200], Loss: 0.4943
# Epoch [177/200], Loss: 0.1993
# Epoch [178/200], Loss: 0.6491
# Epoch [179/200], Loss: 0.4826
# Epoch [180/200], Loss: 0.1916
# Epoch [181/200], Loss: 0.4630
# Epoch [182/200], Loss: 0.0195
# Epoch [183/200], Loss: 1.7291
# Epoch [184/200], Loss: 0.1234
# Epoch [185/200], Loss: 0.1072
# Epoch [186/200], Loss: 0.1020
# Epoch [187/200], Loss: 0.2394
# Epoch [188/200], Loss: 0.0145
# Epoch [189/200], Loss: 0.0983
# Epoch [190/200], Loss: 0.0115
# Epoch [191/200], Loss: 0.2860
# Epoch [192/200], Loss: 0.2698
# Epoch [193/200], Loss: 0.3872
# Epoch [194/200], Loss: 0.0081
# Epoch [195/200], Loss: 0.0000
# Epoch [196/200], Loss: 0.0659
# Epoch [197/200], Loss: 0.0003
# Epoch [198/200], Loss: 0.3401
# Epoch [199/200], Loss: 0.2269
# Epoch [200/200], Loss: 0.2685
# Test Loss: 5.9734
